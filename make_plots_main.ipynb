# %%
# !pip install moval
# !pip install statannotations
# !pip install pandas
# !pip install tqdm
# !pip install matplotlib
# !pip install seaborn==0.12 # because statannotations not support the latest
# Out:
# ...
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.0
#     Uninstalling seaborn-0.12.0:
#       Successfully uninstalled seaborn-0.12.0
# ...
#   Using cached seaborn-0.12.0-py3-none-any.whl (285 kB)
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# statannotations 0.6.0 requires seaborn<0.12,>=0.9.0, but you have seaborn 0.12.0 which is incompatible.
# ...

# %%
import os
import gdown
import itertools
import zipfile
import pandas as pd
import numpy as np
import moval
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print(f"The installed MOVAL verision is {moval.__version__}")
print(f"The installed seaborn verision is {sns.__version__}")
# Out:
# The installed MOVAL verision is 0.2.5
# The installed seaborn verision is 0.12.0

# %%
# cls, acc

# %%
# cls, all conditions (95 + 95 + 7)
with open('cls_acc.npy', 'rb') as f:
    cifar10_acc_res = np.load(f)
    cifar10_acc_gt = np.load(f)
    cifar10_acc_res_ensemble = np.load(f)
    cifar100_acc_res = np.load(f)
    cifar100_acc_gt = np.load(f)
    cifar100_acc_res_ensemble = np.load(f)
    skin_acc_res = np.load(f)
    skin_acc_gt = np.load(f)
    skin_acc_res_ensemble = np.load(f)
with open('cls_sens.npy', 'rb') as f:
    cifar10_sens_res = np.load(f)
    cifar10_sens_gt = np.load(f)
    cifar10_sens_res_ensemble = np.load(f)
    cifar100_sens_res = np.load(f)
    cifar100_sens_gt = np.load(f)
    cifar100_sens_res_ensemble = np.load(f)
    skin_sens_res = np.load(f)
    skin_sens_gt = np.load(f)
    skin_sens_res_ensemble = np.load(f)
with open('cls_prec.npy', 'rb') as f:
    cifar10_prec_res = np.load(f)
    cifar10_prec_gt = np.load(f)
    cifar10_prec_res_ensemble = np.load(f)
    cifar100_prec_res = np.load(f)
    cifar100_prec_gt = np.load(f)
    cifar100_prec_res_ensemble = np.load(f)
    skin_prec_res = np.load(f)
    skin_prec_gt = np.load(f)
    skin_prec_res_ensemble = np.load(f)
with open('cls_f1.npy', 'rb') as f:
    cifar10_f1_res = np.load(f)
    cifar10_f1_gt = np.load(f)
    cifar10_f1_res_ensemble = np.load(f)
    cifar100_f1_res = np.load(f)
    cifar100_f1_gt = np.load(f)
    cifar100_f1_res_ensemble = np.load(f)
    skin_f1_res = np.load(f)
    skin_f1_gt = np.load(f)
    skin_f1_res_ensemble = np.load(f)
with open('cls_auc.npy', 'rb') as f:
    cifar10_auc_res = np.load(f)
    cifar10_auc_gt = np.load(f)
    cifar10_auc_res_ensemble = np.load(f)
    cifar100_auc_res = np.load(f)
    cifar100_auc_gt = np.load(f)
    cifar100_auc_res_ensemble = np.load(f)
    skin_auc_res = np.load(f)
    skin_auc_gt = np.load(f)
    skin_auc_res_ensemble = np.load(f)
with open('cls_conds_f1.npy', 'rb') as f:
    cifar10ci1_f1_res = np.load(f)
    cifar10ci1_f1_gt = np.load(f)
    cifar10ci1_f1_res_ensemble = np.load(f)
    cifar10ci2_f1_res = np.load(f)
    cifar10ci2_f1_gt = np.load(f)
    cifar10ci2_f1_res_ensemble = np.load(f)
    cifar10rl1_f1_res = np.load(f)
    cifar10rl1_f1_gt = np.load(f)
    cifar10rl1_f1_res_ensemble = np.load(f)
    cifar10rl2_f1_res = np.load(f)
    cifar10rl2_f1_gt = np.load(f)
    cifar10rl2_f1_res_ensemble = np.load(f)

# %%
# seg2d, all conditions (65 + 4)
with open('seg2d_acc.npy', 'rb') as f:
    cardiac_syn_acc_res = np.load(f)
    cardiac_syn_acc_gt = np.load(f)
    cardiac_syn_acc_res_ensemble = np.load(f)
    cardiac_nat_acc_res = np.load(f)
    cardiac_nat_acc_gt = np.load(f)
    cardiac_nat_acc_res_ensemble = np.load(f)
with open('seg2d_sens.npy', 'rb') as f:
    cardiac_syn_sens_res = np.load(f)
    cardiac_syn_sens_gt = np.load(f)
    cardiac_syn_sens_res_ensemble = np.load(f)
    cardiac_nat_sens_res = np.load(f)
    cardiac_nat_sens_gt = np.load(f)
    cardiac_nat_sens_res_ensemble = np.load(f)
with open('seg2d_prec.npy', 'rb') as f:
    cardiac_syn_prec_res = np.load(f)
    cardiac_syn_prec_gt = np.load(f)
    cardiac_syn_prec_res_ensemble = np.load(f)
    cardiac_nat_prec_res = np.load(f)
    cardiac_nat_prec_gt = np.load(f)
    cardiac_nat_prec_res_ensemble = np.load(f)
with open('seg2d_f1.npy', 'rb') as f:
    cardiac_syn_f1_res = np.load(f)
    cardiac_syn_f1_gt = np.load(f)
    cardiac_syn_f1_res_ensemble = np.load(f)
    cardiac_nat_f1_res = np.load(f)
    cardiac_nat_f1_gt = np.load(f)
    cardiac_nat_f1_res_ensemble = np.load(f)
with open('seg2d_auc.npy', 'rb') as f:
    cardiac_syn_auc_res = np.load(f)
    cardiac_syn_auc_gt = np.load(f)
    cardiac_syn_auc_res_ensemble = np.load(f)
    cardiac_nat_auc_res = np.load(f)
    cardiac_nat_auc_gt = np.load(f)
    cardiac_nat_auc_res_ensemble = np.load(f)

# %%
# seg3d, all conditions (83 + 5 + 83 + 12)
with open('seg3d_acc.npy', 'rb') as f:
    prostate_syn_acc_res = np.load(f)
    prostate_syn_acc_gt = np.load(f)
    prostate_syn_acc_res_ensemble = np.load(f)
    prostate_nat_acc_res = np.load(f)
    prostate_nat_acc_gt = np.load(f)
    prostate_nat_acc_res_ensemble = np.load(f)
    brain_syn_acc_res = np.load(f)
    brain_syn_acc_gt = np.load(f)
    brain_syn_acc_res_ensemble = np.load(f)
    brain_nat_acc_res = np.load(f)
    brain_nat_acc_gt = np.load(f)
    brain_nat_acc_res_ensemble = np.load(f)
with open('seg3d_sens.npy', 'rb') as f:
    prostate_syn_sens_res = np.load(f)
    prostate_syn_sens_gt = np.load(f)
    prostate_syn_sens_res_ensemble = np.load(f)
    prostate_nat_sens_res = np.load(f)
    prostate_nat_sens_gt = np.load(f)
    prostate_nat_sens_res_ensemble = np.load(f)
    brain_syn_sens_res = np.load(f)
    brain_syn_sens_gt = np.load(f)
    brain_syn_sens_res_ensemble = np.load(f)
    brain_nat_sens_res = np.load(f)
    brain_nat_sens_gt = np.load(f)
    brain_nat_sens_res_ensemble = np.load(f)
with open('seg3d_prec.npy', 'rb') as f:
    prostate_syn_prec_res = np.load(f)
    prostate_syn_prec_gt = np.load(f)
    prostate_syn_prec_res_ensemble = np.load(f)
    prostate_nat_prec_res = np.load(f)
    prostate_nat_prec_gt = np.load(f)
    prostate_nat_prec_res_ensemble = np.load(f)
    brain_syn_prec_res = np.load(f)
    brain_syn_prec_gt = np.load(f)
    brain_syn_prec_res_ensemble = np.load(f)
    brain_nat_prec_res = np.load(f)
    brain_nat_prec_gt = np.load(f)
    brain_nat_prec_res_ensemble = np.load(f)
with open('seg3d_f1.npy', 'rb') as f:
    prostate_syn_f1_res = np.load(f)
    prostate_syn_f1_gt = np.load(f)
    prostate_syn_f1_res_ensemble = np.load(f)
    prostate_nat_f1_res = np.load(f)
    prostate_nat_f1_gt = np.load(f)
    prostate_nat_f1_res_ensemble = np.load(f)
    brain_syn_f1_res = np.load(f)
    brain_syn_f1_gt = np.load(f)
    brain_syn_f1_res_ensemble = np.load(f)
    brain_nat_f1_res = np.load(f)
    brain_nat_f1_gt = np.load(f)
    brain_nat_f1_res_ensemble = np.load(f)
with open('seg3d_auc.npy', 'rb') as f:
    prostate_syn_auc_res = np.load(f)
    prostate_syn_auc_gt = np.load(f)
    prostate_syn_auc_res_ensemble = np.load(f)
    prostate_nat_auc_res = np.load(f)
    prostate_nat_auc_gt = np.load(f)
    prostate_nat_auc_res_ensemble = np.load(f)
    brain_syn_auc_res = np.load(f)
    brain_syn_auc_gt = np.load(f)
    brain_syn_auc_res_ensemble = np.load(f)
    brain_nat_auc_res = np.load(f)
    brain_nat_auc_gt = np.load(f)
    brain_nat_auc_res_ensemble = np.load(f)
with open('seg3d_conds_f1.npy', 'rb') as f:
    brainci1_syn_f1_res = np.load(f)
    brainci1_syn_f1_gt = np.load(f)
    brainci1_syn_f1_res_ensemble = np.load(f)
    brainci2_syn_f1_res = np.load(f)
    brainci2_syn_f1_gt = np.load(f)
    brainci2_syn_f1_res_ensemble = np.load(f)
    brainrl1_syn_f1_res = np.load(f)
    brainrl1_syn_f1_gt = np.load(f)
    brainrl1_syn_f1_res_ensemble = np.load(f)
    brainrl2_syn_f1_res = np.load(f)
    brainrl2_syn_f1_gt = np.load(f)
    brainrl2_syn_f1_res_ensemble = np.load(f)
    brainci1_nat_f1_res = np.load(f)
    brainci1_nat_f1_gt = np.load(f)
    brainci1_nat_f1_res_ensemble = np.load(f)
    brainci2_nat_f1_res = np.load(f)
    brainci2_nat_f1_gt = np.load(f)
    brainci2_nat_f1_res_ensemble = np.load(f)
    brainrl1_nat_f1_res = np.load(f)
    brainrl1_nat_f1_gt = np.load(f)
    brainrl1_nat_f1_res_ensemble = np.load(f)
    brainrl2_nat_f1_res = np.load(f)
    brainrl2_nat_f1_gt = np.load(f)
    brainrl2_nat_f1_res_ensemble = np.load(f)

# %%
# do the plots

# %%
# cls acc
diff_mean_cifar10 = np.mean(np.abs(cifar10_acc_res - cifar10_acc_gt), axis = 1)
diff_ensemb_cifar10 = np.mean(np.abs(cifar10_acc_res_ensemble - cifar10_acc_gt[0, :]), axis = 1)
#
diff_mean_cifar100 = np.mean(np.abs(cifar100_acc_res - cifar100_acc_gt), axis = 1)
diff_ensemb_cifar100 = np.mean(np.abs(cifar100_acc_res_ensemble - cifar100_acc_gt[0, :]), axis = 1)
#
diff_mean_skin = np.mean(np.abs(skin_acc_res - skin_acc_gt), axis = 1)
diff_ensemb_skin = np.mean(np.abs(skin_acc_res_ensemble - skin_acc_gt[0, :]), axis = 1)
#
diff_mean = (diff_mean_cifar10 + diff_mean_cifar100 + diff_mean_skin) / 3
diff_ensemb = (diff_ensemb_cifar10 + diff_ensemb_cifar100 + diff_ensemb_skin) / 3

# %%
# full
confs = ['MCP', 'Energy', 'Entropy', 'Doctor']
estim_algorithms = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']

estim = []
conf = []
err_mean = []
novel = []
k_option = 0
err_mean_existing = []

for _estim_algorithm in estim_algorithms:
    for _conf in confs:

        # class agnostic version
        
        conf.append(_conf)
        estim.append(_estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))

        if _conf == 'MCP' and (_estim_algorithm in ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']):
            novel.append('Existing Methods')
            err_mean_existing.append(diff_mean[k_option])
        else:
            novel.append('Provided by MOVAL')
        k_option += 1

        # class specific version
        if _estim_algorithm == 'AC':
            continue
        
        conf.append(_conf)
        estim.append('CS ' + _estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))
        novel.append('Provided by MOVAL')
        
        k_option += 1

conf.append('MOVAL')
estim.append('MOVAL\nEnsemble')

err_mean.append(np.log(diff_ensemb[0]))
novel.append('Provided by MOVAL')

# %%
d = {'Estimation Algorithm': estim, 'Confidence Score': conf, 'MAE': err_mean, 'Category': novel}
df = pd.DataFrame(data=d)
#
custom_order = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC', 'CS TS', 'CS DoC', 'CS ATC', 'CS TS-ATC', 'MOVAL\nEnsemble']
df['Estimation Algorithm'] = pd.Categorical(df['Estimation Algorithm'], categories=custom_order, ordered=True)
df = df.sort_values(by='Estimation Algorithm')
#
custom_order = ['MCP', 'Energy', 'Entropy', 'Doctor', 'MOVAL']
df['Confidence Score'] = pd.Categorical(df['Confidence Score'], categories=custom_order, ordered=True)
df = df.sort_values(by='Confidence Score')
#
# Map 'Confidence Score' to numerical values
confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3, 'MOVAL': 1.5}
df['Confidence Score Numeric'] = df['Confidence Score'].map(confidence_mapping)
_confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3}
#
# Map 'Confidence Score' to numerical values
estimation_mapping = {'AC': 0, 'TS': 1, 'DoC': 2, 'ATC': 3, 'TS-ATC': 4, 'CS TS': 5, 'CS DoC': 6, 'CS ATC': 7, 'CS TS-ATC': 8, 'MOVAL\nEnsemble': 9.5}
df['Estimation Algorithm Numeric'] = df['Estimation Algorithm'].map(estimation_mapping)

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.set_style("darkgrid")
category_palette = {'Existing Methods': 'grey', 'Provided by MOVAL': '#1f77b4'}
ax = sns.scatterplot(
    data=df, x="Estimation Algorithm Numeric", y="Confidence Score Numeric", hue="Category", size="MAE",
    sizes=(100, 2000), palette=category_palette
)
ax.set(ylim=(3.5, -0.5))
ax.tick_params(axis='x', rotation=20)
#
# Convert y-axis back to categorical labels
ax.set_yticks(list(_confidence_mapping.values()))
ax.set_yticklabels(list(_confidence_mapping.keys()))
# Convert y-axis back to categorical labels
ax.set_xticks(list(estimation_mapping.values()))
ax.set_xticklabels(list(estimation_mapping.keys()))
#
# Get the handles and labels from the legend
handles, labels = ax.get_legend_handles_labels()

# Create a custom legend with only desired categories
desired_labels = ['Category', 'Existing Methods', 'Provided by MOVAL', 'MAE']
desired_handles = [h for h, l in zip(handles, labels) if l in desired_labels]

# Create custom legend entries for sizes
current_method = np.min(err_mean_existing)
our_method = np.min(np.concatenate((diff_mean, diff_ensemb)))

current_method_log = np.log(current_method)
our_method_log = np.log(our_method)
min_mae = df['MAE'].min()
max_mae = df['MAE'].max()
min_size, max_size = 50, 1000

sizes_legend_small = [plt.scatter([], [], s=s, label=f'Size: {s}', color='#1f77b4') for s in [min_size + (our_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]
sizes_legend_large = [plt.scatter([], [], s=s, label=f'Size: {s}', color='grey') for s in [min_size + (current_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]

# Concatenate legend handles and labels
desired_handles = desired_handles + sizes_legend_large + sizes_legend_small
desired_labels = desired_labels + [f'Existing Best: {current_method * 100:.1f}'] + [f'MOVAL Best: {our_method * 100:.1f}']

# Create the legend with desired categories and size examples
legend = plt.legend(handles=desired_handles, labels=desired_labels, bbox_to_anchor=(1., 1.), labelspacing=1)

# Set the y-axis label
ax.set_ylabel('Confidence Score')
ax.set_xlabel('Estimation Algorithm')

top_5 = df.nsmallest(5, 'MAE')
top_n = 1
for i, point in top_5.iterrows():
    ax.annotate(
        f"Top {top_n}", 
        (point["Estimation Algorithm Numeric"], point["Confidence Score Numeric"]),
        textcoords="offset points", 
        xytext=(0,12), 
        ha='center',
        fontsize=12, 
        color='red', 
        weight='bold',
        fontstyle='italic'
    )
    top_n += 1

plt.savefig('Fig_cls_acc.pdf', bbox_inches='tight')

# %%
print(f"existing best: {current_method * 100}, to moval {diff_ensemb[0] * 100}")
# Out:
# existing best: 4.85624353579682, to moval 3.089172953691191

# %%
# cls sens
# prepare class prior
clslist = []
clslist.append([0, 1, 2, 3, 4, 5, 6])
clslist.append([1, 2, 3, 4, 5, 6])
clslist.append([0, 1, 2, 3, 4, 5])
clslist.append([0, 1, 2, 3, 4, 5, 6])
clslist.append([4, 5])
clslist.append([1, 2, 3, 4, 5])
clslist.append([4, 5])
#
diff_mean_cifar10 = np.mean(np.abs(cifar10_sens_res - cifar10_sens_gt), axis = (0, 2, 3))
diff_ensemb_cifar10 = np.mean(np.abs(cifar10_sens_res_ensemble - cifar10_sens_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_cifar100 = np.mean(np.abs(cifar100_sens_res - cifar100_sens_gt), axis = (0, 2, 3))
diff_ensemb_cifar100 = np.mean(np.abs(cifar100_sens_res_ensemble - cifar100_sens_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diffs_abs = np.abs(skin_sens_res - skin_sens_gt)
diff = []
for cond in range(len(skin_sens_res)):
    cls_sel = clslist[cond]
    diff.append(np.mean(diffs_abs[cond:cond+1, :, :, cls_sel], axis = 3))
diff = np.array(diff)
diff = diff[:, 0, :, 0]
diff_mean_skin = np.mean(diff, axis = 0)

diffs_abs_ensemble = np.abs(skin_sens_res_ensemble - skin_sens_gt[:, 0:1, :, :])
diff_ensemble = []
for cond in range(len(skin_sens_res)):
    cls_sel = clslist[cond]
    diff_ensemble.append(np.mean(diffs_abs_ensemble[cond:cond+1, :, :, cls_sel], axis = 3))
diff_ensemble = np.array(diff_ensemble)
diff_ensemble = diff_ensemble[:, 0, :, 0]
diff_ensemb_skin = np.mean(diff_ensemble, axis = 0)
#
diff_mean = (diff_mean_cifar10 + diff_mean_cifar100 + diff_mean_skin) / 3
diff_ensemb = (diff_ensemb_cifar10 + diff_ensemb_cifar100 + diff_ensemb_skin) / 3

# %%
# full
confs = ['MCP', 'Energy', 'Entropy', 'Doctor']
estim_algorithms = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']

estim = []
conf = []
err_mean = []
err_mean_existing = []
novel = []
k_option = 0

for _estim_algorithm in estim_algorithms:
    for _conf in confs:

        # class agnostic version
        
        conf.append(_conf)
        estim.append(_estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))

        if _conf == 'MCP' and (_estim_algorithm in ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']):
            novel.append('Existing Methods')
            err_mean_existing.append(diff_mean[k_option])
        else:
            novel.append('Provided by MOVAL')
        k_option += 1

        # class specific version
        if _estim_algorithm == 'AC':
            continue
        
        conf.append(_conf)
        estim.append('CS ' + _estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))
        novel.append('Provided by MOVAL')
        
        k_option += 1

conf.append('MOVAL')
estim.append('MOVAL\nEnsemble')

err_mean.append(np.log(diff_ensemb[0]))
novel.append('Provided by MOVAL')

# %%
d = {'Estimation Algorithm': estim, 'Confidence Score': conf, 'MAE': err_mean, 'Category': novel}
df = pd.DataFrame(data=d)
#
custom_order = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC', 'CS TS', 'CS DoC', 'CS ATC', 'CS TS-ATC', 'MOVAL\nEnsemble']
df['Estimation Algorithm'] = pd.Categorical(df['Estimation Algorithm'], categories=custom_order, ordered=True)
df = df.sort_values(by='Estimation Algorithm')
#
custom_order = ['MCP', 'Energy', 'Entropy', 'Doctor', 'MOVAL']
df['Confidence Score'] = pd.Categorical(df['Confidence Score'], categories=custom_order, ordered=True)
df = df.sort_values(by='Confidence Score')
#
# Map 'Confidence Score' to numerical values
confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3, 'MOVAL': 1.5}
df['Confidence Score Numeric'] = df['Confidence Score'].map(confidence_mapping)
_confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3}
#
# Map 'Confidence Score' to numerical values
estimation_mapping = {'AC': 0, 'TS': 1, 'DoC': 2, 'ATC': 3, 'TS-ATC': 4, 'CS TS': 5, 'CS DoC': 6, 'CS ATC': 7, 'CS TS-ATC': 8, 'MOVAL\nEnsemble': 9.5}
df['Estimation Algorithm Numeric'] = df['Estimation Algorithm'].map(estimation_mapping)

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.set_style("darkgrid")
category_palette = {'Existing Methods': 'grey', 'Provided by MOVAL': '#1f77b4'}
ax = sns.scatterplot(
    data=df, x="Estimation Algorithm Numeric", y="Confidence Score Numeric", hue="Category", size="MAE",
    sizes=(100, 2000), palette=category_palette
)
ax.set(ylim=(3.5, -0.5))
ax.tick_params(axis='x', rotation=20)
#
# Convert y-axis back to categorical labels
ax.set_yticks(list(_confidence_mapping.values()))
ax.set_yticklabels(list(_confidence_mapping.keys()))
# Convert y-axis back to categorical labels
ax.set_xticks(list(estimation_mapping.values()))
ax.set_xticklabels(list(estimation_mapping.keys()))
#
# Get the handles and labels from the legend
handles, labels = ax.get_legend_handles_labels()

# Create a custom legend with only desired categories
desired_labels = ['Category', 'Existing Methods', 'Provided by MOVAL', 'MAE']
desired_handles = [h for h, l in zip(handles, labels) if l in desired_labels]

# Create custom legend entries for sizes
current_method = np.min(err_mean_existing)
our_method = np.min(np.concatenate((diff_mean, diff_ensemb)))

current_method_log = np.log(current_method)
our_method_log = np.log(our_method)
min_mae = df['MAE'].min()
max_mae = df['MAE'].max()
min_size, max_size = 50, 1000

sizes_legend_small = [plt.scatter([], [], s=s, label=f'Size: {s}', color='#1f77b4') for s in [min_size + (our_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]
sizes_legend_large = [plt.scatter([], [], s=s, label=f'Size: {s}', color='grey') for s in [min_size + (current_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]

# Concatenate legend handles and labels
desired_handles = desired_handles + sizes_legend_large + sizes_legend_small
desired_labels = desired_labels + [f'Existing Best: {current_method * 100:.1f}'] + [f'MOVAL Best: {our_method * 100:.1f}']

# Create the legend with desired categories and size examples
legend = plt.legend(handles=desired_handles, labels=desired_labels, bbox_to_anchor=(1., 1.), labelspacing=1)

# Set the y-axis label
ax.set_ylabel('Confidence Score')
ax.set_xlabel('Estimation Algorithm')

top_5 = df.nsmallest(5, 'MAE')
top_n = 1
for i, point in top_5.iterrows():
    ax.annotate(
        f"Top {top_n}", 
        (point["Estimation Algorithm Numeric"], point["Confidence Score Numeric"]),
        textcoords="offset points", 
        xytext=(0,12), 
        ha='center',
        fontsize=12, 
        color='red', 
        weight='bold',
        fontstyle='italic'
    )
    top_n += 1

plt.savefig('Fig_cls_sens.pdf', bbox_inches='tight')

# %%
# cls f1
# prepare class prior
clslist = []
clslist.append([0, 1, 2, 3, 4, 5, 6])
clslist.append([1, 2, 3, 4, 5, 6])
clslist.append([0, 1, 2, 3, 4, 5])
clslist.append([0, 1, 2, 3, 4, 5, 6])
clslist.append([4, 5])
clslist.append([1, 2, 3, 4, 5])
clslist.append([4, 5])
#
diff_mean_cifar10 = np.mean(np.abs(cifar10_f1_res - cifar10_f1_gt), axis = (0, 2, 3))
diff_ensemb_cifar10 = np.mean(np.abs(cifar10_f1_res_ensemble - cifar10_f1_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_cifar100 = np.mean(np.abs(cifar100_f1_res - cifar100_f1_gt), axis = (0, 2, 3))
diff_ensemb_cifar100 = np.mean(np.abs(cifar100_f1_res_ensemble - cifar100_f1_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diffs_abs = np.abs(skin_f1_res - skin_f1_gt)
diff = []
for cond in range(len(skin_f1_res)):
    cls_sel = clslist[cond]
    diff.append(np.mean(diffs_abs[cond:cond+1, :, :, cls_sel], axis = 3))
diff = np.array(diff)
diff = diff[:, 0, :, 0]
diff_mean_skin = np.mean(diff, axis = 0)

diffs_abs_ensemble = np.abs(skin_f1_res_ensemble - skin_f1_gt[:, 0:1, :, :])
diff_ensemble = []
for cond in range(len(skin_f1_res)):
    cls_sel = clslist[cond]
    diff_ensemble.append(np.mean(diffs_abs_ensemble[cond:cond+1, :, :, cls_sel], axis = 3))
diff_ensemble = np.array(diff_ensemble)
diff_ensemble = diff_ensemble[:, 0, :, 0]
diff_ensemb_skin = np.mean(diff_ensemble, axis = 0)
#
diff_mean = (diff_mean_cifar10 + diff_mean_cifar100 + diff_mean_skin) / 3
diff_ensemb = (diff_ensemb_cifar10 + diff_ensemb_cifar100 + diff_ensemb_skin) / 3

# %%
# full
confs = ['MCP', 'Energy', 'Entropy', 'Doctor']
estim_algorithms = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']

estim = []
conf = []
err_mean = []
err_mean_existing = []
novel = []
k_option = 0

for _estim_algorithm in estim_algorithms:
    for _conf in confs:

        # class agnostic version
        
        conf.append(_conf)
        estim.append(_estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))

        if _conf == 'MCP' and (_estim_algorithm in ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']):
            novel.append('Existing Methods')
            err_mean_existing.append(diff_mean[k_option])
        else:
            novel.append('Provided by MOVAL')
        k_option += 1

        # class specific version
        if _estim_algorithm == 'AC':
            continue
        
        conf.append(_conf)
        estim.append('CS ' + _estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))
        novel.append('Provided by MOVAL')
        
        k_option += 1

conf.append('MOVAL')
estim.append('MOVAL\nEnsemble')

err_mean.append(np.log(diff_ensemb[0]))
novel.append('Provided by MOVAL')

# %%
d = {'Estimation Algorithm': estim, 'Confidence Score': conf, 'MAE': err_mean, 'Category': novel}
df = pd.DataFrame(data=d)
#
custom_order = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC', 'CS TS', 'CS DoC', 'CS ATC', 'CS TS-ATC', 'MOVAL\nEnsemble']
df['Estimation Algorithm'] = pd.Categorical(df['Estimation Algorithm'], categories=custom_order, ordered=True)
df = df.sort_values(by='Estimation Algorithm')
#
custom_order = ['MCP', 'Energy', 'Entropy', 'Doctor', 'MOVAL']
df['Confidence Score'] = pd.Categorical(df['Confidence Score'], categories=custom_order, ordered=True)
df = df.sort_values(by='Confidence Score')
#
# Map 'Confidence Score' to numerical values
confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3, 'MOVAL': 1.5}
df['Confidence Score Numeric'] = df['Confidence Score'].map(confidence_mapping)
_confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3}
#
# Map 'Confidence Score' to numerical values
estimation_mapping = {'AC': 0, 'TS': 1, 'DoC': 2, 'ATC': 3, 'TS-ATC': 4, 'CS TS': 5, 'CS DoC': 6, 'CS ATC': 7, 'CS TS-ATC': 8, 'MOVAL\nEnsemble': 9.5}
df['Estimation Algorithm Numeric'] = df['Estimation Algorithm'].map(estimation_mapping)

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.set_style("darkgrid")
category_palette = {'Existing Methods': 'grey', 'Provided by MOVAL': '#1f77b4'}
ax = sns.scatterplot(
    data=df, x="Estimation Algorithm Numeric", y="Confidence Score Numeric", hue="Category", size="MAE",
    sizes=(100, 2000), palette=category_palette
)
ax.set(ylim=(3.5, -0.5))
ax.tick_params(axis='x', rotation=20)
#
# Convert y-axis back to categorical labels
ax.set_yticks(list(_confidence_mapping.values()))
ax.set_yticklabels(list(_confidence_mapping.keys()))
# Convert y-axis back to categorical labels
ax.set_xticks(list(estimation_mapping.values()))
ax.set_xticklabels(list(estimation_mapping.keys()))
#
# Get the handles and labels from the legend
handles, labels = ax.get_legend_handles_labels()

# Create a custom legend with only desired categories
desired_labels = ['Category', 'Existing Methods', 'Provided by MOVAL', 'MAE']
desired_handles = [h for h, l in zip(handles, labels) if l in desired_labels]

# Create custom legend entries for sizes
current_method = np.min(err_mean_existing)
our_method = np.min(np.concatenate((diff_mean, diff_ensemb)))

current_method_log = np.log(current_method)
our_method_log = np.log(our_method)
min_mae = df['MAE'].min()
max_mae = df['MAE'].max()
min_size, max_size = 50, 1000

sizes_legend_small = [plt.scatter([], [], s=s, label=f'Size: {s}', color='#1f77b4') for s in [min_size + (our_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]
sizes_legend_large = [plt.scatter([], [], s=s, label=f'Size: {s}', color='grey') for s in [min_size + (current_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]

# Concatenate legend handles and labels
desired_handles = desired_handles + sizes_legend_large + sizes_legend_small
desired_labels = desired_labels + [f'Existing Best: {current_method * 100:.1f}'] + [f'MOVAL Best: {our_method * 100:.1f}']

# Create the legend with desired categories and size examples
legend = plt.legend(handles=desired_handles, labels=desired_labels, bbox_to_anchor=(1., 1.), labelspacing=1)

# Set the y-axis label
ax.set_ylabel('Confidence Score')
ax.set_xlabel('Estimation Algorithm')

top_5 = df.nsmallest(5, 'MAE')
top_n = 1
for i, point in top_5.iterrows():
    ax.annotate(
        f"Top {top_n}", 
        (point["Estimation Algorithm Numeric"], point["Confidence Score Numeric"]),
        textcoords="offset points", 
        xytext=(0,12), 
        ha='center',
        fontsize=12, 
        color='red', 
        weight='bold',
        fontstyle='italic'
    )
    top_n += 1

plt.savefig('Fig_cls_f1.pdf', bbox_inches='tight')

# %%
print(f"existing best: {current_method * 100}, to moval {diff_ensemb[0] * 100}")
# Out:
# existing best: 20.62778498492307, to moval 14.810041420924588

# %%
# cls prec
# prepare class prior
clslist = []
clslist.append([0, 1, 2, 3, 4, 5, 6])
clslist.append([1, 2, 3, 4, 5, 6])
clslist.append([0, 1, 2, 3, 4, 5])
clslist.append([0, 1, 2, 3, 4, 5, 6])
clslist.append([4, 5])
clslist.append([1, 2, 3, 4, 5])
clslist.append([4, 5])
#
diff_mean_cifar10 = np.mean(np.abs(cifar10_prec_res - cifar10_prec_gt), axis = (0, 2, 3))
diff_ensemb_cifar10 = np.mean(np.abs(cifar10_prec_res_ensemble - cifar10_prec_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_cifar100 = np.mean(np.abs(cifar100_prec_res - cifar100_prec_gt), axis = (0, 2, 3))
diff_ensemb_cifar100 = np.mean(np.abs(cifar100_prec_res_ensemble - cifar100_prec_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diffs_abs = np.abs(skin_prec_res - skin_prec_gt)
diff = []
for cond in range(len(skin_prec_res)):
    cls_sel = clslist[cond]
    diff.append(np.mean(diffs_abs[cond:cond+1, :, :, cls_sel], axis = 3))
diff = np.array(diff)
diff = diff[:, 0, :, 0]
diff_mean_skin = np.mean(diff, axis = 0)

diffs_abs_ensemble = np.abs(skin_prec_res_ensemble - skin_prec_gt[:, 0:1, :, :])
diff_ensemble = []
for cond in range(len(skin_prec_res)):
    cls_sel = clslist[cond]
    diff_ensemble.append(np.mean(diffs_abs_ensemble[cond:cond+1, :, :, cls_sel], axis = 3))
diff_ensemble = np.array(diff_ensemble)
diff_ensemble = diff_ensemble[:, 0, :, 0]
diff_ensemb_skin = np.mean(diff_ensemble, axis = 0)
#
diff_mean = (diff_mean_cifar10 + diff_mean_cifar100 + diff_mean_skin) / 3
diff_ensemb = (diff_ensemb_cifar10 + diff_ensemb_cifar100 + diff_ensemb_skin) / 3

# %%
# half
confs = ['MCP', 'Energy', 'Entropy', 'Doctor']
estim_algorithms = ['AC', 'TS', 'DoC']

estim = []
conf = []
err_mean = []
novel = []
k_option = 0
err_mean_existing = []

for _estim_algorithm in estim_algorithms:
    for _conf in confs:

        # class agnostic version
        
        conf.append(_conf)
        estim.append(_estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))

        if _conf == 'MCP' and (_estim_algorithm in ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']):
            novel.append('Existing Methods')
            err_mean_existing.append(diff_mean[k_option])
        else:
            novel.append('Provided by MOVAL')
        k_option += 1

        # class specific version
        if _estim_algorithm == 'AC':
            continue
        
        conf.append(_conf)
        estim.append('CS ' + _estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))
        novel.append('Provided by MOVAL')
        
        k_option += 1

conf.append('MOVAL')
estim.append('MOVAL\nEnsemble')

err_mean.append(np.log(diff_ensemb[0]))
novel.append('Provided by MOVAL')

# %%
d = {'Estimation Algorithm': estim, 'Confidence Score': conf, 'MAE': err_mean, 'Category': novel}
df = pd.DataFrame(data=d)
#
custom_order = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC', 'CS TS', 'CS DoC', 'CS ATC', 'CS TS-ATC', 'MOVAL\nEnsemble']
df['Estimation Algorithm'] = pd.Categorical(df['Estimation Algorithm'], categories=custom_order, ordered=True)
df = df.sort_values(by='Estimation Algorithm')
#
custom_order = ['MCP', 'Energy', 'Entropy', 'Doctor', 'MOVAL']
df['Confidence Score'] = pd.Categorical(df['Confidence Score'], categories=custom_order, ordered=True)
df = df.sort_values(by='Confidence Score')
#
# Map 'Confidence Score' to numerical values
confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3, 'MOVAL': 1.5}
df['Confidence Score Numeric'] = df['Confidence Score'].map(confidence_mapping)
_confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3}
#
# Map 'Confidence Score' to numerical values
estimation_mapping = {'AC': 0, 'TS': 1, 'DoC': 2, 'CS TS': 3, 'CS DoC': 4, 'MOVAL\nEnsemble': 5.5}
df['Estimation Algorithm Numeric'] = df['Estimation Algorithm'].map(estimation_mapping)

# %%
sns.set(rc={'figure.figsize':(3.7,3)})
sns.set_style("darkgrid")
category_palette = {'Existing Methods': 'grey', 'Provided by MOVAL': '#1f77b4'}
ax = sns.scatterplot(
    data=df, x="Estimation Algorithm Numeric", y="Confidence Score Numeric", hue="Category", size="MAE",
    sizes=(100, 2000), palette=category_palette
)
ax.set(ylim=(3.5, -0.5))
ax.tick_params(axis='x', rotation=20)
#
# Convert y-axis back to categorical labels
ax.set_yticks(list(_confidence_mapping.values()))
ax.set_yticklabels(list(_confidence_mapping.keys()))
# Convert y-axis back to categorical labels
ax.set_xticks(list(estimation_mapping.values()))
ax.set_xticklabels(list(estimation_mapping.keys()))
#
# Get the handles and labels from the legend
handles, labels = ax.get_legend_handles_labels()

# Create a custom legend with only desired categories
desired_labels = ['Category', 'Existing Methods', 'Provided by MOVAL', 'MAE']
desired_handles = [h for h, l in zip(handles, labels) if l in desired_labels]

# Create custom legend entries for sizes
current_method = np.min(err_mean_existing)
our_method = np.min(np.concatenate((diff_mean, diff_ensemb)))

current_method_log = np.log(current_method)
our_method_log = np.log(our_method)
min_mae = df['MAE'].min()
max_mae = df['MAE'].max()
min_size, max_size = 50, 1000

sizes_legend_small = [plt.scatter([], [], s=s, label=f'Size: {s}', color='#1f77b4') for s in [min_size + (our_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]
sizes_legend_large = [plt.scatter([], [], s=s, label=f'Size: {s}', color='grey') for s in [min_size + (current_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]

# Concatenate legend handles and labels
desired_handles = desired_handles + sizes_legend_large + sizes_legend_small
desired_labels = desired_labels + [f'Existing Best: {current_method * 100:.1f}'] + [f'MOVAL Best: {our_method * 100:.1f}']

# Create the legend with desired categories and size examples
legend = plt.legend(handles=desired_handles, labels=desired_labels, bbox_to_anchor=(1., 1.), labelspacing=1)

# Set the y-axis label
ax.set_ylabel('Confidence Score')
ax.set_xlabel('Estimation Algorithm')

top_5 = df.nsmallest(5, 'MAE')
top_n = 1
for i, point in top_5.iterrows():
    ax.annotate(
        f"Top {top_n}", 
        (point["Estimation Algorithm Numeric"], point["Confidence Score Numeric"]),
        textcoords="offset points", 
        xytext=(0,12), 
        ha='center',
        fontsize=12, 
        color='red', 
        weight='bold',
        fontstyle='italic'
    )
    top_n += 1

plt.savefig('Fig_cls_prec.pdf', bbox_inches='tight')

# %%
print(f"existing best: {current_method * 100}, to moval {our_method * 100}")
# Out:
# existing best: 27.317918276412673, to moval 24.103868250428082

# %%
# cls auc
# prepare class prior
clslist = []
clslist.append([0, 1, 2, 3, 4, 5, 6])
clslist.append([1, 2, 3, 4, 5, 6])
clslist.append([0, 1, 2, 3, 4, 5])
clslist.append([0, 1, 2, 3, 4, 5, 6])
clslist.append([4, 5])
clslist.append([1, 2, 3, 4, 5])
clslist.append([4, 5])
#
diff_mean_cifar10 = np.mean(np.abs(cifar10_auc_res - cifar10_auc_gt), axis = (0, 2, 3))
diff_ensemb_cifar10 = np.mean(np.abs(cifar10_auc_res_ensemble - cifar10_auc_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_cifar100 = np.mean(np.abs(cifar100_auc_res - cifar100_auc_gt), axis = (0, 2, 3))
diff_ensemb_cifar100 = np.mean(np.abs(cifar100_auc_res_ensemble - cifar100_auc_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diffs_abs = np.abs(skin_auc_res - skin_auc_gt)
diff = []
for cond in range(len(skin_auc_res)):
    cls_sel = clslist[cond]
    diff.append(np.mean(diffs_abs[cond:cond+1, :, :, cls_sel], axis = 3))
diff = np.array(diff)
diff = diff[:, 0, :, 0]
diff_mean_skin = np.mean(diff, axis = 0)

diffs_abs_ensemble = np.abs(skin_auc_res_ensemble - skin_auc_gt[:, 0:1, :, :])
diff_ensemble = []
for cond in range(len(skin_auc_res)):
    cls_sel = clslist[cond]
    diff_ensemble.append(np.mean(diffs_abs_ensemble[cond:cond+1, :, :, cls_sel], axis = 3))
diff_ensemble = np.array(diff_ensemble)
diff_ensemble = diff_ensemble[:, 0, :, 0]
diff_ensemb_skin = np.mean(diff_ensemble, axis = 0)
#
diff_mean = (diff_mean_cifar10 + diff_mean_cifar100 + diff_mean_skin) / 3
diff_ensemb = (diff_ensemb_cifar10 + diff_ensemb_cifar100 + diff_ensemb_skin) / 3

# %%
# half
confs = ['MCP', 'Energy', 'Entropy', 'Doctor']
estim_algorithms = ['AC', 'TS', 'DoC']

estim = []
conf = []
err_mean = []
novel = []
k_option = 0
err_mean_existing = []

for _estim_algorithm in estim_algorithms:
    for _conf in confs:

        # class agnostic version
        
        conf.append(_conf)
        estim.append(_estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))

        if _conf == 'MCP' and (_estim_algorithm in ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']):
            novel.append('Existing Methods')
            err_mean_existing.append(diff_mean[k_option])
        else:
            novel.append('Provided by MOVAL')
        k_option += 1

        # class specific version
        if _estim_algorithm == 'AC':
            continue
        
        conf.append(_conf)
        estim.append('CS ' + _estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))
        novel.append('Provided by MOVAL')
        
        k_option += 1

conf.append('MOVAL')
estim.append('MOVAL\nEnsemble')

err_mean.append(np.log(diff_ensemb[0]))
novel.append('Provided by MOVAL')

# %%
d = {'Estimation Algorithm': estim, 'Confidence Score': conf, 'MAE': err_mean, 'Category': novel}
df = pd.DataFrame(data=d)
#
custom_order = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC', 'CS TS', 'CS DoC', 'CS ATC', 'CS TS-ATC', 'MOVAL\nEnsemble']
df['Estimation Algorithm'] = pd.Categorical(df['Estimation Algorithm'], categories=custom_order, ordered=True)
df = df.sort_values(by='Estimation Algorithm')
#
custom_order = ['MCP', 'Energy', 'Entropy', 'Doctor', 'MOVAL']
df['Confidence Score'] = pd.Categorical(df['Confidence Score'], categories=custom_order, ordered=True)
df = df.sort_values(by='Confidence Score')
#
# Map 'Confidence Score' to numerical values
confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3, 'MOVAL': 1.5}
df['Confidence Score Numeric'] = df['Confidence Score'].map(confidence_mapping)
_confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3}
#
# Map 'Confidence Score' to numerical values
estimation_mapping = {'AC': 0, 'TS': 1, 'DoC': 2, 'CS TS': 3, 'CS DoC': 4, 'MOVAL\nEnsemble': 5.5}
df['Estimation Algorithm Numeric'] = df['Estimation Algorithm'].map(estimation_mapping)

# %%
sns.set(rc={'figure.figsize':(3.7,3)})
sns.set_style("darkgrid")
category_palette = {'Existing Methods': 'grey', 'Provided by MOVAL': '#1f77b4'}
ax = sns.scatterplot(
    data=df, x="Estimation Algorithm Numeric", y="Confidence Score Numeric", hue="Category", size="MAE",
    sizes=(100, 2000), palette=category_palette
)
ax.set(ylim=(3.5, -0.5))
ax.tick_params(axis='x', rotation=20)
#
# Convert y-axis back to categorical labels
ax.set_yticks(list(_confidence_mapping.values()))
ax.set_yticklabels(list(_confidence_mapping.keys()))
# Convert y-axis back to categorical labels
ax.set_xticks(list(estimation_mapping.values()))
ax.set_xticklabels(list(estimation_mapping.keys()))
#
# Get the handles and labels from the legend
handles, labels = ax.get_legend_handles_labels()

# Create a custom legend with only desired categories
desired_labels = ['Category', 'Existing Methods', 'Provided by MOVAL', 'MAE']
desired_handles = [h for h, l in zip(handles, labels) if l in desired_labels]

# Create custom legend entries for sizes
current_method = np.min(err_mean_existing)
our_method = np.min(np.concatenate((diff_mean, diff_ensemb)))

current_method_log = np.log(current_method)
our_method_log = np.log(our_method)
min_mae = df['MAE'].min()
max_mae = df['MAE'].max()
min_size, max_size = 50, 1000

sizes_legend_small = [plt.scatter([], [], s=s, label=f'Size: {s}', color='#1f77b4') for s in [min_size + (our_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]
sizes_legend_large = [plt.scatter([], [], s=s, label=f'Size: {s}', color='grey') for s in [min_size + (current_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]

# Concatenate legend handles and labels
desired_handles = desired_handles + sizes_legend_large + sizes_legend_small
desired_labels = desired_labels + [f'Existing Best: {current_method * 100:.1f}'] + [f'MOVAL Best: {our_method * 100:.1f}']

# Create the legend with desired categories and size examples
legend = plt.legend(handles=desired_handles, labels=desired_labels, bbox_to_anchor=(1., 1.), labelspacing=1)

# Set the y-axis label
ax.set_ylabel('Confidence Score')
ax.set_xlabel('Estimation Algorithm')

top_5 = df.nsmallest(5, 'MAE')
top_n = 1
for i, point in top_5.iterrows():
    ax.annotate(
        f"Top {top_n}", 
        (point["Estimation Algorithm Numeric"], point["Confidence Score Numeric"]),
        textcoords="offset points", 
        xytext=(0,12), 
        ha='center',
        fontsize=12, 
        color='red', 
        weight='bold',
        fontstyle='italic'
    )
    top_n += 1

plt.savefig('Fig_cls_auc.pdf', bbox_inches='tight')

# %%
print(f"existing best: {current_method * 100}, to moval {our_method * 100}")
# Out:
# existing best: 10.332281315744362, to moval 8.08130735001313

# %%
# seg2d acc
diff_mean_syn = np.mean(np.abs(cardiac_syn_acc_res - cardiac_syn_acc_gt), axis = (0, 2, 3))
diff_ensemb_syn = np.mean(np.abs(cardiac_syn_acc_res_ensemble - cardiac_syn_acc_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_nat = np.mean(np.abs(cardiac_nat_acc_res - cardiac_nat_acc_gt), axis = (0, 2, 3))
diff_ensemb_nat = np.mean(np.abs(cardiac_nat_acc_res_ensemble - cardiac_nat_acc_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean = (diff_mean_syn + diff_mean_nat) / 2
diff_ensemb = (diff_ensemb_syn + diff_ensemb_nat) / 2

# %%
# full
confs = ['MCP', 'Energy', 'Entropy', 'Doctor']
estim_algorithms = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']

estim = []
conf = []
err_mean = []
novel = []
k_option = 0
err_mean_existing = []

for _estim_algorithm in estim_algorithms:
    for _conf in confs:

        # class agnostic version
        
        conf.append(_conf)
        estim.append(_estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))

        if _conf == 'MCP' and (_estim_algorithm in ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']):
            novel.append('Existing Methods')
            err_mean_existing.append(diff_mean[k_option])
        else:
            novel.append('Provided by MOVAL')
        k_option += 1

        # class specific version
        if _estim_algorithm == 'AC':
            continue
        
        conf.append(_conf)
        estim.append('CS ' + _estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))
        novel.append('Provided by MOVAL')
        
        k_option += 1

conf.append('MOVAL')
estim.append('MOVAL\nEnsemble')

err_mean.append(np.log(diff_ensemb[0]))
novel.append('Provided by MOVAL')

# %%
d = {'Estimation Algorithm': estim, 'Confidence Score': conf, 'MAE': err_mean, 'Category': novel}
df = pd.DataFrame(data=d)
#
custom_order = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC', 'CS TS', 'CS DoC', 'CS ATC', 'CS TS-ATC', 'MOVAL\nEnsemble']
df['Estimation Algorithm'] = pd.Categorical(df['Estimation Algorithm'], categories=custom_order, ordered=True)
df = df.sort_values(by='Estimation Algorithm')
#
custom_order = ['MCP', 'Energy', 'Entropy', 'Doctor', 'MOVAL']
df['Confidence Score'] = pd.Categorical(df['Confidence Score'], categories=custom_order, ordered=True)
df = df.sort_values(by='Confidence Score')
#
# Map 'Confidence Score' to numerical values
confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3, 'MOVAL': 1.5}
df['Confidence Score Numeric'] = df['Confidence Score'].map(confidence_mapping)
_confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3}
#
# Map 'Confidence Score' to numerical values
estimation_mapping = {'AC': 0, 'TS': 1, 'DoC': 2, 'ATC': 3, 'TS-ATC': 4, 'CS TS': 5, 'CS DoC': 6, 'CS ATC': 7, 'CS TS-ATC': 8, 'MOVAL\nEnsemble': 9.5}
df['Estimation Algorithm Numeric'] = df['Estimation Algorithm'].map(estimation_mapping)

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.set_style("darkgrid")
category_palette = {'Existing Methods': 'grey', 'Provided by MOVAL': '#1f77b4'}
ax = sns.scatterplot(
    data=df, x="Estimation Algorithm Numeric", y="Confidence Score Numeric", hue="Category", size="MAE",
    sizes=(100, 2000), palette=category_palette
)
ax.set(ylim=(3.5, -0.5))
ax.tick_params(axis='x', rotation=20)
#
# Convert y-axis back to categorical labels
ax.set_yticks(list(_confidence_mapping.values()))
ax.set_yticklabels(list(_confidence_mapping.keys()))
# Convert y-axis back to categorical labels
ax.set_xticks(list(estimation_mapping.values()))
ax.set_xticklabels(list(estimation_mapping.keys()))
#
# Get the handles and labels from the legend
handles, labels = ax.get_legend_handles_labels()

# Create a custom legend with only desired categories
desired_labels = ['Category', 'Existing Methods', 'Provided by MOVAL', 'MAE']
desired_handles = [h for h, l in zip(handles, labels) if l in desired_labels]

# Create custom legend entries for sizes
current_method = np.min(err_mean_existing)
our_method = np.min(np.concatenate((diff_mean, diff_ensemb)))

current_method_log = np.log(current_method)
our_method_log = np.log(our_method)
min_mae = df['MAE'].min()
max_mae = df['MAE'].max()
min_size, max_size = 50, 1000

sizes_legend_small = [plt.scatter([], [], s=s, label=f'Size: {s}', color='#1f77b4') for s in [min_size + (our_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]
sizes_legend_large = [plt.scatter([], [], s=s, label=f'Size: {s}', color='grey') for s in [min_size + (current_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]

# Concatenate legend handles and labels
desired_handles = desired_handles + sizes_legend_large + sizes_legend_small
desired_labels = desired_labels + [f'Existing Best: {current_method * 100:.1f}'] + [f'MOVAL Best: {our_method * 100:.1f}']

# Create the legend with desired categories and size examples
legend = plt.legend(handles=desired_handles, labels=desired_labels, bbox_to_anchor=(1., 1.), labelspacing=1)

# Set the y-axis label
ax.set_ylabel('Confidence Score')
ax.set_xlabel('Estimation Algorithm')

top_5 = df.nsmallest(5, 'MAE')
top_n = 1
for i, point in top_5.iterrows():
    ax.annotate(
        f"Top {top_n}", 
        (point["Estimation Algorithm Numeric"], point["Confidence Score Numeric"]),
        textcoords="offset points", 
        xytext=(0,12), 
        ha='center',
        fontsize=12, 
        color='red', 
        weight='bold',
        fontstyle='italic'
    )
    top_n += 1

plt.savefig('Fig_seg2d_acc.pdf', bbox_inches='tight')

# %%
# seg2d f1
diff_mean_cardiac_syn = np.mean(np.abs(cardiac_syn_f1_res - cardiac_syn_f1_gt), axis = (0, 2, 3))
diff_ensemb_cardiac_syn = np.mean(np.abs(cardiac_syn_f1_res_ensemble - cardiac_syn_f1_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_cardiac_nat = np.mean(np.abs(cardiac_nat_f1_res - cardiac_nat_f1_gt), axis = (0, 2, 3))
diff_ensemb_cardiac_nat = np.mean(np.abs(cardiac_nat_f1_res_ensemble - cardiac_nat_f1_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean = (diff_mean_cardiac_syn + diff_mean_cardiac_nat) / 2
diff_ensemb = (diff_ensemb_cardiac_syn + diff_ensemb_cardiac_nat ) / 2

# %%
# full
confs = ['MCP', 'Energy', 'Entropy', 'Doctor']
estim_algorithms = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']

estim = []
conf = []
err_mean = []
novel = []
k_option = 0
err_mean_existing = []

for _estim_algorithm in estim_algorithms:
    for _conf in confs:

        # class agnostic version
        
        conf.append(_conf)
        estim.append(_estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))

        if _conf == 'MCP' and (_estim_algorithm in ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']):
            novel.append('Existing Methods')
            err_mean_existing.append(diff_mean[k_option])
        else:
            novel.append('Provided by MOVAL')
        k_option += 1

        # class specific version
        if _estim_algorithm == 'AC':
            continue
        
        conf.append(_conf)
        estim.append('CS ' + _estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))
        novel.append('Provided by MOVAL')
        
        k_option += 1

conf.append('MOVAL')
estim.append('MOVAL\nEnsemble')

err_mean.append(np.log(diff_ensemb[0]))
novel.append('Provided by MOVAL')

# %%
d = {'Estimation Algorithm': estim, 'Confidence Score': conf, 'MAE': err_mean, 'Category': novel}
df = pd.DataFrame(data=d)
#
custom_order = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC', 'CS TS', 'CS DoC', 'CS ATC', 'CS TS-ATC', 'MOVAL\nEnsemble']
df['Estimation Algorithm'] = pd.Categorical(df['Estimation Algorithm'], categories=custom_order, ordered=True)
df = df.sort_values(by='Estimation Algorithm')
#
custom_order = ['MCP', 'Energy', 'Entropy', 'Doctor', 'MOVAL']
df['Confidence Score'] = pd.Categorical(df['Confidence Score'], categories=custom_order, ordered=True)
df = df.sort_values(by='Confidence Score')
#
# Map 'Confidence Score' to numerical values
confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3, 'MOVAL': 1.5}
df['Confidence Score Numeric'] = df['Confidence Score'].map(confidence_mapping)
_confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3}
#
# Map 'Confidence Score' to numerical values
estimation_mapping = {'AC': 0, 'TS': 1, 'DoC': 2, 'ATC': 3, 'TS-ATC': 4, 'CS TS': 5, 'CS DoC': 6, 'CS ATC': 7, 'CS TS-ATC': 8, 'MOVAL\nEnsemble': 9.5}
df['Estimation Algorithm Numeric'] = df['Estimation Algorithm'].map(estimation_mapping)

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.set_style("darkgrid")
category_palette = {'Existing Methods': 'grey', 'Provided by MOVAL': '#1f77b4'}
ax = sns.scatterplot(
    data=df, x="Estimation Algorithm Numeric", y="Confidence Score Numeric", hue="Category", size="MAE",
    sizes=(100, 2000), palette=category_palette
)
ax.set(ylim=(3.5, -0.5))
ax.tick_params(axis='x', rotation=20)
#
# Convert y-axis back to categorical labels
ax.set_yticks(list(_confidence_mapping.values()))
ax.set_yticklabels(list(_confidence_mapping.keys()))
# Convert y-axis back to categorical labels
ax.set_xticks(list(estimation_mapping.values()))
ax.set_xticklabels(list(estimation_mapping.keys()))
#
# Get the handles and labels from the legend
handles, labels = ax.get_legend_handles_labels()

# Create a custom legend with only desired categories
desired_labels = ['Category', 'Existing Methods', 'Provided by MOVAL', 'MAE']
desired_handles = [h for h, l in zip(handles, labels) if l in desired_labels]

# Create custom legend entries for sizes
current_method = np.min(err_mean_existing)
our_method = np.min(np.concatenate((diff_mean, diff_ensemb)))

current_method_log = np.log(current_method)
our_method_log = np.log(our_method)
min_mae = df['MAE'].min()
max_mae = df['MAE'].max()
min_size, max_size = 50, 1000

sizes_legend_small = [plt.scatter([], [], s=s, label=f'Size: {s}', color='#1f77b4') for s in [min_size + (our_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]
sizes_legend_large = [plt.scatter([], [], s=s, label=f'Size: {s}', color='grey') for s in [min_size + (current_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]

# Concatenate legend handles and labels
desired_handles = desired_handles + sizes_legend_large + sizes_legend_small
desired_labels = desired_labels + [f'Existing Best: {current_method * 100:.1f}'] + [f'MOVAL Best: {our_method * 100:.1f}']

# Create the legend with desired categories and size examples
legend = plt.legend(handles=desired_handles, labels=desired_labels, bbox_to_anchor=(1., 1.), labelspacing=1)

# Set the y-axis label
ax.set_ylabel('Confidence Score')
ax.set_xlabel('Estimation Algorithm')

top_5 = df.nsmallest(5, 'MAE')
top_n = 1
for i, point in top_5.iterrows():
    ax.annotate(
        f"Top {top_n}", 
        (point["Estimation Algorithm Numeric"], point["Confidence Score Numeric"]),
        textcoords="offset points", 
        xytext=(0,12), 
        ha='center',
        fontsize=12, 
        color='red', 
        weight='bold',
        fontstyle='italic'
    )
    top_n += 1

plt.savefig('Fig_seg2d_f1.pdf', bbox_inches='tight')

# %%
print(f"existing best: {current_method * 100}, to moval {our_method * 100}")
# Out:
# existing best: 7.047459664102565, to moval 3.4387302185897433

# %%
# seg2d sens
diff_mean_cardiac_syn = np.mean(np.abs(cardiac_syn_sens_res - cardiac_syn_sens_gt), axis = (0, 2, 3))
diff_ensemb_cardiac_syn = np.mean(np.abs(cardiac_syn_sens_res_ensemble - cardiac_syn_sens_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_cardiac_nat = np.mean(np.abs(cardiac_nat_sens_res - cardiac_nat_sens_gt), axis = (0, 2, 3))
diff_ensemb_cardiac_nat = np.mean(np.abs(cardiac_nat_sens_res_ensemble - cardiac_nat_sens_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean = (diff_mean_cardiac_syn + diff_mean_cardiac_nat) / 2
diff_ensemb = (diff_ensemb_cardiac_syn + diff_ensemb_cardiac_nat ) / 2

# %%
# full
confs = ['MCP', 'Energy', 'Entropy', 'Doctor']
estim_algorithms = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']

estim = []
conf = []
err_mean = []
novel = []
k_option = 0
err_mean_existing = []

for _estim_algorithm in estim_algorithms:
    for _conf in confs:

        # class agnostic version
        
        conf.append(_conf)
        estim.append(_estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))

        if _conf == 'MCP' and (_estim_algorithm in ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']):
            novel.append('Existing Methods')
            err_mean_existing.append(diff_mean[k_option])
        else:
            novel.append('Provided by MOVAL')
        k_option += 1

        # class specific version
        if _estim_algorithm == 'AC':
            continue
        
        conf.append(_conf)
        estim.append('CS ' + _estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))
        novel.append('Provided by MOVAL')
        
        k_option += 1

conf.append('MOVAL')
estim.append('MOVAL\nEnsemble')

err_mean.append(np.log(diff_ensemb[0]))
novel.append('Provided by MOVAL')

# %%
d = {'Estimation Algorithm': estim, 'Confidence Score': conf, 'MAE': err_mean, 'Category': novel}
df = pd.DataFrame(data=d)
#
custom_order = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC', 'CS TS', 'CS DoC', 'CS ATC', 'CS TS-ATC', 'MOVAL\nEnsemble']
df['Estimation Algorithm'] = pd.Categorical(df['Estimation Algorithm'], categories=custom_order, ordered=True)
df = df.sort_values(by='Estimation Algorithm')
#
custom_order = ['MCP', 'Energy', 'Entropy', 'Doctor', 'MOVAL']
df['Confidence Score'] = pd.Categorical(df['Confidence Score'], categories=custom_order, ordered=True)
df = df.sort_values(by='Confidence Score')
#
# Map 'Confidence Score' to numerical values
confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3, 'MOVAL': 1.5}
df['Confidence Score Numeric'] = df['Confidence Score'].map(confidence_mapping)
_confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3}
#
# Map 'Confidence Score' to numerical values
estimation_mapping = {'AC': 0, 'TS': 1, 'DoC': 2, 'ATC': 3, 'TS-ATC': 4, 'CS TS': 5, 'CS DoC': 6, 'CS ATC': 7, 'CS TS-ATC': 8, 'MOVAL\nEnsemble': 9.5}
df['Estimation Algorithm Numeric'] = df['Estimation Algorithm'].map(estimation_mapping)

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.set_style("darkgrid")
category_palette = {'Existing Methods': 'grey', 'Provided by MOVAL': '#1f77b4'}
ax = sns.scatterplot(
    data=df, x="Estimation Algorithm Numeric", y="Confidence Score Numeric", hue="Category", size="MAE",
    sizes=(100, 2000), palette=category_palette
)
ax.set(ylim=(3.5, -0.5))
ax.tick_params(axis='x', rotation=20)
#
# Convert y-axis back to categorical labels
ax.set_yticks(list(_confidence_mapping.values()))
ax.set_yticklabels(list(_confidence_mapping.keys()))
# Convert y-axis back to categorical labels
ax.set_xticks(list(estimation_mapping.values()))
ax.set_xticklabels(list(estimation_mapping.keys()))
#
# Get the handles and labels from the legend
handles, labels = ax.get_legend_handles_labels()

# Create a custom legend with only desired categories
desired_labels = ['Category', 'Existing Methods', 'Provided by MOVAL', 'MAE']
desired_handles = [h for h, l in zip(handles, labels) if l in desired_labels]

# Create custom legend entries for sizes
current_method = np.min(err_mean_existing)
our_method = np.min(np.concatenate((diff_mean, diff_ensemb)))

current_method_log = np.log(current_method)
our_method_log = np.log(our_method)
min_mae = df['MAE'].min()
max_mae = df['MAE'].max()
min_size, max_size = 50, 1000

sizes_legend_small = [plt.scatter([], [], s=s, label=f'Size: {s}', color='#1f77b4') for s in [min_size + (our_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]
sizes_legend_large = [plt.scatter([], [], s=s, label=f'Size: {s}', color='grey') for s in [min_size + (current_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]

# Concatenate legend handles and labels
desired_handles = desired_handles + sizes_legend_large + sizes_legend_small
desired_labels = desired_labels + [f'Existing Best: {current_method * 100:.1f}'] + [f'MOVAL Best: {our_method * 100:.1f}']

# Create the legend with desired categories and size examples
legend = plt.legend(handles=desired_handles, labels=desired_labels, bbox_to_anchor=(1., 1.), labelspacing=1)

# Set the y-axis label
ax.set_ylabel('Confidence Score')
ax.set_xlabel('Estimation Algorithm')

top_5 = df.nsmallest(5, 'MAE')
top_n = 1
for i, point in top_5.iterrows():
    ax.annotate(
        f"Top {top_n}", 
        (point["Estimation Algorithm Numeric"], point["Confidence Score Numeric"]),
        textcoords="offset points", 
        xytext=(0,12), 
        ha='center',
        fontsize=12, 
        color='red', 
        weight='bold',
        fontstyle='italic'
    )
    top_n += 1

plt.savefig('Fig_seg2d_sens.pdf', bbox_inches='tight')

# %%
print(f"existing best: {current_method * 100}, to moval {diff_ensemb[0] * 100}")
# Out:
# existing best: 3.0733607698717935, to moval 3.087989640384614

# %%
# seg2d prec
diff_mean_cardiac_syn = np.mean(np.abs(cardiac_syn_prec_res - cardiac_syn_prec_gt), axis = (0, 2, 3))
diff_ensemb_cardiac_syn = np.mean(np.abs(cardiac_syn_prec_res_ensemble - cardiac_syn_prec_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_cardiac_nat = np.mean(np.abs(cardiac_nat_prec_res - cardiac_nat_prec_gt), axis = (0, 2, 3))
diff_ensemb_cardiac_nat = np.mean(np.abs(cardiac_nat_prec_res_ensemble - cardiac_nat_prec_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean = (diff_mean_cardiac_syn + diff_mean_cardiac_nat) / 2
diff_ensemb = (diff_ensemb_cardiac_syn + diff_ensemb_cardiac_nat ) / 2

# %%
# full
confs = ['MCP', 'Energy', 'Entropy', 'Doctor']
estim_algorithms = ['AC', 'TS', 'DoC']

estim = []
conf = []
err_mean = []
novel = []
k_option = 0
err_mean_existing = []

for _estim_algorithm in estim_algorithms:
    for _conf in confs:

        # class agnostic version
        
        conf.append(_conf)
        estim.append(_estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))

        if _conf == 'MCP' and (_estim_algorithm in ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']):
            novel.append('Existing Methods')
            err_mean_existing.append(diff_mean[k_option])
        else:
            novel.append('Provided by MOVAL')
        k_option += 1

        # class specific version
        if _estim_algorithm == 'AC':
            continue
        
        conf.append(_conf)
        estim.append('CS ' + _estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))
        novel.append('Provided by MOVAL')
        
        k_option += 1

conf.append('MOVAL')
estim.append('MOVAL\nEnsemble')

err_mean.append(np.log(diff_ensemb[0]))
novel.append('Provided by MOVAL')

# %%
d = {'Estimation Algorithm': estim, 'Confidence Score': conf, 'MAE': err_mean, 'Category': novel}
df = pd.DataFrame(data=d)
#
custom_order = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC', 'CS TS', 'CS DoC', 'CS ATC', 'CS TS-ATC', 'MOVAL\nEnsemble']
df['Estimation Algorithm'] = pd.Categorical(df['Estimation Algorithm'], categories=custom_order, ordered=True)
df = df.sort_values(by='Estimation Algorithm')
#
custom_order = ['MCP', 'Energy', 'Entropy', 'Doctor', 'MOVAL']
df['Confidence Score'] = pd.Categorical(df['Confidence Score'], categories=custom_order, ordered=True)
df = df.sort_values(by='Confidence Score')
#
# Map 'Confidence Score' to numerical values
confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3, 'MOVAL': 1.5}
df['Confidence Score Numeric'] = df['Confidence Score'].map(confidence_mapping)
_confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3}
#
# Map 'Confidence Score' to numerical values
estimation_mapping = {'AC': 0, 'TS': 1, 'DoC': 2, 'CS TS': 3, 'CS DoC': 4, 'MOVAL\nEnsemble': 5.5}
df['Estimation Algorithm Numeric'] = df['Estimation Algorithm'].map(estimation_mapping)

# %%
sns.set(rc={'figure.figsize':(3.7,3)})
sns.set_style("darkgrid")
category_palette = {'Existing Methods': 'grey', 'Provided by MOVAL': '#1f77b4'}
ax = sns.scatterplot(
    data=df, x="Estimation Algorithm Numeric", y="Confidence Score Numeric", hue="Category", size="MAE",
    sizes=(100, 2000), palette=category_palette
)
ax.set(ylim=(3.5, -0.5))
ax.tick_params(axis='x', rotation=20)
#
# Convert y-axis back to categorical labels
ax.set_yticks(list(_confidence_mapping.values()))
ax.set_yticklabels(list(_confidence_mapping.keys()))
# Convert y-axis back to categorical labels
ax.set_xticks(list(estimation_mapping.values()))
ax.set_xticklabels(list(estimation_mapping.keys()))
#
# Get the handles and labels from the legend
handles, labels = ax.get_legend_handles_labels()

# Create a custom legend with only desired categories
desired_labels = ['Category', 'Existing Methods', 'Provided by MOVAL', 'MAE']
desired_handles = [h for h, l in zip(handles, labels) if l in desired_labels]

# Create custom legend entries for sizes
current_method = np.min(err_mean_existing)
our_method = np.min(np.concatenate((diff_mean, diff_ensemb)))

current_method_log = np.log(current_method)
our_method_log = np.log(our_method)
min_mae = df['MAE'].min()
max_mae = df['MAE'].max()
min_size, max_size = 50, 1000

sizes_legend_small = [plt.scatter([], [], s=s, label=f'Size: {s}', color='#1f77b4') for s in [min_size + (our_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]
sizes_legend_large = [plt.scatter([], [], s=s, label=f'Size: {s}', color='grey') for s in [min_size + (current_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]

# Concatenate legend handles and labels
desired_handles = desired_handles + sizes_legend_large + sizes_legend_small
desired_labels = desired_labels + [f'Existing Best: {current_method * 100:.1f}'] + [f'MOVAL Best: {our_method * 100:.1f}']

# Create the legend with desired categories and size examples
legend = plt.legend(handles=desired_handles, labels=desired_labels, bbox_to_anchor=(1., 1.), labelspacing=1)

# Set the y-axis label
ax.set_ylabel('Confidence Score')
ax.set_xlabel('Estimation Algorithm')

top_5 = df.nsmallest(5, 'MAE')
top_n = 1
for i, point in top_5.iterrows():
    ax.annotate(
        f"Top {top_n}", 
        (point["Estimation Algorithm Numeric"], point["Confidence Score Numeric"]),
        textcoords="offset points", 
        xytext=(0,12), 
        ha='center',
        fontsize=12, 
        color='red', 
        weight='bold',
        fontstyle='italic'
    )
    top_n += 1

plt.savefig('Fig_seg2d_prec.pdf', bbox_inches='tight')

# %%
print(f"existing best: {current_method * 100}, to moval {diff_ensemb[0] * 100}")
# Out:
# existing best: 9.06069318974359, to moval 7.681707208974356

# %%
# seg2d auc
diff_mean_cardiac_syn = np.mean(np.abs(cardiac_syn_auc_res - cardiac_syn_auc_gt), axis = (0, 2, 3))
diff_ensemb_cardiac_syn = np.mean(np.abs(cardiac_syn_auc_res_ensemble - cardiac_syn_auc_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_cardiac_nat = np.mean(np.abs(cardiac_nat_auc_res - cardiac_nat_auc_gt), axis = (0, 2, 3))
diff_ensemb_cardiac_nat = np.mean(np.abs(cardiac_nat_auc_res_ensemble - cardiac_nat_auc_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean = (diff_mean_cardiac_syn + diff_mean_cardiac_nat) / 2
diff_ensemb = (diff_ensemb_cardiac_syn + diff_ensemb_cardiac_nat ) / 2

# %%
# full
confs = ['MCP', 'Energy', 'Entropy', 'Doctor']
estim_algorithms = ['AC', 'TS', 'DoC']

estim = []
conf = []
err_mean = []
novel = []
k_option = 0
err_mean_existing = []

for _estim_algorithm in estim_algorithms:
    for _conf in confs:

        # class agnostic version
        
        conf.append(_conf)
        estim.append(_estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))

        if _conf == 'MCP' and (_estim_algorithm in ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']):
            novel.append('Existing Methods')
            err_mean_existing.append(diff_mean[k_option])
        else:
            novel.append('Provided by MOVAL')
        k_option += 1

        # class specific version
        if _estim_algorithm == 'AC':
            continue
        
        conf.append(_conf)
        estim.append('CS ' + _estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))
        novel.append('Provided by MOVAL')
        
        k_option += 1

conf.append('MOVAL')
estim.append('MOVAL\nEnsemble')

err_mean.append(np.log(diff_ensemb[0]))
novel.append('Provided by MOVAL')

# %%
d = {'Estimation Algorithm': estim, 'Confidence Score': conf, 'MAE': err_mean, 'Category': novel}
df = pd.DataFrame(data=d)
#
custom_order = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC', 'CS TS', 'CS DoC', 'CS ATC', 'CS TS-ATC', 'MOVAL\nEnsemble']
df['Estimation Algorithm'] = pd.Categorical(df['Estimation Algorithm'], categories=custom_order, ordered=True)
df = df.sort_values(by='Estimation Algorithm')
#
custom_order = ['MCP', 'Energy', 'Entropy', 'Doctor', 'MOVAL']
df['Confidence Score'] = pd.Categorical(df['Confidence Score'], categories=custom_order, ordered=True)
df = df.sort_values(by='Confidence Score')
#
# Map 'Confidence Score' to numerical values
confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3, 'MOVAL': 1.5}
df['Confidence Score Numeric'] = df['Confidence Score'].map(confidence_mapping)
_confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3}
#
# Map 'Confidence Score' to numerical values
estimation_mapping = {'AC': 0, 'TS': 1, 'DoC': 2, 'CS TS': 3, 'CS DoC': 4, 'MOVAL\nEnsemble': 5.5}
df['Estimation Algorithm Numeric'] = df['Estimation Algorithm'].map(estimation_mapping)

# %%
sns.set(rc={'figure.figsize':(3.7,3)})
sns.set_style("darkgrid")
category_palette = {'Existing Methods': 'grey', 'Provided by MOVAL': '#1f77b4'}
ax = sns.scatterplot(
    data=df, x="Estimation Algorithm Numeric", y="Confidence Score Numeric", hue="Category", size="MAE",
    sizes=(100, 2000), palette=category_palette
)
ax.set(ylim=(3.5, -0.5))
ax.tick_params(axis='x', rotation=20)
#
# Convert y-axis back to categorical labels
ax.set_yticks(list(_confidence_mapping.values()))
ax.set_yticklabels(list(_confidence_mapping.keys()))
# Convert y-axis back to categorical labels
ax.set_xticks(list(estimation_mapping.values()))
ax.set_xticklabels(list(estimation_mapping.keys()))
#
# Get the handles and labels from the legend
handles, labels = ax.get_legend_handles_labels()

# Create a custom legend with only desired categories
desired_labels = ['Category', 'Existing Methods', 'Provided by MOVAL', 'MAE']
desired_handles = [h for h, l in zip(handles, labels) if l in desired_labels]

# Create custom legend entries for sizes
current_method = np.min(err_mean_existing)
our_method = np.min(np.concatenate((diff_mean, diff_ensemb)))

current_method_log = np.log(current_method)
our_method_log = np.log(our_method)
min_mae = df['MAE'].min()
max_mae = df['MAE'].max()
min_size, max_size = 50, 1000

sizes_legend_small = [plt.scatter([], [], s=s, label=f'Size: {s}', color='#1f77b4') for s in [min_size + (our_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]
sizes_legend_large = [plt.scatter([], [], s=s, label=f'Size: {s}', color='grey') for s in [min_size + (current_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]

# Concatenate legend handles and labels
desired_handles = desired_handles + sizes_legend_large + sizes_legend_small
desired_labels = desired_labels + [f'Existing Best: {current_method * 100:.1f}'] + [f'MOVAL Best: {our_method * 100:.1f}']

# Create the legend with desired categories and size examples
legend = plt.legend(handles=desired_handles, labels=desired_labels, bbox_to_anchor=(1., 1.), labelspacing=1)

# Set the y-axis label
ax.set_ylabel('Confidence Score')
ax.set_xlabel('Estimation Algorithm')

top_5 = df.nsmallest(5, 'MAE')
top_n = 1
for i, point in top_5.iterrows():
    ax.annotate(
        f"Top {top_n}", 
        (point["Estimation Algorithm Numeric"], point["Confidence Score Numeric"]),
        textcoords="offset points", 
        xytext=(0,12), 
        ha='center',
        fontsize=12, 
        color='red', 
        weight='bold',
        fontstyle='italic'
    )
    top_n += 1

plt.savefig('Fig_seg2d_auc.pdf', bbox_inches='tight')

# %%
# seg3d acc
diff_mean_brain_syn = np.mean(np.abs(brain_syn_acc_res - brain_syn_acc_gt), axis = (0, 2, 3))
diff_ensemb_brain_syn = np.mean(np.abs(brain_syn_acc_res_ensemble - brain_syn_acc_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_brain_nat = np.mean(np.abs(brain_nat_acc_res - brain_nat_acc_gt), axis = (0, 2, 3))
diff_ensemb_brain_nat = np.mean(np.abs(brain_nat_acc_res_ensemble - brain_nat_acc_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_pros_nat = np.mean(np.abs(prostate_nat_acc_res - prostate_nat_acc_gt), axis = (0, 2, 3))
diff_ensemb_pros_nat = np.mean(np.abs(prostate_nat_acc_res_ensemble - prostate_nat_acc_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean = (diff_mean_brain_syn + diff_mean_brain_nat + diff_mean_pros_nat) / 3
diff_ensemb = (diff_ensemb_brain_syn + diff_ensemb_brain_nat + diff_ensemb_pros_nat) / 3

# %%
# full
confs = ['MCP', 'Energy', 'Entropy', 'Doctor']
estim_algorithms = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']

estim = []
conf = []
err_mean = []
novel = []
k_option = 0
err_mean_existing = []

for _estim_algorithm in estim_algorithms:
    for _conf in confs:

        # class agnostic version
        
        conf.append(_conf)
        estim.append(_estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))

        if _conf == 'MCP' and (_estim_algorithm in ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']):
            novel.append('Existing Methods')
            err_mean_existing.append(diff_mean[k_option])
        else:
            novel.append('Provided by MOVAL')
        k_option += 1

        # class specific version
        if _estim_algorithm == 'AC':
            continue
        
        conf.append(_conf)
        estim.append('CS ' + _estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))
        novel.append('Provided by MOVAL')
        
        k_option += 1

conf.append('MOVAL')
estim.append('MOVAL\nEnsemble')

err_mean.append(np.log(diff_ensemb[0]))
novel.append('Provided by MOVAL')

# %%
d = {'Estimation Algorithm': estim, 'Confidence Score': conf, 'MAE': err_mean, 'Category': novel}
df = pd.DataFrame(data=d)
#
custom_order = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC', 'CS TS', 'CS DoC', 'CS ATC', 'CS TS-ATC', 'MOVAL\nEnsemble']
df['Estimation Algorithm'] = pd.Categorical(df['Estimation Algorithm'], categories=custom_order, ordered=True)
df = df.sort_values(by='Estimation Algorithm')
#
custom_order = ['MCP', 'Energy', 'Entropy', 'Doctor', 'MOVAL']
df['Confidence Score'] = pd.Categorical(df['Confidence Score'], categories=custom_order, ordered=True)
df = df.sort_values(by='Confidence Score')
#
# Map 'Confidence Score' to numerical values
confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3, 'MOVAL': 1.5}
df['Confidence Score Numeric'] = df['Confidence Score'].map(confidence_mapping)
_confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3}
#
# Map 'Confidence Score' to numerical values
estimation_mapping = {'AC': 0, 'TS': 1, 'DoC': 2, 'ATC': 3, 'TS-ATC': 4, 'CS TS': 5, 'CS DoC': 6, 'CS ATC': 7, 'CS TS-ATC': 8, 'MOVAL\nEnsemble': 9.5}
df['Estimation Algorithm Numeric'] = df['Estimation Algorithm'].map(estimation_mapping)

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.set_style("darkgrid")
category_palette = {'Existing Methods': 'grey', 'Provided by MOVAL': '#1f77b4'}
ax = sns.scatterplot(
    data=df, x="Estimation Algorithm Numeric", y="Confidence Score Numeric", hue="Category", size="MAE",
    sizes=(100, 2000), palette=category_palette
)
ax.set(ylim=(3.5, -0.5))
ax.tick_params(axis='x', rotation=20)
#
# Convert y-axis back to categorical labels
ax.set_yticks(list(_confidence_mapping.values()))
ax.set_yticklabels(list(_confidence_mapping.keys()))
# Convert y-axis back to categorical labels
ax.set_xticks(list(estimation_mapping.values()))
ax.set_xticklabels(list(estimation_mapping.keys()))
#
# Get the handles and labels from the legend
handles, labels = ax.get_legend_handles_labels()

# Create a custom legend with only desired categories
desired_labels = ['Category', 'Existing Methods', 'Provided by MOVAL', 'MAE']
desired_handles = [h for h, l in zip(handles, labels) if l in desired_labels]

# Create custom legend entries for sizes
current_method = np.min(err_mean_existing)
our_method = np.min(np.concatenate((diff_mean, diff_ensemb)))

current_method_log = np.log(current_method)
our_method_log = np.log(our_method)
min_mae = df['MAE'].min()
max_mae = df['MAE'].max()
min_size, max_size = 50, 1000

sizes_legend_small = [plt.scatter([], [], s=s, label=f'Size: {s}', color='#1f77b4') for s in [min_size + (our_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]
sizes_legend_large = [plt.scatter([], [], s=s, label=f'Size: {s}', color='grey') for s in [min_size + (current_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]

# Concatenate legend handles and labels
desired_handles = desired_handles + sizes_legend_large + sizes_legend_small
desired_labels = desired_labels + [f'Existing Best: {current_method * 100:.1f}'] + [f'MOVAL Best: {our_method * 100:.1f}']

# Create the legend with desired categories and size examples
legend = plt.legend(handles=desired_handles, labels=desired_labels, bbox_to_anchor=(1., 1.), labelspacing=1)

# Set the y-axis label
ax.set_ylabel('Confidence Score')
ax.set_xlabel('Estimation Algorithm')

top_5 = df.nsmallest(5, 'MAE')
top_n = 1
for i, point in top_5.iterrows():
    ax.annotate(
        f"Top {top_n}", 
        (point["Estimation Algorithm Numeric"], point["Confidence Score Numeric"]),
        textcoords="offset points", 
        xytext=(0,12), 
        ha='center',
        fontsize=12, 
        color='red', 
        weight='bold',
        fontstyle='italic'
    )
    top_n += 1

plt.savefig('Fig_seg3d_acc.pdf', bbox_inches='tight')

# %%
# seg3d f1
diff_mean_brain_syn = np.mean(np.abs(brain_syn_f1_res - brain_syn_f1_gt), axis = (0, 2, 3))
diff_ensemb_brain_syn = np.mean(np.abs(brain_syn_f1_res_ensemble - brain_syn_f1_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_brain_nat = np.mean(np.abs(brain_nat_f1_res - brain_nat_f1_gt), axis = (0, 2, 3))
diff_ensemb_brain_nat = np.mean(np.abs(brain_nat_f1_res_ensemble - brain_nat_f1_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_pros_syn = np.mean(np.abs(prostate_syn_f1_res - prostate_syn_f1_gt), axis = (0, 2, 3))
diff_ensemb_pros_syn = np.mean(np.abs(prostate_syn_f1_res_ensemble - prostate_syn_f1_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_pros_nat = np.mean(np.abs(prostate_nat_f1_res - prostate_nat_f1_gt), axis = (0, 2, 3))
diff_ensemb_pros_nat = np.mean(np.abs(prostate_nat_f1_res_ensemble - prostate_nat_f1_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean = (diff_mean_brain_syn + diff_mean_brain_nat + diff_mean_pros_nat + diff_mean_pros_syn) / 4
diff_ensemb = (diff_ensemb_brain_syn + diff_ensemb_brain_nat + diff_ensemb_pros_nat + diff_ensemb_pros_syn) / 4

# %%
# full
confs = ['MCP', 'Energy', 'Entropy', 'Doctor']
estim_algorithms = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']

estim = []
conf = []
err_mean = []
novel = []
k_option = 0
err_mean_existing = []

for _estim_algorithm in estim_algorithms:
    for _conf in confs:

        # class agnostic version
        
        conf.append(_conf)
        estim.append(_estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))

        if _conf == 'MCP' and (_estim_algorithm in ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']):
            novel.append('Existing Methods')
            err_mean_existing.append(diff_mean[k_option])
        else:
            novel.append('Provided by MOVAL')
        k_option += 1

        # class specific version
        if _estim_algorithm == 'AC':
            continue
        
        conf.append(_conf)
        estim.append('CS ' + _estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))
        novel.append('Provided by MOVAL')
        
        k_option += 1

conf.append('MOVAL')
estim.append('MOVAL\nEnsemble')

err_mean.append(np.log(diff_ensemb[0]))
novel.append('Provided by MOVAL')

# %%
d = {'Estimation Algorithm': estim, 'Confidence Score': conf, 'MAE': err_mean, 'Category': novel}
df = pd.DataFrame(data=d)
#
custom_order = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC', 'CS TS', 'CS DoC', 'CS ATC', 'CS TS-ATC', 'MOVAL\nEnsemble']
df['Estimation Algorithm'] = pd.Categorical(df['Estimation Algorithm'], categories=custom_order, ordered=True)
df = df.sort_values(by='Estimation Algorithm')
#
custom_order = ['MCP', 'Energy', 'Entropy', 'Doctor', 'MOVAL']
df['Confidence Score'] = pd.Categorical(df['Confidence Score'], categories=custom_order, ordered=True)
df = df.sort_values(by='Confidence Score')
#
# Map 'Confidence Score' to numerical values
confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3, 'MOVAL': 1.5}
df['Confidence Score Numeric'] = df['Confidence Score'].map(confidence_mapping)
_confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3}
#
# Map 'Confidence Score' to numerical values
estimation_mapping = {'AC': 0, 'TS': 1, 'DoC': 2, 'ATC': 3, 'TS-ATC': 4, 'CS TS': 5, 'CS DoC': 6, 'CS ATC': 7, 'CS TS-ATC': 8, 'MOVAL\nEnsemble': 9.5}
df['Estimation Algorithm Numeric'] = df['Estimation Algorithm'].map(estimation_mapping)

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.set_style("darkgrid")
category_palette = {'Existing Methods': 'grey', 'Provided by MOVAL': '#1f77b4'}
ax = sns.scatterplot(
    data=df, x="Estimation Algorithm Numeric", y="Confidence Score Numeric", hue="Category", size="MAE",
    sizes=(100, 2000), palette=category_palette
)
ax.set(ylim=(3.5, -0.5))
ax.tick_params(axis='x', rotation=20)
#
# Convert y-axis back to categorical labels
ax.set_yticks(list(_confidence_mapping.values()))
ax.set_yticklabels(list(_confidence_mapping.keys()))
# Convert y-axis back to categorical labels
ax.set_xticks(list(estimation_mapping.values()))
ax.set_xticklabels(list(estimation_mapping.keys()))
#
# Get the handles and labels from the legend
handles, labels = ax.get_legend_handles_labels()

# Create a custom legend with only desired categories
desired_labels = ['Category', 'Existing Methods', 'Provided by MOVAL', 'MAE']
desired_handles = [h for h, l in zip(handles, labels) if l in desired_labels]

# Create custom legend entries for sizes
current_method = np.min(err_mean_existing)
our_method = np.min(np.concatenate((diff_mean, diff_ensemb)))

current_method_log = np.log(current_method)
our_method_log = np.log(our_method)
min_mae = df['MAE'].min()
max_mae = df['MAE'].max()
min_size, max_size = 50, 1000

sizes_legend_small = [plt.scatter([], [], s=s, label=f'Size: {s}', color='#1f77b4') for s in [min_size + (our_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]
sizes_legend_large = [plt.scatter([], [], s=s, label=f'Size: {s}', color='grey') for s in [min_size + (current_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]

# Concatenate legend handles and labels
desired_handles = desired_handles + sizes_legend_large + sizes_legend_small
desired_labels = desired_labels + [f'Existing Best: {current_method * 100:.1f}'] + [f'MOVAL Best: {our_method * 100:.1f}']

# Create the legend with desired categories and size examples
legend = plt.legend(handles=desired_handles, labels=desired_labels, bbox_to_anchor=(1., 1.), labelspacing=1)

# Set the y-axis label
ax.set_ylabel('Confidence Score')
ax.set_xlabel('Estimation Algorithm')

top_5 = df.nsmallest(5, 'MAE')
top_n = 1
for i, point in top_5.iterrows():
    ax.annotate(
        f"Top {top_n}", 
        (point["Estimation Algorithm Numeric"], point["Confidence Score Numeric"]),
        textcoords="offset points", 
        xytext=(0,12), 
        ha='center',
        fontsize=12, 
        color='red', 
        weight='bold',
        fontstyle='italic'
    )
    top_n += 1

plt.savefig('Fig_seg3d_f1.pdf', bbox_inches='tight')

# %%
print(f"existing best: {current_method * 100}, to moval {diff_ensemb[0] * 100}")
# Out:
# existing best: 16.133704442821287, to moval 7.736017057831325

# %%
# seg3d sens
diff_mean_brain_syn = np.mean(np.abs(brain_syn_sens_res - brain_syn_sens_gt), axis = (0, 2, 3))
diff_ensemb_brain_syn = np.mean(np.abs(brain_syn_sens_res_ensemble - brain_syn_sens_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_brain_nat = np.mean(np.abs(brain_nat_sens_res - brain_nat_sens_gt), axis = (0, 2, 3))
diff_ensemb_brain_nat = np.mean(np.abs(brain_nat_sens_res_ensemble - brain_nat_sens_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_pros_syn = np.mean(np.abs(prostate_syn_sens_res - prostate_syn_sens_gt), axis = (0, 2, 3))
diff_ensemb_pros_syn = np.mean(np.abs(prostate_syn_sens_res_ensemble - prostate_syn_sens_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_pros_nat = np.mean(np.abs(prostate_nat_sens_res - prostate_nat_sens_gt), axis = (0, 2, 3))
diff_ensemb_pros_nat = np.mean(np.abs(prostate_nat_sens_res_ensemble - prostate_nat_sens_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean = (diff_mean_brain_syn + diff_mean_brain_nat + diff_mean_pros_nat + diff_mean_pros_syn) / 4
diff_ensemb = (diff_ensemb_brain_syn + diff_ensemb_brain_nat + diff_ensemb_pros_nat + diff_ensemb_pros_syn) / 4

# %%
# full
confs = ['MCP', 'Energy', 'Entropy', 'Doctor']
estim_algorithms = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']

estim = []
conf = []
err_mean = []
novel = []
k_option = 0
err_mean_existing = []

for _estim_algorithm in estim_algorithms:
    for _conf in confs:

        # class agnostic version
        
        conf.append(_conf)
        estim.append(_estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))

        if _conf == 'MCP' and (_estim_algorithm in ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']):
            novel.append('Existing Methods')
            err_mean_existing.append(diff_mean[k_option])
        else:
            novel.append('Provided by MOVAL')
        k_option += 1

        # class specific version
        if _estim_algorithm == 'AC':
            continue
        
        conf.append(_conf)
        estim.append('CS ' + _estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))
        novel.append('Provided by MOVAL')
        
        k_option += 1

conf.append('MOVAL')
estim.append('MOVAL\nEnsemble')

err_mean.append(np.log(diff_ensemb[0]))
novel.append('Provided by MOVAL')

# %%
d = {'Estimation Algorithm': estim, 'Confidence Score': conf, 'MAE': err_mean, 'Category': novel}
df = pd.DataFrame(data=d)
#
custom_order = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC', 'CS TS', 'CS DoC', 'CS ATC', 'CS TS-ATC', 'MOVAL\nEnsemble']
df['Estimation Algorithm'] = pd.Categorical(df['Estimation Algorithm'], categories=custom_order, ordered=True)
df = df.sort_values(by='Estimation Algorithm')
#
custom_order = ['MCP', 'Energy', 'Entropy', 'Doctor', 'MOVAL']
df['Confidence Score'] = pd.Categorical(df['Confidence Score'], categories=custom_order, ordered=True)
df = df.sort_values(by='Confidence Score')
#
# Map 'Confidence Score' to numerical values
confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3, 'MOVAL': 1.5}
df['Confidence Score Numeric'] = df['Confidence Score'].map(confidence_mapping)
_confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3}
#
# Map 'Confidence Score' to numerical values
estimation_mapping = {'AC': 0, 'TS': 1, 'DoC': 2, 'ATC': 3, 'TS-ATC': 4, 'CS TS': 5, 'CS DoC': 6, 'CS ATC': 7, 'CS TS-ATC': 8, 'MOVAL\nEnsemble': 9.5}
df['Estimation Algorithm Numeric'] = df['Estimation Algorithm'].map(estimation_mapping)

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.set_style("darkgrid")
category_palette = {'Existing Methods': 'grey', 'Provided by MOVAL': '#1f77b4'}
ax = sns.scatterplot(
    data=df, x="Estimation Algorithm Numeric", y="Confidence Score Numeric", hue="Category", size="MAE",
    sizes=(100, 2000), palette=category_palette
)
ax.set(ylim=(3.5, -0.5))
ax.tick_params(axis='x', rotation=20)
#
# Convert y-axis back to categorical labels
ax.set_yticks(list(_confidence_mapping.values()))
ax.set_yticklabels(list(_confidence_mapping.keys()))
# Convert y-axis back to categorical labels
ax.set_xticks(list(estimation_mapping.values()))
ax.set_xticklabels(list(estimation_mapping.keys()))
#
# Get the handles and labels from the legend
handles, labels = ax.get_legend_handles_labels()

# Create a custom legend with only desired categories
desired_labels = ['Category', 'Existing Methods', 'Provided by MOVAL', 'MAE']
desired_handles = [h for h, l in zip(handles, labels) if l in desired_labels]

# Create custom legend entries for sizes
current_method = np.min(err_mean_existing)
our_method = np.min(np.concatenate((diff_mean, diff_ensemb)))

current_method_log = np.log(current_method)
our_method_log = np.log(our_method)
min_mae = df['MAE'].min()
max_mae = df['MAE'].max()
min_size, max_size = 50, 1000

sizes_legend_small = [plt.scatter([], [], s=s, label=f'Size: {s}', color='#1f77b4') for s in [min_size + (our_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]
sizes_legend_large = [plt.scatter([], [], s=s, label=f'Size: {s}', color='grey') for s in [min_size + (current_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]

# Concatenate legend handles and labels
desired_handles = desired_handles + sizes_legend_large + sizes_legend_small
desired_labels = desired_labels + [f'Existing Best: {current_method * 100:.1f}'] + [f'MOVAL Best: {our_method * 100:.1f}']

# Create the legend with desired categories and size examples
legend = plt.legend(handles=desired_handles, labels=desired_labels, bbox_to_anchor=(1., 1.), labelspacing=1)

# Set the y-axis label
ax.set_ylabel('Confidence Score')
ax.set_xlabel('Estimation Algorithm')

top_5 = df.nsmallest(5, 'MAE')
top_n = 1
for i, point in top_5.iterrows():
    ax.annotate(
        f"Top {top_n}", 
        (point["Estimation Algorithm Numeric"], point["Confidence Score Numeric"]),
        textcoords="offset points", 
        xytext=(0,12), 
        ha='center',
        fontsize=12, 
        color='red', 
        weight='bold',
        fontstyle='italic'
    )
    top_n += 1

plt.savefig('Fig_seg3d_sens.pdf', bbox_inches='tight')

# %%
print(f"existing best: {current_method * 100}, to moval {diff_ensemb[0] * 100}")
# Out:
# existing best: 14.763344624598396, to moval 10.432021408985943

# %%
# seg3d prec
diff_mean_brain_syn = np.mean(np.abs(brain_syn_prec_res - brain_syn_prec_gt), axis = (0, 2, 3))
diff_ensemb_brain_syn = np.mean(np.abs(brain_syn_prec_res_ensemble - brain_syn_prec_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_brain_nat = np.mean(np.abs(brain_nat_prec_res - brain_nat_prec_gt), axis = (0, 2, 3))
diff_ensemb_brain_nat = np.mean(np.abs(brain_nat_prec_res_ensemble - brain_nat_prec_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_pros_syn = np.mean(np.abs(prostate_syn_prec_res - prostate_syn_prec_gt), axis = (0, 2, 3))
diff_ensemb_pros_syn = np.mean(np.abs(prostate_syn_prec_res_ensemble - prostate_syn_prec_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_pros_nat = np.mean(np.abs(prostate_nat_prec_res - prostate_nat_prec_gt), axis = (0, 2, 3))
diff_ensemb_pros_nat = np.mean(np.abs(prostate_nat_prec_res_ensemble - prostate_nat_prec_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean = (diff_mean_brain_syn + diff_mean_brain_nat + diff_mean_pros_nat + diff_mean_pros_syn) / 4
diff_ensemb = (diff_ensemb_brain_syn + diff_ensemb_brain_nat + diff_ensemb_pros_nat + diff_ensemb_pros_syn) / 4

# %%
# full
confs = ['MCP', 'Energy', 'Entropy', 'Doctor']
estim_algorithms = ['AC', 'TS', 'DoC']

estim = []
conf = []
err_mean = []
novel = []
k_option = 0
err_mean_existing = []

for _estim_algorithm in estim_algorithms:
    for _conf in confs:

        # class agnostic version
        
        conf.append(_conf)
        estim.append(_estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))

        if _conf == 'MCP' and (_estim_algorithm in ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']):
            novel.append('Existing Methods')
            err_mean_existing.append(diff_mean[k_option])
        else:
            novel.append('Provided by MOVAL')
        k_option += 1

        # class specific version
        if _estim_algorithm == 'AC':
            continue
        
        conf.append(_conf)
        estim.append('CS ' + _estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))
        novel.append('Provided by MOVAL')
        
        k_option += 1

conf.append('MOVAL')
estim.append('MOVAL\nEnsemble')

err_mean.append(np.log(diff_ensemb[0]))
novel.append('Provided by MOVAL')

# %%
d = {'Estimation Algorithm': estim, 'Confidence Score': conf, 'MAE': err_mean, 'Category': novel}
df = pd.DataFrame(data=d)
#
custom_order = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC', 'CS TS', 'CS DoC', 'CS ATC', 'CS TS-ATC', 'MOVAL\nEnsemble']
df['Estimation Algorithm'] = pd.Categorical(df['Estimation Algorithm'], categories=custom_order, ordered=True)
df = df.sort_values(by='Estimation Algorithm')
#
custom_order = ['MCP', 'Energy', 'Entropy', 'Doctor', 'MOVAL']
df['Confidence Score'] = pd.Categorical(df['Confidence Score'], categories=custom_order, ordered=True)
df = df.sort_values(by='Confidence Score')
#
# Map 'Confidence Score' to numerical values
confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3, 'MOVAL': 1.5}
df['Confidence Score Numeric'] = df['Confidence Score'].map(confidence_mapping)
_confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3}
#
# Map 'Confidence Score' to numerical values
estimation_mapping = {'AC': 0, 'TS': 1, 'DoC': 2, 'CS TS': 3, 'CS DoC': 4, 'MOVAL\nEnsemble': 5.5}
df['Estimation Algorithm Numeric'] = df['Estimation Algorithm'].map(estimation_mapping)

# %%
sns.set(rc={'figure.figsize':(3.7,3)})
sns.set_style("darkgrid")
category_palette = {'Existing Methods': 'grey', 'Provided by MOVAL': '#1f77b4'}
ax = sns.scatterplot(
    data=df, x="Estimation Algorithm Numeric", y="Confidence Score Numeric", hue="Category", size="MAE",
    sizes=(100, 2000), palette=category_palette
)
ax.set(ylim=(3.5, -0.5))
ax.tick_params(axis='x', rotation=20)
#
# Convert y-axis back to categorical labels
ax.set_yticks(list(_confidence_mapping.values()))
ax.set_yticklabels(list(_confidence_mapping.keys()))
# Convert y-axis back to categorical labels
ax.set_xticks(list(estimation_mapping.values()))
ax.set_xticklabels(list(estimation_mapping.keys()))
#
# Get the handles and labels from the legend
handles, labels = ax.get_legend_handles_labels()

# Create a custom legend with only desired categories
desired_labels = ['Category', 'Existing Methods', 'Provided by MOVAL', 'MAE']
desired_handles = [h for h, l in zip(handles, labels) if l in desired_labels]

# Create custom legend entries for sizes
current_method = np.min(err_mean_existing)
our_method = np.min(np.concatenate((diff_mean, diff_ensemb)))

current_method_log = np.log(current_method)
our_method_log = np.log(our_method)
min_mae = df['MAE'].min()
max_mae = df['MAE'].max()
min_size, max_size = 50, 1000

sizes_legend_small = [plt.scatter([], [], s=s, label=f'Size: {s}', color='#1f77b4') for s in [min_size + (our_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]
sizes_legend_large = [plt.scatter([], [], s=s, label=f'Size: {s}', color='grey') for s in [min_size + (current_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]

# Concatenate legend handles and labels
desired_handles = desired_handles + sizes_legend_large + sizes_legend_small
desired_labels = desired_labels + [f'Existing Best: {current_method * 100:.1f}'] + [f'MOVAL Best: {our_method * 100:.1f}']

# Create the legend with desired categories and size examples
legend = plt.legend(handles=desired_handles, labels=desired_labels, bbox_to_anchor=(1., 1.), labelspacing=1)

# Set the y-axis label
ax.set_ylabel('Confidence Score')
ax.set_xlabel('Estimation Algorithm')

top_5 = df.nsmallest(5, 'MAE')
top_n = 1
for i, point in top_5.iterrows():
    ax.annotate(
        f"Top {top_n}", 
        (point["Estimation Algorithm Numeric"], point["Confidence Score Numeric"]),
        textcoords="offset points", 
        xytext=(0,12), 
        ha='center',
        fontsize=12, 
        color='red', 
        weight='bold',
        fontstyle='italic'
    )
    top_n += 1

plt.savefig('Fig_seg3d_prec.pdf', bbox_inches='tight')

# %%
print(f"existing best: {current_method * 100}, to moval {diff_ensemb[0] * 100}")
# Out:
# existing best: 9.089806025451805, to moval 5.124473714708835

# %%
# seg3d auc
diff_mean_brain_syn = np.mean(np.abs(brain_syn_auc_res - brain_syn_auc_gt), axis = (0, 2, 3))
diff_ensemb_brain_syn = np.mean(np.abs(brain_syn_auc_res_ensemble - brain_syn_auc_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_brain_nat = np.mean(np.abs(brain_nat_auc_res - brain_nat_auc_gt), axis = (0, 2, 3))
diff_ensemb_brain_nat = np.mean(np.abs(brain_nat_auc_res_ensemble - brain_nat_auc_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_pros_syn = np.mean(np.abs(prostate_syn_auc_res - prostate_syn_auc_gt), axis = (0, 2, 3))
diff_ensemb_pros_syn = np.mean(np.abs(prostate_syn_auc_res_ensemble - prostate_syn_auc_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean_pros_nat = np.mean(np.abs(prostate_nat_auc_res - prostate_nat_auc_gt), axis = (0, 2, 3))
diff_ensemb_pros_nat = np.mean(np.abs(prostate_nat_auc_res_ensemble - prostate_nat_auc_gt[:, 0:1, :, :]), axis = (0, 2, 3))
#
diff_mean = (diff_mean_brain_syn + diff_mean_brain_nat + diff_mean_pros_nat + diff_mean_pros_syn) / 4
diff_ensemb = (diff_ensemb_brain_syn + diff_ensemb_brain_nat + diff_ensemb_pros_nat + diff_ensemb_pros_syn) / 4

# %%
# full
confs = ['MCP', 'Energy', 'Entropy', 'Doctor']
estim_algorithms = ['AC', 'TS', 'DoC']

estim = []
conf = []
err_mean = []
novel = []
k_option = 0
err_mean_existing = []

for _estim_algorithm in estim_algorithms:
    for _conf in confs:

        # class agnostic version
        
        conf.append(_conf)
        estim.append(_estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))

        if _conf == 'MCP' and (_estim_algorithm in ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC']):
            novel.append('Existing Methods')
            err_mean_existing.append(diff_mean[k_option])
        else:
            novel.append('Provided by MOVAL')
        k_option += 1

        # class specific version
        if _estim_algorithm == 'AC':
            continue
        
        conf.append(_conf)
        estim.append('CS ' + _estim_algorithm)

        err_mean.append(np.log(diff_mean[k_option]))
        novel.append('Provided by MOVAL')
        
        k_option += 1

conf.append('MOVAL')
estim.append('MOVAL\nEnsemble')

err_mean.append(np.log(diff_ensemb[0]))
novel.append('Provided by MOVAL')

# %%
d = {'Estimation Algorithm': estim, 'Confidence Score': conf, 'MAE': err_mean, 'Category': novel}
df = pd.DataFrame(data=d)
#
custom_order = ['AC', 'TS', 'DoC', 'ATC', 'TS-ATC', 'CS TS', 'CS DoC', 'CS ATC', 'CS TS-ATC', 'MOVAL\nEnsemble']
df['Estimation Algorithm'] = pd.Categorical(df['Estimation Algorithm'], categories=custom_order, ordered=True)
df = df.sort_values(by='Estimation Algorithm')
#
custom_order = ['MCP', 'Energy', 'Entropy', 'Doctor', 'MOVAL']
df['Confidence Score'] = pd.Categorical(df['Confidence Score'], categories=custom_order, ordered=True)
df = df.sort_values(by='Confidence Score')
#
# Map 'Confidence Score' to numerical values
confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3, 'MOVAL': 1.5}
df['Confidence Score Numeric'] = df['Confidence Score'].map(confidence_mapping)
_confidence_mapping = {'MCP': 0, 'Energy': 1, 'Entropy': 2, 'Doctor': 3}
#
# Map 'Confidence Score' to numerical values
estimation_mapping = {'AC': 0, 'TS': 1, 'DoC': 2, 'CS TS': 3, 'CS DoC': 4, 'MOVAL\nEnsemble': 5.5}
df['Estimation Algorithm Numeric'] = df['Estimation Algorithm'].map(estimation_mapping)

# %%
sns.set(rc={'figure.figsize':(3.7,3)})
sns.set_style("darkgrid")
category_palette = {'Existing Methods': 'grey', 'Provided by MOVAL': '#1f77b4'}
ax = sns.scatterplot(
    data=df, x="Estimation Algorithm Numeric", y="Confidence Score Numeric", hue="Category", size="MAE",
    sizes=(100, 2000), palette=category_palette
)
ax.set(ylim=(3.5, -0.5))
ax.tick_params(axis='x', rotation=20)
#
# Convert y-axis back to categorical labels
ax.set_yticks(list(_confidence_mapping.values()))
ax.set_yticklabels(list(_confidence_mapping.keys()))
# Convert y-axis back to categorical labels
ax.set_xticks(list(estimation_mapping.values()))
ax.set_xticklabels(list(estimation_mapping.keys()))
#
# Get the handles and labels from the legend
handles, labels = ax.get_legend_handles_labels()

# Create a custom legend with only desired categories
desired_labels = ['Category', 'Existing Methods', 'Provided by MOVAL', 'MAE']
desired_handles = [h for h, l in zip(handles, labels) if l in desired_labels]

# Create custom legend entries for sizes
current_method = np.min(err_mean_existing)
our_method = np.min(np.concatenate((diff_mean, diff_ensemb)))

current_method_log = np.log(current_method)
our_method_log = np.log(our_method)
min_mae = df['MAE'].min()
max_mae = df['MAE'].max()
min_size, max_size = 50, 1000

sizes_legend_small = [plt.scatter([], [], s=s, label=f'Size: {s}', color='#1f77b4') for s in [min_size + (our_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]
sizes_legend_large = [plt.scatter([], [], s=s, label=f'Size: {s}', color='grey') for s in [min_size + (current_method_log - min_mae) / (max_mae - min_mae) * (max_size - min_size)]]

# Concatenate legend handles and labels
desired_handles = desired_handles + sizes_legend_large + sizes_legend_small
desired_labels = desired_labels + [f'Existing Best: {current_method * 100:.1f}'] + [f'MOVAL Best: {our_method * 100:.1f}']

# Create the legend with desired categories and size examples
legend = plt.legend(handles=desired_handles, labels=desired_labels, bbox_to_anchor=(1., 1.), labelspacing=1)

# Set the y-axis label
ax.set_ylabel('Confidence Score')
ax.set_xlabel('Estimation Algorithm')

top_5 = df.nsmallest(5, 'MAE')
top_n = 1
for i, point in top_5.iterrows():
    ax.annotate(
        f"Top {top_n}", 
        (point["Estimation Algorithm Numeric"], point["Confidence Score Numeric"]),
        textcoords="offset points", 
        xytext=(0,12), 
        ha='center',
        fontsize=12, 
        color='red', 
        weight='bold',
        fontstyle='italic'
    )
    top_n += 1

plt.savefig('Fig_seg3d_auc.pdf', bbox_inches='tight')
