# %%
# !pip install moval
# !pip install statannotations
# !pip install pandas
# !pip install tqdm
# !pip install matplotlib
# !pip install seaborn==0.12 # because statannotations not support the latest
# Out:
# ...
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.0
#     Uninstalling seaborn-0.12.0:
#       Successfully uninstalled seaborn-0.12.0
# ...
#   Using cached seaborn-0.12.0-py3-none-any.whl (285 kB)
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# statannotations 0.6.0 requires seaborn<0.12,>=0.9.0, but you have seaborn 0.12.0 which is incompatible.
# ...

# %%
import os
import gdown
import itertools
import zipfile
import random
import pandas as pd
import numpy as np
import moval
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
from statannotations.Annotator import Annotator

# %%
print(f"The installed MOVAL verision is {moval.__version__}")
print(f"The installed seaborn verision is {sns.__version__}")
# Out:
# The installed MOVAL verision is 0.2.5
# The installed seaborn verision is 0.12.0

# %%
# cls, acc

# %%
import numpy as np

# cls, all conditions (95 + 95 + 7)
with open('cls_acc.npy', 'rb') as f:
    cifar10_acc_res = np.load(f) * 100
    cifar10_acc_gt = np.load(f) * 100
    cifar10_acc_res_ensemble = np.load(f) * 100
    cifar100_acc_res = np.load(f) * 100
    cifar100_acc_gt = np.load(f) * 100
    cifar100_acc_res_ensemble = np.load(f) * 100
    skin_acc_res = np.load(f) * 100
    skin_acc_gt = np.load(f) * 100
    skin_acc_res_ensemble = np.load(f) * 100

with open('cls_sens.npy', 'rb') as f:
    cifar10_sens_res = np.load(f) * 100
    cifar10_sens_gt = np.load(f) * 100
    cifar10_sens_res_ensemble = np.load(f) * 100
    cifar100_sens_res = np.load(f) * 100
    cifar100_sens_gt = np.load(f) * 100
    cifar100_sens_res_ensemble = np.load(f) * 100
    skin_sens_res = np.load(f) * 100
    skin_sens_gt = np.load(f) * 100
    skin_sens_res_ensemble = np.load(f) * 100

with open('cls_prec.npy', 'rb') as f:
    cifar10_prec_res = np.load(f) * 100
    cifar10_prec_gt = np.load(f) * 100
    cifar10_prec_res_ensemble = np.load(f) * 100
    cifar100_prec_res = np.load(f) * 100
    cifar100_prec_gt = np.load(f) * 100
    cifar100_prec_res_ensemble = np.load(f) * 100
    skin_prec_res = np.load(f) * 100
    skin_prec_gt = np.load(f) * 100
    skin_prec_res_ensemble = np.load(f) * 100

with open('cls_f1.npy', 'rb') as f:
    cifar10_f1_res = np.load(f) * 100
    cifar10_f1_gt = np.load(f) * 100
    cifar10_f1_res_ensemble = np.load(f) * 100
    cifar100_f1_res = np.load(f) * 100
    cifar100_f1_gt = np.load(f) * 100
    cifar100_f1_res_ensemble = np.load(f) * 100
    skin_f1_res = np.load(f) * 100
    skin_f1_gt = np.load(f) * 100
    skin_f1_res_ensemble = np.load(f) * 100

with open('cls_auc.npy', 'rb') as f:
    cifar10_auc_res = np.load(f) * 100
    cifar10_auc_gt = np.load(f) * 100
    cifar10_auc_res_ensemble = np.load(f) * 100
    cifar100_auc_res = np.load(f) * 100
    cifar100_auc_gt = np.load(f) * 100
    cifar100_auc_res_ensemble = np.load(f) * 100
    skin_auc_res = np.load(f) * 100
    skin_auc_gt = np.load(f) * 100
    skin_auc_res_ensemble = np.load(f) * 100

with open('cls_conds_f1.npy', 'rb') as f:
    cifar10ci1_f1_res = np.load(f) * 100
    cifar10ci1_f1_gt = np.load(f) * 100
    cifar10ci1_f1_res_ensemble = np.load(f) * 100
    cifar10ci2_f1_res = np.load(f) * 100
    cifar10ci2_f1_gt = np.load(f) * 100
    cifar10ci2_f1_res_ensemble = np.load(f) * 100
    cifar10rl1_f1_res = np.load(f) * 100
    cifar10rl1_f1_gt = np.load(f) * 100
    cifar10rl1_f1_res_ensemble = np.load(f) * 100
    cifar10rl2_f1_res = np.load(f) * 100
    cifar10rl2_f1_gt = np.load(f) * 100
    cifar10rl2_f1_res_ensemble = np.load(f) * 100

# %%
import numpy as np

# seg2d, all conditions (65 + 4)
with open('seg2d_acc.npy', 'rb') as f:
    cardiac_syn_acc_res = np.load(f) * 100
    cardiac_syn_acc_gt = np.load(f) * 100
    cardiac_syn_acc_res_ensemble = np.load(f) * 100
    cardiac_nat_acc_res = np.load(f) * 100
    cardiac_nat_acc_gt = np.load(f) * 100
    cardiac_nat_acc_res_ensemble = np.load(f) * 100

with open('seg2d_sens.npy', 'rb') as f:
    cardiac_syn_sens_res = np.load(f) * 100
    cardiac_syn_sens_gt = np.load(f) * 100
    cardiac_syn_sens_res_ensemble = np.load(f) * 100
    cardiac_nat_sens_res = np.load(f) * 100
    cardiac_nat_sens_gt = np.load(f) * 100
    cardiac_nat_sens_res_ensemble = np.load(f) * 100

with open('seg2d_prec.npy', 'rb') as f:
    cardiac_syn_prec_res = np.load(f) * 100
    cardiac_syn_prec_gt = np.load(f) * 100
    cardiac_syn_prec_res_ensemble = np.load(f) * 100
    cardiac_nat_prec_res = np.load(f) * 100
    cardiac_nat_prec_gt = np.load(f) * 100
    cardiac_nat_prec_res_ensemble = np.load(f) * 100

with open('seg2d_f1.npy', 'rb') as f:
    cardiac_syn_f1_res = np.load(f) * 100
    cardiac_syn_f1_gt = np.load(f) * 100
    cardiac_syn_f1_res_ensemble = np.load(f) * 100
    cardiac_nat_f1_res = np.load(f) * 100
    cardiac_nat_f1_gt = np.load(f) * 100
    cardiac_nat_f1_res_ensemble = np.load(f) * 100

with open('seg2d_auc.npy', 'rb') as f:
    cardiac_syn_auc_res = np.load(f) * 100
    cardiac_syn_auc_gt = np.load(f) * 100
    cardiac_syn_auc_res_ensemble = np.load(f) * 100
    cardiac_nat_auc_res = np.load(f) * 100
    cardiac_nat_auc_gt = np.load(f) * 100
    cardiac_nat_auc_res_ensemble = np.load(f) * 100

# %%
# seg3d, all conditions (83 + 5 + 83 + 12)
with open('seg3d_acc.npy', 'rb') as f:
    prostate_syn_acc_res = np.load(f) * 100
    prostate_syn_acc_gt = np.load(f) * 100
    prostate_syn_acc_res_ensemble = np.load(f) * 100
    prostate_nat_acc_res = np.load(f) * 100
    prostate_nat_acc_gt = np.load(f) * 100
    prostate_nat_acc_res_ensemble = np.load(f) * 100
    brain_syn_acc_res = np.load(f) * 100
    brain_syn_acc_gt = np.load(f) * 100
    brain_syn_acc_res_ensemble = np.load(f) * 100
    brain_nat_acc_res = np.load(f) * 100
    brain_nat_acc_gt = np.load(f) * 100
    brain_nat_acc_res_ensemble = np.load(f) * 100

with open('seg3d_sens.npy', 'rb') as f:
    prostate_syn_sens_res = np.load(f) * 100
    prostate_syn_sens_gt = np.load(f) * 100
    prostate_syn_sens_res_ensemble = np.load(f) * 100
    prostate_nat_sens_res = np.load(f) * 100
    prostate_nat_sens_gt = np.load(f) * 100
    prostate_nat_sens_res_ensemble = np.load(f) * 100
    brain_syn_sens_res = np.load(f) * 100
    brain_syn_sens_gt = np.load(f) * 100
    brain_syn_sens_res_ensemble = np.load(f) * 100
    brain_nat_sens_res = np.load(f) * 100
    brain_nat_sens_gt = np.load(f) * 100
    brain_nat_sens_res_ensemble = np.load(f) * 100

with open('seg3d_prec.npy', 'rb') as f:
    prostate_syn_prec_res = np.load(f) * 100
    prostate_syn_prec_gt = np.load(f) * 100
    prostate_syn_prec_res_ensemble = np.load(f) * 100
    prostate_nat_prec_res = np.load(f) * 100
    prostate_nat_prec_gt = np.load(f) * 100
    prostate_nat_prec_res_ensemble = np.load(f) * 100
    brain_syn_prec_res = np.load(f) * 100
    brain_syn_prec_gt = np.load(f) * 100
    brain_syn_prec_res_ensemble = np.load(f) * 100
    brain_nat_prec_res = np.load(f) * 100
    brain_nat_prec_gt = np.load(f) * 100
    brain_nat_prec_res_ensemble = np.load(f) * 100

with open('seg3d_f1.npy', 'rb') as f:
    prostate_syn_f1_res = np.load(f) * 100
    prostate_syn_f1_gt = np.load(f) * 100
    prostate_syn_f1_res_ensemble = np.load(f) * 100
    prostate_nat_f1_res = np.load(f) * 100
    prostate_nat_f1_gt = np.load(f) * 100
    prostate_nat_f1_res_ensemble = np.load(f) * 100
    brain_syn_f1_res = np.load(f) * 100
    brain_syn_f1_gt = np.load(f) * 100
    brain_syn_f1_res_ensemble = np.load(f) * 100
    brain_nat_f1_res = np.load(f) * 100
    brain_nat_f1_gt = np.load(f) * 100
    brain_nat_f1_res_ensemble = np.load(f) * 100

with open('seg3d_auc.npy', 'rb') as f:
    prostate_syn_auc_res = np.load(f) * 100
    prostate_syn_auc_gt = np.load(f) * 100
    prostate_syn_auc_res_ensemble = np.load(f) * 100
    prostate_nat_auc_res = np.load(f) * 100
    prostate_nat_auc_gt = np.load(f) * 100
    prostate_nat_auc_res_ensemble = np.load(f) * 100
    brain_syn_auc_res = np.load(f) * 100
    brain_syn_auc_gt = np.load(f) * 100
    brain_syn_auc_res_ensemble = np.load(f) * 100
    brain_nat_auc_res = np.load(f) * 100
    brain_nat_auc_gt = np.load(f) * 100
    brain_nat_auc_res_ensemble = np.load(f) * 100

with open('seg3d_conds_f1.npy', 'rb') as f:
    brainci1_syn_f1_res = np.load(f) * 100
    brainci1_syn_f1_gt = np.load(f) * 100
    brainci1_syn_f1_res_ensemble = np.load(f) * 100
    brainci2_syn_f1_res = np.load(f) * 100
    brainci2_syn_f1_gt = np.load(f) * 100
    brainci2_syn_f1_res_ensemble = np.load(f) * 100
    brainrl1_syn_f1_res = np.load(f) * 100
    brainrl1_syn_f1_gt = np.load(f) * 100
    brainrl1_syn_f1_res_ensemble = np.load(f) * 100
    brainrl2_syn_f1_res = np.load(f) * 100
    brainrl2_syn_f1_gt = np.load(f) * 100
    brainrl2_syn_f1_res_ensemble = np.load(f) * 100
    brainci1_nat_f1_res = np.load(f) * 100
    brainci1_nat_f1_gt = np.load(f) * 100
    brainci1_nat_f1_res_ensemble = np.load(f) * 100
    brainci2_nat_f1_res = np.load(f) * 100
    brainci2_nat_f1_gt = np.load(f) * 100
    brainci2_nat_f1_res_ensemble = np.load(f) * 100
    brainrl1_nat_f1_res = np.load(f) * 100
    brainrl1_nat_f1_gt = np.load(f) * 100
    brainrl1_nat_f1_res_ensemble = np.load(f) * 100
    brainrl2_nat_f1_res = np.load(f) * 100
    brainrl2_nat_f1_gt = np.load(f) * 100
    brainrl2_nat_f1_res_ensemble = np.load(f) * 100

# %%
# do the plots

# %%
# eraze the in-existing class for skin lesion
clslist = []
clslist.append([0, 1, 2, 3, 4, 5, 6])
clslist.append([1, 2, 3, 4, 5, 6])
clslist.append([0, 1, 2, 3, 4, 5])
clslist.append([0, 1, 2, 3, 4, 5, 6])
clslist.append([4, 5])
clslist.append([1, 2, 3, 4, 5])
clslist.append([4, 5])

# %%
skin_sens_res_ = []
for cond in range(len(skin_sens_res)):
    cls_sel = clslist[cond]
    skin_sens_res_cls = skin_sens_res[0:1, :, :, cls_sel]
    if len(skin_sens_res_) == 0:
        skin_sens_res_ =  skin_sens_res_cls[0, :, 0, :]
    else:
        skin_sens_res_ = np.concatenate((skin_sens_res_, skin_sens_res_cls[0, :, 0, :]), axis = 1)
#
skin_sens_res_ensemble_ = []
for cond in range(len(skin_sens_res_ensemble)):
    cls_sel = clslist[cond]
    skin_sens_res_cls = skin_sens_res_ensemble[0:1, :, :, cls_sel]
    if len(skin_sens_res_ensemble_) == 0:
        skin_sens_res_ensemble_ =  skin_sens_res_cls[0, :, 0, :]
    else:
        skin_sens_res_ensemble_ = np.concatenate((skin_sens_res_ensemble_, skin_sens_res_cls[0, :, 0, :]), axis = 1)
#
skin_sens_gt_ = []
for cond in range(len(skin_sens_res)):
    cls_sel = clslist[cond]
    skin_sens_gt_cls = skin_sens_gt[0:1, :, :, cls_sel]
    if len(skin_sens_gt_) == 0:
        skin_sens_gt_ =  skin_sens_gt_cls[0, :, 0, :]
    else:
        skin_sens_gt_ = np.concatenate((skin_sens_gt_, skin_sens_gt_cls[0, :, 0, :]), axis = 1)
#
skin_prec_res_ = []
for cond in range(len(skin_prec_res)):
    cls_sel = clslist[cond]
    skin_prec_res_cls = skin_prec_res[0:1, :, :, cls_sel]
    if len(skin_prec_res_) == 0:
        skin_prec_res_ =  skin_prec_res_cls[0, :, 0, :]
    else:
        skin_prec_res_ = np.concatenate((skin_prec_res_, skin_prec_res_cls[0, :, 0, :]), axis = 1)
#
skin_prec_res_ensemble_ = []
for cond in range(len(skin_prec_res_ensemble)):
    cls_sel = clslist[cond]
    skin_prec_res_cls = skin_prec_res_ensemble[0:1, :, :, cls_sel]
    if len(skin_prec_res_ensemble_) == 0:
        skin_prec_res_ensemble_ =  skin_prec_res_cls[0, :, 0, :]
    else:
        skin_prec_res_ensemble_ = np.concatenate((skin_prec_res_ensemble_, skin_prec_res_cls[0, :, 0, :]), axis = 1)
#
skin_prec_gt_ = []
for cond in range(len(skin_prec_res)):
    cls_sel = clslist[cond]
    skin_prec_gt_cls = skin_prec_gt[0:1, :, :, cls_sel]
    if len(skin_prec_gt_) == 0:
        skin_prec_gt_ =  skin_prec_gt_cls[0, :, 0, :]
    else:
        skin_prec_gt_ = np.concatenate((skin_prec_gt_, skin_prec_gt_cls[0, :, 0, :]), axis = 1)
skin_f1_res_ = []
for cond in range(len(skin_f1_res)):
    cls_sel = clslist[cond]
    skin_f1_res_cls = skin_f1_res[0:1, :, :, cls_sel]
    if len(skin_f1_res_) == 0:
        skin_f1_res_ =  skin_f1_res_cls[0, :, 0, :]
    else:
        skin_f1_res_ = np.concatenate((skin_f1_res_, skin_f1_res_cls[0, :, 0, :]), axis = 1)
#
skin_f1_res_ensemble_ = []
for cond in range(len(skin_f1_res_ensemble)):
    cls_sel = clslist[cond]
    skin_f1_res_cls = skin_f1_res_ensemble[0:1, :, :, cls_sel]
    if len(skin_f1_res_ensemble_) == 0:
        skin_f1_res_ensemble_ =  skin_f1_res_cls[0, :, 0, :]
    else:
        skin_f1_res_ensemble_ = np.concatenate((skin_f1_res_ensemble_, skin_f1_res_cls[0, :, 0, :]), axis = 1)
#
skin_f1_gt_ = []
for cond in range(len(skin_f1_res)):
    cls_sel = clslist[cond]
    skin_f1_gt_cls = skin_f1_gt[0:1, :, :, cls_sel]
    if len(skin_f1_gt_) == 0:
        skin_f1_gt_ =  skin_f1_gt_cls[0, :, 0, :]
    else:
        skin_f1_gt_ = np.concatenate((skin_f1_gt_, skin_f1_gt_cls[0, :, 0, :]), axis = 1)
skin_auc_res_ = []
for cond in range(len(skin_auc_res)):
    cls_sel = clslist[cond]
    skin_auc_res_cls = skin_auc_res[0:1, :, :, cls_sel]
    if len(skin_auc_res_) == 0:
        skin_auc_res_ =  skin_auc_res_cls[0, :, 0, :]
    else:
        skin_auc_res_ = np.concatenate((skin_auc_res_, skin_auc_res_cls[0, :, 0, :]), axis = 1)
#
skin_auc_res_ensemble_ = []
for cond in range(len(skin_auc_res_ensemble)):
    cls_sel = clslist[cond]
    skin_auc_res_cls = skin_auc_res_ensemble[0:1, :, :, cls_sel]
    if len(skin_auc_res_ensemble_) == 0:
        skin_auc_res_ensemble_ =  skin_auc_res_cls[0, :, 0, :]
    else:
        skin_auc_res_ensemble_ = np.concatenate((skin_auc_res_ensemble_, skin_auc_res_cls[0, :, 0, :]), axis = 1)
#
skin_auc_gt_ = []
for cond in range(len(skin_auc_res)):
    cls_sel = clslist[cond]
    skin_auc_gt_cls = skin_auc_gt[0:1, :, :, cls_sel]
    if len(skin_auc_gt_) == 0:
        skin_auc_gt_ =  skin_auc_gt_cls[0, :, 0, :]
    else:
        skin_auc_gt_ = np.concatenate((skin_auc_gt_, skin_auc_gt_cls[0, :, 0, :]), axis = 1)

# %%
estim_cls_acc = np.concatenate((cifar10_acc_res, cifar100_acc_res, skin_acc_res), axis = 1)
estim_cls_acc_ensemb = np.concatenate((cifar10_acc_res_ensemble, cifar100_acc_res_ensemble, skin_acc_res_ensemble), axis = 1)
gt_cls_acc = np.concatenate((cifar10_acc_gt[0:1, :], cifar100_acc_gt[0:1, :], skin_acc_gt[0:1, :]), axis = 1)
#
estim_cls_sens = np.concatenate((cifar10_sens_res.transpose((1, 0, 2, 3)).reshape([36, -1]), 
                               cifar100_sens_res.transpose((1, 0, 2, 3)).reshape([36, -1]), 
                               skin_sens_res_), axis = 1)
estim_cls_sens_ensemb = np.concatenate((cifar10_sens_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                      cifar100_sens_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                      skin_sens_res_ensemble_), axis = 1)
gt_cls_sens = np.concatenate((cifar10_sens_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                            cifar100_sens_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                            skin_sens_gt_[0:1, :]), axis = 1)
#
estim_cls_prec = np.concatenate((cifar10_prec_res.transpose((1, 0, 2, 3)).reshape([20, -1]), 
                               cifar100_prec_res.transpose((1, 0, 2, 3)).reshape([20, -1]), 
                               skin_prec_res_), axis = 1)
estim_cls_prec_ensemb = np.concatenate((cifar10_prec_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                      cifar100_prec_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                      skin_prec_res_ensemble_), axis = 1)
gt_cls_prec = np.concatenate((cifar10_prec_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                            cifar100_prec_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                            skin_prec_gt_[0:1, :]), axis = 1)
#
estim_cls_f1 = np.concatenate((cifar10_f1_res.transpose((1, 0, 2, 3)).reshape([36, -1]), 
                               cifar100_f1_res.transpose((1, 0, 2, 3)).reshape([36, -1]), 
                               skin_f1_res_), axis = 1)
estim_cls_f1_ensemb = np.concatenate((cifar10_f1_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                      cifar100_f1_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                      skin_f1_res_ensemble_), axis = 1)
gt_cls_f1 = np.concatenate((cifar10_f1_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                            cifar100_f1_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                            skin_f1_gt_[0:1, :]), axis = 1)
#
estim_cls_auc = np.concatenate((cifar10_auc_res.transpose((1, 0, 2, 3)).reshape([20, -1]), 
                               cifar100_auc_res.transpose((1, 0, 2, 3)).reshape([20, -1]), 
                               skin_auc_res_), axis = 1)
estim_cls_auc_ensemb = np.concatenate((cifar10_auc_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                      cifar100_auc_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                      skin_auc_res_ensemble_), axis = 1)
gt_cls_auc = np.concatenate((cifar10_auc_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                            cifar100_auc_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                            skin_auc_gt_[0:1, :]), axis = 1)

# %%
existing_index_full = [0, 4, 12, 20, 28]
# class_specific variant, +4
existing_index_FP = [0, 4, 12]

# %%
diff = np.mean(np.abs(estim_cls_acc - np.tile(gt_cls_acc, (36, 1))), axis = 1)
# 95, 95, 7

# %%
#
estim_alg = ["AC", "TS", "DoC", "ATC", "TS-ATC"]
#
diff_existing = diff[existing_index_full]
select_index = np.argmin(diff_existing)
#
baseline_MCP_AC = estim_cls_acc[0, :]
existing_best = estim_cls_acc[existing_index_full[select_index], :]
moval_ensemb = estim_cls_acc_ensemb[0, :]
gt_acc = gt_cls_acc[0, :]

# %%
sns.set_theme(style="darkgrid")

# Create the JointGrid
g = sns.JointGrid()
g.ax_joint.set_xlim([0., 100.])
g.ax_joint.set_ylim([0., 100.])

# Plot the first dataset
sns.scatterplot(x=baseline_MCP_AC[:95], y=gt_acc[:95], color='#d3d3d3', marker='x', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[95:190], y=gt_acc[95:190], color='#d3d3d3', marker='*', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[190:], y=gt_acc[190:], color='#d3d3d3', marker='o', ax=g.ax_joint)
sns.regplot(x=baseline_MCP_AC, y=gt_acc, color='#d3d3d3', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Baseline: MCP | AC')
sns.kdeplot(x=baseline_MCP_AC, fill=True, color='#d3d3d3', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the second dataset

sns.scatterplot(x=existing_best[:95], y=gt_acc[:95], color='grey', marker='x', ax=g.ax_joint)
sns.scatterplot(x=existing_best[95:190], y=gt_acc[95:190], color='grey', marker='*', ax=g.ax_joint)
sns.scatterplot(x=existing_best[190:], y=gt_acc[190:], color='grey', marker='o', ax=g.ax_joint)
sns.regplot(x=existing_best, y=gt_acc, color='grey', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Existing Best: MCP | ' + estim_alg[select_index])
sns.kdeplot(x=existing_best, fill=True, color='grey', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the third dataset
sns.regplot(x=moval_ensemb, y=gt_acc, color='#1f77b4', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='MOVAL Ensemble')
sns.scatterplot(x=moval_ensemb[:95], y=gt_acc[:95], color='#1f77b4', marker='x', ax=g.ax_joint, label='CIFAR10-LT')
sns.scatterplot(x=moval_ensemb[95:190], y=gt_acc[95:190], color='#1f77b4', marker='*', ax=g.ax_joint, label='CIFAR100-LT')
sns.scatterplot(x=moval_ensemb[190:], y=gt_acc[190:], color='#1f77b4', marker='o', ax=g.ax_joint, label='Skin Lesion')
sns.kdeplot(x=moval_ensemb, fill=True, color='#1f77b4', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Add the reference line y=x
g.ax_joint.axline((0, 0), slope=1, color='black', linestyle='--', label='y = x')

# Clear the y marginal plot and remove its axis
g.ax_marg_y.clear()
g.ax_marg_y.axis('off')

# Set axis labels
g.ax_joint.set_xlabel("Predicted Accuracy")
g.ax_joint.set_ylabel("Real Accuracy")

sns.kdeplot(x=gt_acc, color='black', ax=g.ax_marg_x, label='Real Label Distribution')
g.ax_marg_x.legend(loc='upper left')

# Combine legends from all plots
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, loc='best')

# Add title to the figure
plt.suptitle("Accuracy Estimation for Classification Tasks", y=1.02)

plt.savefig('Fig_lineplot_acc_cls.pdf', bbox_inches='tight')

# %%
diff_abs_baseline = np.abs(baseline_MCP_AC-gt_acc)
diff_abs_existing_best = np.abs(existing_best-gt_acc)
diff_abs_moval_ensemb = np.abs(moval_ensemb-gt_acc)

sns.set(rc={'figure.figsize':(6,2)})
sns.set_theme(style="darkgrid")
# Create a figure and a single set of axes
fig, ax = plt.subplots()

# Calculate the bin edges to ensure the same bin size for all histograms
min_val = min(diff_abs_baseline.min(), diff_abs_existing_best.min(), diff_abs_moval_ensemb.min())
max_val = max(diff_abs_baseline.max(), diff_abs_existing_best.max(), diff_abs_moval_ensemb.max())
bin_edges = np.linspace(0, 100, 60)

# Plot each distribution on the same axes
sns.histplot(diff_abs_baseline, color='#d3d3d3', label='Baseline: MCP | AC', kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_existing_best, color='grey', label='Existing Best: MCP | ' + estim_alg[select_index], kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_moval_ensemb, color='#1f77b4', label='MOVAL Ensemble', kde=True, bins=bin_edges, ax=ax)

mean_baseline = diff_abs_baseline.mean()
mean_existing_best = diff_abs_existing_best.mean()
mean_moval_ensemb = diff_abs_moval_ensemb.mean()

# Plot stars for means
ax.plot(mean_baseline, 6, '*', color='#d3d3d3', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_existing_best, 6, '*', color='grey', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_moval_ensemb, 6, '*', color='#1f77b4', markeredgecolor='black', markeredgewidth=1, markersize=15, label='Mean')

# Add legend for histograms
legend_hists = ax.legend(loc='upper right')

# Add both legends to the plot
ax.add_artist(legend_hists)

ax.set_xlabel('MAE')
ax.set_ylabel('Number of Samples')

ax.set_xlim((0, 60))

plt.savefig('Fig_hisplot_acc_cls.pdf', bbox_inches='tight')

# %%
# resample to 35, 35, 35
random.seed(79)
cifar10list = list(range(950))
random.shuffle(cifar10list)
cifar10list_ = cifar10list[:35]
cifar100list = list(range(950, 950+9500))
random.shuffle(cifar10list)
cifar100list_ = cifar100list[:35]
skinlist = list(range(950+9500, 950+9500+35))
# fit_data_list = cifar10list_ + cifar100list_ + skinlist
fit_data_list = list(range(950+9500+35))

# %%
diff = np.mean(np.abs(estim_cls_sens - np.tile(gt_cls_sens, (36, 1))), axis = 1)
# 950, 9500, 49(35)
#
estim_alg = ["AC", "TS", "DoC", "ATC", "TS-ATC"]
#
diff_existing = diff[existing_index_full]
select_index = np.argmin(diff_existing)
#
baseline_MCP_AC = estim_cls_sens[0, :]
existing_best = estim_cls_sens[existing_index_full[select_index], :]
moval_ensemb = estim_cls_sens_ensemb[0, :]
gt_acc = gt_cls_sens[0, :]
#
sns.set_theme(style="darkgrid")

# Create the JointGrid
g = sns.JointGrid()
g.ax_joint.set_xlim([0., 100.])
g.ax_joint.set_ylim([0., 100.])

# Plot the first dataset
sns.scatterplot(x=baseline_MCP_AC[cifar10list_], y=gt_acc[cifar10list_], color='#d3d3d3', marker='x', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[cifar100list_], y=gt_acc[cifar100list_], color='#d3d3d3', marker='*', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[skinlist], y=gt_acc[skinlist], color='#d3d3d3', marker='o', ax=g.ax_joint)
sns.regplot(x=baseline_MCP_AC[fit_data_list], y=gt_acc[fit_data_list], color='#d3d3d3', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Baseline: MCP | AC')
sns.kdeplot(x=baseline_MCP_AC[fit_data_list], fill=True, color='#d3d3d3', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the second dataset
sns.scatterplot(x=existing_best[cifar10list_], y=gt_acc[cifar10list_], color='grey', marker='x', ax=g.ax_joint)
sns.scatterplot(x=existing_best[cifar100list_], y=gt_acc[cifar100list_], color='grey', marker='*', ax=g.ax_joint)
sns.scatterplot(x=existing_best[skinlist], y=gt_acc[skinlist], color='grey', marker='o', ax=g.ax_joint)
sns.regplot(x=existing_best[fit_data_list], y=gt_acc[fit_data_list], color='grey', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Existing Best: MCP | ' + estim_alg[select_index])
sns.kdeplot(x=existing_best[fit_data_list], fill=True, color='grey', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the third dataset
sns.regplot(x=moval_ensemb[fit_data_list], y=gt_acc[fit_data_list], color='#1f77b4', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='MOVAL Ensemble')
sns.scatterplot(x=moval_ensemb[cifar10list_], y=gt_acc[cifar10list_], color='#1f77b4', marker='x', ax=g.ax_joint, label='CIFAR10-LT')
sns.scatterplot(x=moval_ensemb[cifar100list_], y=gt_acc[cifar100list_], color='#1f77b4', marker='*', ax=g.ax_joint, label='CIFAR100-LT')
sns.scatterplot(x=moval_ensemb[skinlist], y=gt_acc[skinlist], color='#1f77b4', marker='o', ax=g.ax_joint, label='Skin Lesion')
sns.kdeplot(x=moval_ensemb[fit_data_list], fill=True, color='#1f77b4', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Add the reference line y=x
g.ax_joint.axline((0, 0), slope=1, color='black', linestyle='--', label='y = x')

# Clear the y marginal plot and remove its axis
g.ax_marg_y.clear()
g.ax_marg_y.axis('off')

# Set axis labels
g.ax_joint.set_xlabel("Predicted Sensitivity")
g.ax_joint.set_ylabel("Real Sensitivity")

sns.kdeplot(x=gt_acc[fit_data_list], color='black', ax=g.ax_marg_x, label='Real Label Distribution')
g.ax_marg_x.legend(loc='upper right')

# Combine legends from all plots
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, loc='best')

# Add title to the figure
plt.suptitle("Sensitivity Estimation for Classification Tasks", y=1.02)

plt.savefig('Fig_lineplot_sensitivity_cls.pdf', bbox_inches='tight')

# %%
diff_abs_baseline = np.abs(baseline_MCP_AC-gt_acc)
diff_abs_existing_best = np.abs(existing_best-gt_acc)
diff_abs_moval_ensemb = np.abs(moval_ensemb-gt_acc)

sns.set(rc={'figure.figsize':(6,2)})
sns.set_theme(style="darkgrid")
# Create a figure and a single set of axes
fig, ax = plt.subplots()

# Calculate the bin edges to ensure the same bin size for all histograms
min_val = min(diff_abs_baseline.min(), diff_abs_existing_best.min(), diff_abs_moval_ensemb.min())
max_val = max(diff_abs_baseline.max(), diff_abs_existing_best.max(), diff_abs_moval_ensemb.max())
# bin_edges = np.linspace(min_val, max_val, 30)
bin_edges = np.linspace(0, 100, 60)

# Plot each distribution on the same axes
sns.histplot(diff_abs_baseline, color='#d3d3d3', label='Baseline: MCP | AC', kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_existing_best, color='grey', label='Existing Best: MCP | ' + estim_alg[select_index], kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_moval_ensemb, color='#1f77b4', label='MOVAL Ensemble', kde=True, bins=bin_edges, ax=ax)

mean_baseline = diff_abs_baseline.mean()
mean_existing_best = diff_abs_existing_best.mean()
mean_moval_ensemb = diff_abs_moval_ensemb.mean()

# Plot stars for means
ax.plot(mean_baseline, 160, '*', color='#d3d3d3', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_existing_best, 320, '*', color='grey', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_moval_ensemb, 160, '*', color='#1f77b4', markeredgecolor='black', markeredgewidth=1, markersize=15, label='Mean')

# Add legend for histograms
legend_hists = ax.legend(loc='upper right')

# Add both legends to the plot
ax.add_artist(legend_hists)

ax.set_xlabel('MAE')
ax.set_ylabel('Number of Samples')

ax.set_xlim((0, 60))

plt.savefig('Fig_hisplot_sens_cls.pdf', bbox_inches='tight')

# %%
diff = np.mean(np.abs(estim_cls_prec - np.tile(gt_cls_prec, (20, 1))), axis = 1)
# 950, 9500, 49(35)
#
estim_alg = ["AC", "TS", "DoC", "ATC", "TS-ATC"]
#
diff_existing = diff[existing_index_FP]
select_index = np.argmin(diff_existing)
#
baseline_MCP_AC = estim_cls_prec[0, :]
existing_best = estim_cls_prec[existing_index_full[select_index], :]
moval_ensemb = estim_cls_prec_ensemb[0, :]
gt_acc = gt_cls_prec[0, :]
#
sns.set_theme(style="darkgrid")

# Create the JointGrid
g = sns.JointGrid()
g.ax_joint.set_xlim([0., 100.])
g.ax_joint.set_ylim([0., 100.])

# Plot the first dataset
sns.scatterplot(x=baseline_MCP_AC[cifar10list_], y=gt_acc[cifar10list_], color='#d3d3d3', marker='x', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[cifar100list_], y=gt_acc[cifar100list_], color='#d3d3d3', marker='*', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[skinlist], y=gt_acc[skinlist], color='#d3d3d3', marker='o', ax=g.ax_joint)
sns.regplot(x=baseline_MCP_AC[fit_data_list], y=gt_acc[fit_data_list], color='#d3d3d3', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Baseline: MCP | AC')
sns.kdeplot(x=baseline_MCP_AC[fit_data_list], fill=True, color='#d3d3d3', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the second dataset
sns.scatterplot(x=existing_best[cifar10list_], y=gt_acc[cifar10list_], color='grey', marker='x', ax=g.ax_joint)
sns.scatterplot(x=existing_best[cifar100list_], y=gt_acc[cifar100list_], color='grey', marker='*', ax=g.ax_joint)
sns.scatterplot(x=existing_best[skinlist], y=gt_acc[skinlist], color='grey', marker='o', ax=g.ax_joint)
sns.regplot(x=existing_best[fit_data_list], y=gt_acc[fit_data_list], color='grey', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Existing Best: MCP | ' + estim_alg[select_index])
sns.kdeplot(x=existing_best[fit_data_list], fill=True, color='grey', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the third dataset
sns.regplot(x=moval_ensemb[fit_data_list], y=gt_acc[fit_data_list], color='#1f77b4', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='MOVAL Ensemble')
sns.scatterplot(x=moval_ensemb[cifar10list_], y=gt_acc[cifar10list_], color='#1f77b4', marker='x', ax=g.ax_joint, label='CIFAR10-LT')
sns.scatterplot(x=moval_ensemb[cifar100list_], y=gt_acc[cifar100list_], color='#1f77b4', marker='*', ax=g.ax_joint, label='CIFAR100-LT')
sns.scatterplot(x=moval_ensemb[skinlist], y=gt_acc[skinlist], color='#1f77b4', marker='o', ax=g.ax_joint, label='Skin Lesion')
sns.kdeplot(x=moval_ensemb[fit_data_list], fill=True, color='#1f77b4', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Add the reference line y=x
g.ax_joint.axline((0, 0), slope=1, color='black', linestyle='--', label='y = x')

# Clear the y marginal plot and remove its axis
g.ax_marg_y.clear()
g.ax_marg_y.axis('off')

# Set axis labels
g.ax_joint.set_xlabel("Predicted Precision")
g.ax_joint.set_ylabel("Real Precision")

sns.kdeplot(x=gt_acc[fit_data_list], color='black', ax=g.ax_marg_x, label='Real Label Distribution')
g.ax_marg_x.legend(loc='upper right')

# Combine legends from all plots
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, loc='best')

# Add title to the figure
plt.suptitle("Precision Estimation for Classification Tasks", y=1.02)

plt.savefig('Fig_lineplot_precision_cls.pdf', bbox_inches='tight')

# %%
diff_abs_baseline = np.abs(baseline_MCP_AC-gt_acc)
diff_abs_existing_best = np.abs(existing_best-gt_acc)
diff_abs_moval_ensemb = np.abs(moval_ensemb-gt_acc)

sns.set(rc={'figure.figsize':(6,2)})
sns.set_theme(style="darkgrid")
# Create a figure and a single set of axes
fig, ax = plt.subplots()

# Calculate the bin edges to ensure the same bin size for all histograms
min_val = min(diff_abs_baseline.min(), diff_abs_existing_best.min(), diff_abs_moval_ensemb.min())
max_val = max(diff_abs_baseline.max(), diff_abs_existing_best.max(), diff_abs_moval_ensemb.max())
# bin_edges = np.linspace(min_val, max_val, 30)
bin_edges = np.linspace(0, 100, 60)

# Plot each distribution on the same axes
sns.histplot(diff_abs_baseline, color='#d3d3d3', label='Baseline: MCP | AC', kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_existing_best, color='grey', label='Existing Best: MCP | ' + estim_alg[select_index], kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_moval_ensemb, color='#1f77b4', label='MOVAL Ensemble', kde=True, bins=bin_edges, ax=ax)

mean_baseline = diff_abs_baseline.mean()
mean_existing_best = diff_abs_existing_best.mean()
mean_moval_ensemb = diff_abs_moval_ensemb.mean()

# Plot stars for means
ax.plot(mean_baseline, 100, '*', color='#d3d3d3', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_existing_best, 100, '*', color='grey', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_moval_ensemb, 100, '*', color='#1f77b4', markeredgecolor='black', markeredgewidth=1, markersize=15, label='Mean')

# Add legend for histograms
legend_hists = ax.legend(loc='upper right')

# Add both legends to the plot
ax.add_artist(legend_hists)

ax.set_xlabel('MAE')
ax.set_ylabel('Number of Samples')

ax.set_xlim((0, 60))

plt.savefig('Fig_hisplot_prec_cls.pdf', bbox_inches='tight')

# %%
diff = np.mean(np.abs(estim_cls_f1 - np.tile(gt_cls_f1, (36, 1))), axis = 1)
# 950, 9500, 49(35)
#
estim_alg = ["AC", "TS", "DoC", "ATC", "TS-ATC"]
#
diff_existing = diff[existing_index_full]
select_index = np.argmin(diff_existing)
#
baseline_MCP_AC = estim_cls_f1[0, :]
existing_best = estim_cls_f1[existing_index_full[select_index], :]
moval_ensemb = estim_cls_f1_ensemb[0, :]
gt_acc = gt_cls_f1[0, :]
#
sns.set_theme(style="darkgrid")

# Create the JointGrid
g = sns.JointGrid()
g.ax_joint.set_xlim([0., 100.])
g.ax_joint.set_ylim([0., 100.])

# Plot the first dataset
sns.scatterplot(x=baseline_MCP_AC[cifar10list_], y=gt_acc[cifar10list_], color='#d3d3d3', marker='x', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[cifar100list_], y=gt_acc[cifar100list_], color='#d3d3d3', marker='*', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[skinlist], y=gt_acc[skinlist], color='#d3d3d3', marker='o', ax=g.ax_joint)
sns.regplot(x=baseline_MCP_AC[fit_data_list], y=gt_acc[fit_data_list], color='#d3d3d3', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Baseline: MCP | AC')
sns.kdeplot(x=baseline_MCP_AC[fit_data_list], fill=True, color='#d3d3d3', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the second dataset
sns.scatterplot(x=existing_best[cifar10list_], y=gt_acc[cifar10list_], color='grey', marker='x', ax=g.ax_joint)
sns.scatterplot(x=existing_best[cifar100list_], y=gt_acc[cifar100list_], color='grey', marker='*', ax=g.ax_joint)
sns.scatterplot(x=existing_best[skinlist], y=gt_acc[skinlist], color='grey', marker='o', ax=g.ax_joint)
sns.regplot(x=existing_best[fit_data_list], y=gt_acc[fit_data_list], color='grey', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Existing Best: MCP | ' + estim_alg[select_index])
sns.kdeplot(x=existing_best[fit_data_list], fill=True, color='grey', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the third dataset
sns.regplot(x=moval_ensemb[fit_data_list], y=gt_acc[fit_data_list], color='#1f77b4', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='MOVAL Ensemble')
sns.scatterplot(x=moval_ensemb[cifar10list_], y=gt_acc[cifar10list_], color='#1f77b4', marker='x', ax=g.ax_joint, label='CIFAR10-LT')
sns.scatterplot(x=moval_ensemb[cifar100list_], y=gt_acc[cifar100list_], color='#1f77b4', marker='*', ax=g.ax_joint, label='CIFAR100-LT')
sns.scatterplot(x=moval_ensemb[skinlist], y=gt_acc[skinlist], color='#1f77b4', marker='o', ax=g.ax_joint, label='Skin Lesion')
sns.kdeplot(x=moval_ensemb[fit_data_list], fill=True, color='#1f77b4', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Add the reference line y=x
g.ax_joint.axline((0, 0), slope=1, color='black', linestyle='--', label='y = x')

# Clear the y marginal plot and remove its axis
g.ax_marg_y.clear()
g.ax_marg_y.axis('off')

# Set axis labels
g.ax_joint.set_xlabel("Predicted F1-Score")
g.ax_joint.set_ylabel("Real F1-Score")

sns.kdeplot(x=gt_acc[fit_data_list], color='black', ax=g.ax_marg_x, label='Real Label Distribution')
g.ax_marg_x.legend(loc='upper left')

# Combine legends from all plots
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, loc='best')

# Add title to the figure
plt.suptitle("F1-Score Estimation for Classification Tasks", y=1.02)

plt.savefig('Fig_lineplot_f1_cls.pdf', bbox_inches='tight')

# %%
diff_abs_baseline = np.abs(baseline_MCP_AC-gt_acc)
diff_abs_existing_best = np.abs(existing_best-gt_acc)
diff_abs_moval_ensemb = np.abs(moval_ensemb-gt_acc)

sns.set(rc={'figure.figsize':(6,2)})
sns.set_theme(style="darkgrid")
# Create a figure and a single set of axes
fig, ax = plt.subplots()

# Calculate the bin edges to ensure the same bin size for all histograms
min_val = min(diff_abs_baseline.min(), diff_abs_existing_best.min(), diff_abs_moval_ensemb.min())
max_val = max(diff_abs_baseline.max(), diff_abs_existing_best.max(), diff_abs_moval_ensemb.max())
# bin_edges = np.linspace(min_val, max_val, 30)
bin_edges = np.linspace(0, 100, 50)

# Plot each distribution on the same axes
sns.histplot(diff_abs_baseline, color='#d3d3d3', label='Baseline: MCP | AC', kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_existing_best, color='grey', label='Existing Best: MCP | ' + estim_alg[select_index], kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_moval_ensemb, color='#1f77b4', label='MOVAL Ensemble', kde=True, bins=bin_edges, ax=ax)

mean_baseline = diff_abs_baseline.mean()
mean_existing_best = diff_abs_existing_best.mean()
mean_moval_ensemb = diff_abs_moval_ensemb.mean()

# Plot stars for means
ax.plot(mean_baseline, 130, '*', color='#d3d3d3', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_existing_best, 130, '*', color='grey', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_moval_ensemb, 130, '*', color='#1f77b4', markeredgecolor='black', markeredgewidth=1, markersize=15, label='Mean')

# Add legend for histograms
legend_hists = ax.legend(loc='upper right')

# Add both legends to the plot
ax.add_artist(legend_hists)

ax.set_xlabel('MAE')
ax.set_ylabel('Number of Samples')

ax.set_xlim((0, 60))


plt.savefig('Fig_hisplot_f1_cls.pdf', bbox_inches='tight')

# %%
diff = np.mean(np.abs(estim_cls_auc - np.tile(gt_cls_auc, (20, 1))), axis = 1)
# 950, 9500, 49(35)
#
estim_alg = ["AC", "TS", "DoC", "ATC", "TS-ATC"]
#
diff_existing = diff[existing_index_FP]
select_index = np.argmin(diff_existing)
#
baseline_MCP_AC = estim_cls_auc[0, :]
existing_best = estim_cls_auc[existing_index_full[select_index], :]
moval_ensemb = estim_cls_auc_ensemb[0, :]
gt_acc = gt_cls_auc[0, :]
#
sns.set_theme(style="darkgrid")

# Create the JointGrid
g = sns.JointGrid()
g.ax_joint.set_xlim([0., 100.])
g.ax_joint.set_ylim([0., 100.])

# Plot the first dataset
sns.scatterplot(x=baseline_MCP_AC[cifar10list_], y=gt_acc[cifar10list_], color='#d3d3d3', marker='x', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[cifar100list_], y=gt_acc[cifar100list_], color='#d3d3d3', marker='*', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[skinlist], y=gt_acc[skinlist], color='#d3d3d3', marker='o', ax=g.ax_joint)
sns.regplot(x=baseline_MCP_AC[fit_data_list], y=gt_acc[fit_data_list], color='#d3d3d3', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Baseline: MCP | AC')
sns.kdeplot(x=baseline_MCP_AC[fit_data_list], fill=True, color='#d3d3d3', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the second dataset
sns.scatterplot(x=existing_best[cifar10list_], y=gt_acc[cifar10list_], color='grey', marker='x', ax=g.ax_joint)
sns.scatterplot(x=existing_best[cifar100list_], y=gt_acc[cifar100list_], color='grey', marker='*', ax=g.ax_joint)
sns.scatterplot(x=existing_best[skinlist], y=gt_acc[skinlist], color='grey', marker='o', ax=g.ax_joint)
sns.regplot(x=existing_best[fit_data_list], y=gt_acc[fit_data_list], color='grey', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Existing Best: MCP | ' + estim_alg[select_index])
sns.kdeplot(x=existing_best[fit_data_list], fill=True, color='grey', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the third dataset
sns.regplot(x=moval_ensemb[fit_data_list], y=gt_acc[fit_data_list], color='#1f77b4', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='MOVAL Ensemble')
sns.scatterplot(x=moval_ensemb[cifar10list_], y=gt_acc[cifar10list_], color='#1f77b4', marker='x', ax=g.ax_joint, label='CIFAR10-LT')
sns.scatterplot(x=moval_ensemb[cifar100list_], y=gt_acc[cifar100list_], color='#1f77b4', marker='*', ax=g.ax_joint, label='CIFAR100-LT')
sns.scatterplot(x=moval_ensemb[skinlist], y=gt_acc[skinlist], color='#1f77b4', marker='o', ax=g.ax_joint, label='Skin Lesion')
sns.kdeplot(x=moval_ensemb[fit_data_list], fill=True, color='#1f77b4', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Add the reference line y=x
g.ax_joint.axline((0, 0), slope=1, color='black', linestyle='--', label='y = x')

# Clear the y marginal plot and remove its axis
g.ax_marg_y.clear()
g.ax_marg_y.axis('off')

# Set axis labels
g.ax_joint.set_xlabel("Predicted AUC")
g.ax_joint.set_ylabel("Real AUC")

sns.kdeplot(x=gt_acc[fit_data_list], color='black', ax=g.ax_marg_x, label='Real Label Distribution')
g.ax_marg_x.legend(loc='upper left')

# Combine legends from all plots
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, loc='best')

# Add title to the figure
plt.suptitle("AUC Estimation for Classification Tasks", y=1.02)

plt.savefig('Fig_lineplot_auc_cls.pdf', bbox_inches='tight')

# %%
diff_abs_baseline = np.abs(baseline_MCP_AC-gt_acc)
diff_abs_existing_best = np.abs(existing_best-gt_acc)
diff_abs_moval_ensemb = np.abs(moval_ensemb-gt_acc)

sns.set(rc={'figure.figsize':(6,2)})
sns.set_theme(style="darkgrid")
# Create a figure and a single set of axes
fig, ax = plt.subplots()

# Calculate the bin edges to ensure the same bin size for all histograms
min_val = min(diff_abs_baseline.min(), diff_abs_existing_best.min(), diff_abs_moval_ensemb.min())
max_val = max(diff_abs_baseline.max(), diff_abs_existing_best.max(), diff_abs_moval_ensemb.max())
# bin_edges = np.linspace(min_val, max_val, 30)
bin_edges = np.linspace(0, 100, 50)

# Plot each distribution on the same axes
sns.histplot(diff_abs_baseline, color='#d3d3d3', label='Baseline: MCP | AC', kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_existing_best, color='grey', label='Existing Best: MCP | ' + estim_alg[select_index], kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_moval_ensemb, color='#1f77b4', label='MOVAL Ensemble', kde=True, bins=bin_edges, ax=ax)

mean_baseline = diff_abs_baseline.mean()
mean_existing_best = diff_abs_existing_best.mean()
mean_moval_ensemb = diff_abs_moval_ensemb.mean()

# Plot stars for means
ax.plot(mean_baseline, 280, '*', color='#d3d3d3', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_existing_best, 140, '*', color='grey', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_moval_ensemb, 140, '*', color='#1f77b4', markeredgecolor='black', markeredgewidth=1, markersize=15, label='Mean')

# Add legend for histograms
legend_hists = ax.legend(loc='upper right')

# Add both legends to the plot
ax.add_artist(legend_hists)

ax.set_xlabel('MAE')
ax.set_ylabel('Number of Samples')

ax.set_xlim((0, 50))

plt.savefig('Fig_hisplot_auc_cls.pdf', bbox_inches='tight')

# %%
# do for the seg2d

# %%
estim_seg2d_acc = np.concatenate((cardiac_syn_acc_res, cardiac_nat_acc_res), axis = 0)[:, :, 0, 0].transpose((1, 0))
estim_seg2d_acc_ensemb = np.concatenate((cardiac_syn_acc_res_ensemble, cardiac_nat_acc_res_ensemble), axis = 0)[:, :, 0, 0].transpose((1, 0))
gt_seg2d_acc = np.concatenate((cardiac_syn_acc_gt[:, 0:1, :, :], cardiac_nat_acc_gt[:, 0:1, :, :]), axis = 0)[:, :, 0, 0].transpose((1, 0))
#
estim_seg2d_sens = np.concatenate((cardiac_syn_sens_res.transpose((1, 0, 2, 3)).reshape([36, -1]), 
                               cardiac_nat_sens_res.transpose((1, 0, 2, 3)).reshape([36, -1])), axis = 1)
estim_seg2d_sens_ensemb = np.concatenate((cardiac_syn_sens_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                      cardiac_nat_sens_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)
gt_seg2d_sens = np.concatenate((cardiac_syn_sens_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                            cardiac_nat_sens_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)
#
estim_seg2d_prec = np.concatenate((cardiac_syn_prec_res.transpose((1, 0, 2, 3)).reshape([20, -1]), 
                               cardiac_nat_prec_res.transpose((1, 0, 2, 3)).reshape([20, -1])), axis = 1)
estim_seg2d_prec_ensemb = np.concatenate((cardiac_syn_prec_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                      cardiac_nat_prec_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)
gt_seg2d_prec = np.concatenate((cardiac_syn_prec_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                            cardiac_nat_prec_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)
#
estim_seg2d_f1 = np.concatenate((cardiac_syn_f1_res.transpose((1, 0, 2, 3)).reshape([36, -1]), 
                               cardiac_nat_f1_res.transpose((1, 0, 2, 3)).reshape([36, -1])), axis = 1)
estim_seg2d_f1_ensemb = np.concatenate((cardiac_syn_f1_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                      cardiac_nat_f1_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)
gt_seg2d_f1 = np.concatenate((cardiac_syn_f1_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                            cardiac_nat_f1_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)
#
estim_seg2d_auc = np.concatenate((cardiac_syn_auc_res.transpose((1, 0, 2, 3)).reshape([20, -1]), 
                               cardiac_nat_auc_res.transpose((1, 0, 2, 3)).reshape([20, -1])), axis = 1)
estim_seg2d_auc_ensemb = np.concatenate((cardiac_syn_auc_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                      cardiac_nat_auc_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)
gt_seg2d_auc = np.concatenate((cardiac_syn_auc_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                            cardiac_nat_auc_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)

# %%
diff = np.mean(np.abs(estim_seg2d_acc - np.tile(gt_seg2d_acc, (36, 1))), axis = 1)
# 65, 4
#
diff_existing = diff[existing_index_full]
select_index = np.argmin(diff_existing)
#
baseline_MCP_AC = estim_seg2d_acc[0, :]
existing_best = estim_seg2d_acc[existing_index_full[select_index], :]
moval_ensemb = estim_seg2d_acc_ensemb[0, :]
gt_acc = gt_seg2d_acc[0, :]

# %%
sns.set_theme(style="darkgrid")

# Create the JointGrid
g = sns.JointGrid()
g.ax_joint.set_xlim([0., 100.])
g.ax_joint.set_ylim([0., 100.])

# Plot the first dataset
sns.scatterplot(x=baseline_MCP_AC[:65], y=gt_acc[:65], color='#d3d3d3', marker='x', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[65:], y=gt_acc[65:], color='#d3d3d3', marker='o', ax=g.ax_joint)
sns.regplot(x=baseline_MCP_AC, y=gt_acc, color='#d3d3d3', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Baseline: MCP | AC')
sns.kdeplot(x=baseline_MCP_AC, fill=True, color='#d3d3d3', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the second dataset
sns.scatterplot(x=existing_best[:65], y=gt_acc[:65], color='grey', marker='x', ax=g.ax_joint)
sns.scatterplot(x=existing_best[65:], y=gt_acc[65:], color='grey', marker='o', ax=g.ax_joint)
sns.regplot(x=existing_best, y=gt_acc, color='grey', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Existing Best: MCP | ' + estim_alg[select_index])
sns.kdeplot(x=existing_best, fill=True, color='grey', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the third dataset
sns.regplot(x=moval_ensemb, y=gt_acc, color='#1f77b4', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='MOVAL Ensemble')
sns.scatterplot(x=moval_ensemb[:65], y=gt_acc[:65], color='#1f77b4', marker='x', ax=g.ax_joint, label='Cardiac Synthetic')
sns.scatterplot(x=moval_ensemb[65:], y=gt_acc[65:], color='#1f77b4', marker='o', ax=g.ax_joint, label='Cardiac Natural')
sns.kdeplot(x=moval_ensemb, fill=True, color='#1f77b4', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Add the reference line y=x
g.ax_joint.axline((0, 0), slope=1, color='black', linestyle='--', label='y = x')

# Clear the y marginal plot and remove its axis
g.ax_marg_y.clear()
g.ax_marg_y.axis('off')

# Set axis labels
g.ax_joint.set_xlabel("Predicted Accuracy")
g.ax_joint.set_ylabel("Real Accuracy")

sns.kdeplot(x=gt_acc, color='black', ax=g.ax_marg_x, label='Real Label Distribution')
g.ax_marg_x.legend(loc='upper left')

# Combine legends from all plots
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, loc='best')

# Add title to the figure
plt.suptitle("Accuracy Estimation for 2D Segmentation Tasks", y=1.02)

plt.savefig('Fig_lineplot_acc_seg2d.pdf', bbox_inches='tight')

# %%
diff_abs_baseline = np.abs(baseline_MCP_AC-gt_acc)
diff_abs_existing_best = np.abs(existing_best-gt_acc)
diff_abs_moval_ensemb = np.abs(moval_ensemb-gt_acc)

sns.set(rc={'figure.figsize':(6,2)})
sns.set_theme(style="darkgrid")
# Create a figure and a single set of axes
fig, ax = plt.subplots()

# Calculate the bin edges to ensure the same bin size for all histograms
min_val = min(diff_abs_baseline.min(), diff_abs_existing_best.min(), diff_abs_moval_ensemb.min())
max_val = max(diff_abs_baseline.max(), diff_abs_existing_best.max(), diff_abs_moval_ensemb.max())
bin_edges = np.linspace(min_val, max_val, 30)
# bin_edges = np.linspace(0, 20, 30)

# Plot each distribution on the same axes
sns.histplot(diff_abs_baseline, color='#d3d3d3', label='Baseline: MCP | AC', kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_existing_best, color='grey', label='Existing Best: MCP | ' + estim_alg[select_index], kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_moval_ensemb, color='#1f77b4', label='MOVAL Ensemble', kde=True, bins=bin_edges, ax=ax)

mean_baseline = diff_abs_baseline.mean()
mean_existing_best = diff_abs_existing_best.mean()
mean_moval_ensemb = diff_abs_moval_ensemb.mean()

# Plot stars for means
ax.plot(mean_baseline, 3, '*', color='#d3d3d3', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_existing_best, 3, '*', color='grey', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_moval_ensemb, 3, '*', color='#1f77b4', markeredgecolor='black', markeredgewidth=1, markersize=15, label='Mean')

# Add legend for histograms
legend_hists = ax.legend(loc='upper right')

# Add both legends to the plot
ax.add_artist(legend_hists)

ax.set_xlabel('MAE')
ax.set_ylabel('Number of Samples')

# ax.set_xlim((0, 20))


plt.savefig('Fig_hisplot_acc_seg2d.pdf', bbox_inches='tight')

# %%
diff = np.mean(np.abs(estim_seg2d_sens - np.tile(gt_seg2d_sens, (36, 1))), axis = 1)
# 195, 12
#
estim_alg = ["AC", "TS", "DoC", "ATC", "TS-ATC"]
#
diff_existing = diff[existing_index_full]
select_index = np.argmin(diff_existing)
#
baseline_MCP_AC = estim_seg2d_sens[0, :]
existing_best = estim_seg2d_sens[existing_index_full[select_index], :]
moval_ensemb = estim_seg2d_sens_ensemb[0, :]
gt_acc = gt_seg2d_sens[0, :]
#
sns.set_theme(style="darkgrid")

# Create the JointGrid
g = sns.JointGrid()
g.ax_joint.set_xlim([0., 100.])
g.ax_joint.set_ylim([0., 100.])

# Plot the first dataset
sns.scatterplot(x=baseline_MCP_AC[:65], y=gt_acc[:65], color='#d3d3d3', marker='x', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[65:], y=gt_acc[65:], color='#d3d3d3', marker='o', ax=g.ax_joint)
sns.regplot(x=baseline_MCP_AC, y=gt_acc, color='#d3d3d3', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Baseline: MCP | AC')
sns.kdeplot(x=baseline_MCP_AC, fill=True, color='#d3d3d3', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the second dataset
sns.scatterplot(x=existing_best[:65], y=gt_acc[:65], color='grey', marker='x', ax=g.ax_joint)
sns.scatterplot(x=existing_best[65:], y=gt_acc[65:], color='grey', marker='o', ax=g.ax_joint)
sns.regplot(x=existing_best, y=gt_acc, color='grey', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Existing Best: MCP | ' + estim_alg[select_index])
sns.kdeplot(x=existing_best, fill=True, color='grey', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the third dataset
sns.regplot(x=moval_ensemb, y=gt_acc, color='#1f77b4', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='MOVAL Ensemble')
sns.scatterplot(x=moval_ensemb[:65], y=gt_acc[:65], color='#1f77b4', marker='x', ax=g.ax_joint, label='Cardiac Synthetic')
sns.scatterplot(x=moval_ensemb[65:], y=gt_acc[65:], color='#1f77b4', marker='o', ax=g.ax_joint, label='Cardiac Natural')
sns.kdeplot(x=moval_ensemb, fill=True, color='#1f77b4', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Add the reference line y=x
g.ax_joint.axline((0, 0), slope=1, color='black', linestyle='--', label='y = x')

# Clear the y marginal plot and remove its axis
g.ax_marg_y.clear()
g.ax_marg_y.axis('off')

# Set axis labels
g.ax_joint.set_xlabel("Predicted Sensitivity")
g.ax_joint.set_ylabel("Real Sensitivity")

sns.kdeplot(x=gt_acc, color='black', ax=g.ax_marg_x, label='Real Label Distribution')
g.ax_marg_x.set_ylim((0,0.1))
g.ax_marg_x.legend(loc='upper left')

# Combine legends from all plots
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, loc='best')

# Add title to the figure
plt.suptitle("Sensitivity Estimation for 2D Segmentation Tasks", y=1.02)

plt.savefig('Fig_lineplot_sensitivity_seg2d.pdf', bbox_inches='tight')

# %%
diff_abs_baseline = np.abs(baseline_MCP_AC-gt_acc)
diff_abs_existing_best = np.abs(existing_best-gt_acc)
diff_abs_moval_ensemb = np.abs(moval_ensemb-gt_acc)

sns.set(rc={'figure.figsize':(6,2)})
sns.set_theme(style="darkgrid")
# Create a figure and a single set of axes
fig, ax = plt.subplots()

# Calculate the bin edges to ensure the same bin size for all histograms
min_val = min(diff_abs_baseline.min(), diff_abs_existing_best.min(), diff_abs_moval_ensemb.min())
max_val = max(diff_abs_baseline.max(), diff_abs_existing_best.max(), diff_abs_moval_ensemb.max())
bin_edges = np.linspace(0, 100, 100)

# Plot each distribution on the same axes
sns.histplot(diff_abs_baseline, color='#d3d3d3', label='Baseline: MCP | AC', kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_existing_best, color='grey', label='Existing Best: MCP | ' + estim_alg[select_index], kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_moval_ensemb, color='#1f77b4', label='MOVAL Ensemble', kde=True, bins=bin_edges, ax=ax)

mean_baseline = diff_abs_baseline.mean()
mean_existing_best = diff_abs_existing_best.mean()
mean_moval_ensemb = diff_abs_moval_ensemb.mean()

# Plot stars for means
ax.plot(mean_baseline, 4.5, '*', color='#d3d3d3', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_existing_best, 13.5, '*', color='grey', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_moval_ensemb, 4.5, '*', color='#1f77b4', markeredgecolor='black', markeredgewidth=1, markersize=15, label='Mean')

# Add legend for histograms
legend_hists = ax.legend(loc='upper right')

# Add both legends to the plot
ax.add_artist(legend_hists)

ax.set_xlabel('MAE')
ax.set_ylabel('Number of Samples')

ax.set_xlim((0, 30))

plt.savefig('Fig_hisplot_sens_seg2d.pdf', bbox_inches='tight')

# %%
diff = np.mean(np.abs(estim_seg2d_prec - np.tile(gt_seg2d_prec, (20, 1))), axis = 1)
# 195, 12
#
estim_alg = ["AC", "TS", "DoC", "ATC", "TS-ATC"]
#
diff_existing = diff[existing_index_FP]
select_index = np.argmin(diff_existing)
#
baseline_MCP_AC = estim_seg2d_prec[0, :]
existing_best = estim_seg2d_prec[existing_index_full[select_index], :]
moval_ensemb = estim_seg2d_prec_ensemb[0, :]
gt_acc = gt_seg2d_prec[0, :]
#
sns.set_theme(style="darkgrid")

# Create the JointGrid
g = sns.JointGrid()
g.ax_joint.set_xlim([0., 100.])
g.ax_joint.set_ylim([0., 100.])

# Plot the first dataset
sns.scatterplot(x=baseline_MCP_AC[:65], y=gt_acc[:65], color='#d3d3d3', marker='x', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[65:], y=gt_acc[65:], color='#d3d3d3', marker='o', ax=g.ax_joint)
sns.regplot(x=baseline_MCP_AC, y=gt_acc, color='#d3d3d3', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Baseline: MCP | AC')
sns.kdeplot(x=baseline_MCP_AC, fill=True, color='#d3d3d3', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the second dataset
sns.scatterplot(x=existing_best[:65], y=gt_acc[:65], color='grey', marker='x', ax=g.ax_joint)
sns.scatterplot(x=existing_best[65:], y=gt_acc[65:], color='grey', marker='o', ax=g.ax_joint)
sns.regplot(x=existing_best, y=gt_acc, color='grey', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Existing Best: MCP | ' + estim_alg[select_index])
sns.kdeplot(x=existing_best, fill=True, color='grey', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the third dataset
sns.regplot(x=moval_ensemb, y=gt_acc, color='#1f77b4', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='MOVAL Ensemble')
sns.scatterplot(x=moval_ensemb[:65], y=gt_acc[:65], color='#1f77b4', marker='x', ax=g.ax_joint, label='Cardiac Synthetic')
sns.scatterplot(x=moval_ensemb[65:], y=gt_acc[65:], color='#1f77b4', marker='o', ax=g.ax_joint, label='Cardiac Natural')
sns.kdeplot(x=moval_ensemb, fill=True, color='#1f77b4', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Add the reference line y=x
g.ax_joint.axline((0, 0), slope=1, color='black', linestyle='--', label='y = x')

# Clear the y marginal plot and remove its axis
g.ax_marg_y.clear()
g.ax_marg_y.axis('off')

# Set axis labels
g.ax_joint.set_xlabel("Predicted Precision")
g.ax_joint.set_ylabel("Real Precision")

sns.kdeplot(x=gt_acc, color='black', ax=g.ax_marg_x, label='Real Label Distribution')
g.ax_marg_x.legend(loc='upper left')

# Combine legends from all plots
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, loc='best')

# Add title to the figure
plt.suptitle("Precision Estimation for 2D Segmentation Tasks", y=1.02)

plt.savefig('Fig_lineplot_precision_seg2d.pdf', bbox_inches='tight')

# %%
diff_abs_baseline = np.abs(baseline_MCP_AC-gt_acc)
diff_abs_existing_best = np.abs(existing_best-gt_acc)
diff_abs_moval_ensemb = np.abs(moval_ensemb-gt_acc)

sns.set(rc={'figure.figsize':(6,2)})
sns.set_theme(style="darkgrid")
# Create a figure and a single set of axes
fig, ax = plt.subplots()

# Calculate the bin edges to ensure the same bin size for all histograms
min_val = min(diff_abs_baseline.min(), diff_abs_existing_best.min(), diff_abs_moval_ensemb.min())
max_val = max(diff_abs_baseline.max(), diff_abs_existing_best.max(), diff_abs_moval_ensemb.max())
bin_edges = np.linspace(0, 100, 100)

# Plot each distribution on the same axes
sns.histplot(diff_abs_baseline, color='#d3d3d3', label='Baseline: MCP | AC', kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_existing_best, color='grey', label='Existing Best: MCP | ' + estim_alg[select_index], kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_moval_ensemb, color='#1f77b4', label='MOVAL Ensemble', kde=True, bins=bin_edges, ax=ax)

mean_baseline = diff_abs_baseline.mean()
mean_existing_best = diff_abs_existing_best.mean()
mean_moval_ensemb = diff_abs_moval_ensemb.mean()

# Plot stars for means
ax.plot(mean_baseline, 16.5, '*', color='#d3d3d3', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_existing_best, 5.5, '*', color='grey', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_moval_ensemb, 5.5, '*', color='#1f77b4', markeredgecolor='black', markeredgewidth=1, markersize=15, label='Mean')

# Add legend for histograms
legend_hists = ax.legend(loc='upper right')

# Add both legends to the plot
ax.add_artist(legend_hists)

ax.set_xlabel('MAE')
ax.set_ylabel('Number of Samples')

ax.set_xlim((0, 30))

plt.savefig('Fig_hisplot_prec_seg2d.pdf', bbox_inches='tight')

# %%
diff = np.mean(np.abs(estim_seg2d_f1 - np.tile(gt_seg2d_f1, (36, 1))), axis = 1)
# 195, 12
#
estim_alg = ["AC", "TS", "DoC", "ATC", "TS-ATC"]
#
diff_existing = diff[existing_index_full]
select_index = np.argmin(diff_existing)
#
baseline_MCP_AC = estim_seg2d_f1[0, :]
existing_best = estim_seg2d_f1[existing_index_full[select_index], :]
moval_ensemb = estim_seg2d_f1_ensemb[0, :]
gt_acc = gt_seg2d_f1[0, :]
#
sns.set_theme(style="darkgrid")

# Create the JointGrid
g = sns.JointGrid()
g.ax_joint.set_xlim([0., 100.])
g.ax_joint.set_ylim([0., 100.])

# Plot the first dataset
sns.scatterplot(x=baseline_MCP_AC[:65], y=gt_acc[:65], color='#d3d3d3', marker='x', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[65:], y=gt_acc[65:], color='#d3d3d3', marker='o', ax=g.ax_joint)
sns.regplot(x=baseline_MCP_AC, y=gt_acc, color='#d3d3d3', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Baseline: MCP | AC')
sns.kdeplot(x=baseline_MCP_AC, fill=True, color='#d3d3d3', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the second dataset
sns.scatterplot(x=existing_best[:65], y=gt_acc[:65], color='grey', marker='x', ax=g.ax_joint)
sns.scatterplot(x=existing_best[65:], y=gt_acc[65:], color='grey', marker='o', ax=g.ax_joint)
sns.regplot(x=existing_best, y=gt_acc, color='grey', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Existing Best: MCP | ' + estim_alg[select_index])
sns.kdeplot(x=existing_best, fill=True, color='grey', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the third dataset
sns.regplot(x=moval_ensemb, y=gt_acc, color='#1f77b4', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='MOVAL Ensemble')
sns.scatterplot(x=moval_ensemb[:65], y=gt_acc[:65], color='#1f77b4', marker='x', ax=g.ax_joint, label='Cardiac Synthetic')
sns.scatterplot(x=moval_ensemb[65:], y=gt_acc[65:], color='#1f77b4', marker='o', ax=g.ax_joint, label='Cardiac Natural')
sns.kdeplot(x=moval_ensemb, fill=True, color='#1f77b4', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Add the reference line y=x
g.ax_joint.axline((0, 0), slope=1, color='black', linestyle='--', label='y = x')

# Clear the y marginal plot and remove its axis
g.ax_marg_y.clear()
g.ax_marg_y.axis('off')

# Set axis labels
g.ax_joint.set_xlabel("Predicted F1-Score")
g.ax_joint.set_ylabel("Real F1-Score")

sns.kdeplot(x=gt_acc, color='black', ax=g.ax_marg_x, label='Real Label Distribution')
g.ax_marg_x.set_ylim((0,0.2))
g.ax_marg_x.legend(loc='upper left')

# Combine legends from all plots
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, loc='best')

# Add title to the figure
plt.suptitle("F1-Score Estimation for 2D Segmentation Tasks", y=1.02)

plt.savefig('Fig_lineplot_f1_seg2d.pdf', bbox_inches='tight')

# %%
diff_abs_baseline = np.abs(baseline_MCP_AC-gt_acc)
diff_abs_existing_best = np.abs(existing_best-gt_acc)
diff_abs_moval_ensemb = np.abs(moval_ensemb-gt_acc)

sns.set(rc={'figure.figsize':(6,2)})
sns.set_theme(style="darkgrid")
# Create a figure and a single set of axes
fig, ax = plt.subplots()

# Calculate the bin edges to ensure the same bin size for all histograms
min_val = min(diff_abs_baseline.min(), diff_abs_existing_best.min(), diff_abs_moval_ensemb.min())
max_val = max(diff_abs_baseline.max(), diff_abs_existing_best.max(), diff_abs_moval_ensemb.max())
bin_edges = np.linspace(0, 100, 100)

# Plot each distribution on the same axes
sns.histplot(diff_abs_baseline, color='#d3d3d3', label='Baseline: MCP | AC', kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_existing_best, color='grey', label='Existing Best: MCP | ' + estim_alg[select_index], kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_moval_ensemb, color='#1f77b4', label='MOVAL Ensemble', kde=True, bins=bin_edges, ax=ax)

mean_baseline = diff_abs_baseline.mean()
mean_existing_best = diff_abs_existing_best.mean()
mean_moval_ensemb = diff_abs_moval_ensemb.mean()

# Plot stars for means
ax.plot(mean_baseline, 4, '*', color='#d3d3d3', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_existing_best, 4, '*', color='grey', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_moval_ensemb, 4, '*', color='#1f77b4', markeredgecolor='black', markeredgewidth=1, markersize=15, label='Mean')

# Add legend for histograms
legend_hists = ax.legend(loc='upper right')

# Add both legends to the plot
ax.add_artist(legend_hists)

ax.set_xlabel('MAE')
ax.set_ylabel('Number of Samples')

ax.set_xlim((0, 30))

plt.savefig('Fig_hisplot_f1_seg2d.pdf', bbox_inches='tight')

# %%
diff = np.mean(np.abs(estim_seg2d_auc - np.tile(gt_seg2d_auc, (20, 1))), axis = 1)
# 195, 12
#
estim_alg = ["AC", "TS", "DoC", "ATC", "TS-ATC"]
#
diff_existing = diff[existing_index_FP]
select_index = np.argmin(diff_existing)
#
baseline_MCP_AC = estim_seg2d_auc[0, :]
existing_best = estim_seg2d_auc[existing_index_full[select_index], :]
moval_ensemb = estim_seg2d_auc_ensemb[0, :]
gt_acc = gt_seg2d_auc[0, :]
#
sns.set_theme(style="darkgrid")

# Create the JointGrid
g = sns.JointGrid()
g.ax_joint.set_xlim([0., 100.])
g.ax_joint.set_ylim([0., 100.])

# Plot the first dataset
sns.scatterplot(x=baseline_MCP_AC[:65], y=gt_acc[:65], color='#d3d3d3', marker='x', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[65:], y=gt_acc[65:], color='#d3d3d3', marker='o', ax=g.ax_joint)
sns.regplot(x=baseline_MCP_AC, y=gt_acc, color='#d3d3d3', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Baseline: MCP | AC')
sns.kdeplot(x=baseline_MCP_AC, fill=True, color='#d3d3d3', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the second dataset
sns.scatterplot(x=existing_best[:65], y=gt_acc[:65], color='grey', marker='x', ax=g.ax_joint)
sns.scatterplot(x=existing_best[65:], y=gt_acc[65:], color='grey', marker='o', ax=g.ax_joint)
sns.regplot(x=existing_best, y=gt_acc, color='grey', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Existing Best: MCP | ' + estim_alg[select_index])
sns.kdeplot(x=existing_best, fill=True, color='grey', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the third dataset
sns.regplot(x=moval_ensemb, y=gt_acc, color='#1f77b4', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='MOVAL Ensemble')
sns.scatterplot(x=moval_ensemb[:65], y=gt_acc[:65], color='#1f77b4', marker='x', ax=g.ax_joint, label='Cardiac Synthetic')
sns.scatterplot(x=moval_ensemb[65:], y=gt_acc[65:], color='#1f77b4', marker='o', ax=g.ax_joint, label='Cardiac Natural')
sns.kdeplot(x=moval_ensemb, fill=True, color='#1f77b4', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Add the reference line y=x
g.ax_joint.axline((0, 0), slope=1, color='black', linestyle='--', label='y = x')

# Clear the y marginal plot and remove its axis
g.ax_marg_y.clear()
g.ax_marg_y.axis('off')

# Set axis labels
g.ax_joint.set_xlabel("Predicted AUC")
g.ax_joint.set_ylabel("Real AUC")

sns.kdeplot(x=gt_acc, color='black', ax=g.ax_marg_x, label='Real Label Distribution')
g.ax_marg_x.legend(loc='upper left')

# Combine legends from all plots
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, loc='best')

# Add title to the figure
plt.suptitle("AUC Estimation for 2D Segmentation Tasks", y=1.02)

plt.savefig('Fig_lineplot_auc_seg2d.pdf', bbox_inches='tight')

# %%
diff_abs_baseline = np.abs(baseline_MCP_AC-gt_acc)
diff_abs_existing_best = np.abs(existing_best-gt_acc)
diff_abs_moval_ensemb = np.abs(moval_ensemb-gt_acc)

sns.set(rc={'figure.figsize':(6,2)})
sns.set_theme(style="darkgrid")
# Create a figure and a single set of axes
fig, ax = plt.subplots()

# Calculate the bin edges to ensure the same bin size for all histograms
min_val = min(diff_abs_baseline.min(), diff_abs_existing_best.min(), diff_abs_moval_ensemb.min())
max_val = max(diff_abs_baseline.max(), diff_abs_existing_best.max(), diff_abs_moval_ensemb.max())
bin_edges = np.linspace(min_val, max_val, 30)

# Plot each distribution on the same axes
sns.histplot(diff_abs_baseline, color='#d3d3d3', label='Baseline: MCP | AC', kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_existing_best, color='grey', label='Existing Best: MCP | ' + estim_alg[select_index], kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_moval_ensemb, color='#1f77b4', label='MOVAL Ensemble', kde=True, bins=bin_edges, ax=ax)

mean_baseline = diff_abs_baseline.mean()
mean_existing_best = diff_abs_existing_best.mean()
mean_moval_ensemb = diff_abs_moval_ensemb.mean()

# Plot stars for means
ax.plot(mean_baseline, 3.5, '*', color='#d3d3d3', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_existing_best, 3.5, '*', color='grey', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_moval_ensemb, 3.5, '*', color='#1f77b4', markeredgecolor='black', markeredgewidth=1, markersize=15, label='Mean')

# Add legend for histograms
legend_hists = ax.legend(loc='upper right')

# Add both legends to the plot
ax.add_artist(legend_hists)

ax.set_xlabel('MAE')
ax.set_ylabel('Number of Samples')


plt.savefig('Fig_hisplot_auc_seg2d.pdf', bbox_inches='tight')

# %%
# do for seg3d

# %%
estim_seg3d_acc = np.concatenate((prostate_syn_acc_res, prostate_nat_acc_res,
                                  brain_syn_acc_res, brain_nat_acc_res), axis = 0)[:, :, 0, 0].transpose((1, 0))
estim_seg3d_acc_ensemb = np.concatenate((prostate_syn_acc_res_ensemble, prostate_nat_acc_res_ensemble,
                                        brain_syn_acc_res_ensemble, brain_nat_acc_res_ensemble), axis = 0)[:, :, 0, 0].transpose((1, 0))
gt_seg3d_acc = np.concatenate((prostate_syn_acc_gt[:, 0:1, :, :], prostate_nat_acc_gt[:, 0:1, :, :], 
                              brain_syn_acc_gt[:, 0:1, :, :], brain_nat_acc_gt[:, 0:1, :, :]), axis = 0)[:, :, 0, 0].transpose((1, 0))
#
estim_seg3d_sens = np.concatenate((prostate_syn_sens_res.transpose((1, 0, 2, 3)).reshape([36, -1]), 
                                   prostate_nat_sens_res.transpose((1, 0, 2, 3)).reshape([36, -1]),
                                   brain_syn_sens_res.transpose((1, 0, 2, 3)).reshape([36, -1]), 
                                   brain_nat_sens_res.transpose((1, 0, 2, 3)).reshape([36, -1]),), axis = 1)
estim_seg3d_sens_ensemb = np.concatenate((prostate_syn_sens_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                          prostate_nat_sens_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]),
                                          brain_syn_sens_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                          brain_nat_sens_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)
gt_seg3d_sens = np.concatenate((prostate_syn_sens_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                               prostate_nat_sens_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]),
                               brain_syn_sens_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]),
                               brain_nat_sens_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)
#
estim_seg3d_prec = np.concatenate((prostate_syn_prec_res.transpose((1, 0, 2, 3)).reshape([20, -1]), 
                                   prostate_nat_prec_res.transpose((1, 0, 2, 3)).reshape([20, -1]),
                                   brain_syn_prec_res.transpose((1, 0, 2, 3)).reshape([20, -1]), 
                                   brain_nat_prec_res.transpose((1, 0, 2, 3)).reshape([20, -1]),), axis = 1)
estim_seg3d_prec_ensemb = np.concatenate((prostate_syn_prec_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                          prostate_nat_prec_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]),
                                          brain_syn_prec_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                          brain_nat_prec_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)
gt_seg3d_prec = np.concatenate((prostate_syn_prec_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                               prostate_nat_prec_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]),
                               brain_syn_prec_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]),
                               brain_nat_prec_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)
#
estim_seg3d_f1 = np.concatenate((prostate_syn_f1_res.transpose((1, 0, 2, 3)).reshape([36, -1]), 
                                   prostate_nat_f1_res.transpose((1, 0, 2, 3)).reshape([36, -1]),
                                   brain_syn_f1_res.transpose((1, 0, 2, 3)).reshape([36, -1]), 
                                   brain_nat_f1_res.transpose((1, 0, 2, 3)).reshape([36, -1]),), axis = 1)
estim_seg3d_f1_ensemb = np.concatenate((prostate_syn_f1_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                          prostate_nat_f1_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]),
                                          brain_syn_f1_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                          brain_nat_f1_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)
gt_seg3d_f1 = np.concatenate((prostate_syn_f1_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                               prostate_nat_f1_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]),
                               brain_syn_f1_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]),
                               brain_nat_f1_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)
#
estim_seg3d_auc = np.concatenate((prostate_syn_auc_res.transpose((1, 0, 2, 3)).reshape([20, -1]), 
                                   prostate_nat_auc_res.transpose((1, 0, 2, 3)).reshape([20, -1]),
                                   brain_syn_auc_res.transpose((1, 0, 2, 3)).reshape([20, -1]), 
                                   brain_nat_auc_res.transpose((1, 0, 2, 3)).reshape([20, -1]),), axis = 1)
estim_seg3d_auc_ensemb = np.concatenate((prostate_syn_auc_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                          prostate_nat_auc_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]),
                                          brain_syn_auc_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1]), 
                                          brain_nat_auc_res_ensemble.transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)
gt_seg3d_auc = np.concatenate((prostate_syn_auc_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]), 
                               prostate_nat_auc_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]),
                               brain_syn_auc_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1]),
                               brain_nat_auc_gt[:, 0:1, :, :].transpose((1, 0, 2, 3)).reshape([1, -1])), axis = 1)

# %%
diff = np.mean(np.abs(estim_seg3d_acc - np.tile(gt_seg3d_acc, (36, 1))), axis = 1)
# 83, 5, 83, 12
#
diff_existing = diff[existing_index_full]
select_index = np.argmin(diff_existing)
#
baseline_MCP_AC = estim_seg3d_acc[0, :]
existing_best = estim_seg3d_acc[existing_index_full[select_index], :]
moval_ensemb = estim_seg3d_acc_ensemb[0, :]
gt_acc = gt_seg3d_acc[0, :]

# %%
sns.set_theme(style="darkgrid")

# Create the JointGrid
g = sns.JointGrid()
g.ax_joint.set_xlim([0., 100.])
g.ax_joint.set_ylim([0., 100.])

# Plot the first dataset
sns.scatterplot(x=baseline_MCP_AC[:83], y=gt_acc[:83], color='#d3d3d3', marker='*', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[83:83+5], y=gt_acc[83:83+5], color='#d3d3d3', marker='x', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[83+5:83+5+83], y=gt_acc[83+5:83+5+83], color='#d3d3d3', marker='.', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[83+5+83:], y=gt_acc[83+5+83:], color='#d3d3d3', marker='o', ax=g.ax_joint)
sns.regplot(x=baseline_MCP_AC, y=gt_acc, color='#d3d3d3', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Baseline: MCP | AC')
sns.kdeplot(x=baseline_MCP_AC, fill=True, color='#d3d3d3', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the second dataset
sns.scatterplot(x=existing_best[:83], y=gt_acc[:83], color='grey', marker='*', ax=g.ax_joint)
sns.scatterplot(x=existing_best[83:83+5], y=gt_acc[83:83+5], color='grey', marker='x', ax=g.ax_joint)
sns.scatterplot(x=existing_best[83+5:83+5+83], y=gt_acc[83+5:83+5+83], color='grey', marker='.', ax=g.ax_joint)
sns.scatterplot(x=existing_best[83+5+83:], y=gt_acc[83+5+83:], color='grey', marker='o', ax=g.ax_joint)
sns.regplot(x=existing_best, y=gt_acc, color='grey', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Existing Best: MCP | ' + estim_alg[select_index])
sns.kdeplot(x=existing_best, fill=True, color='grey', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the third dataset
sns.regplot(x=moval_ensemb, y=gt_acc, color='#1f77b4', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='MOVAL Ensemble')
sns.scatterplot(x=moval_ensemb[:83], y=gt_acc[:83], color='#1f77b4', marker='*', ax=g.ax_joint, label='Prostate Synthetic')
sns.scatterplot(x=moval_ensemb[83:83+5], y=gt_acc[83:83+5], color='#1f77b4', marker='x', ax=g.ax_joint, label='Prostate Natural')
sns.scatterplot(x=moval_ensemb[83+5:83+5+83], y=gt_acc[83+5:83+5+83], color='#1f77b4', marker='.', ax=g.ax_joint, label='Brain Lesion Synthetic')
sns.scatterplot(x=moval_ensemb[83+5+83:], y=gt_acc[83+5+83:], color='#1f77b4', marker='o', ax=g.ax_joint, label='Brain Lesion Natural')
sns.kdeplot(x=moval_ensemb, fill=True, color='#1f77b4', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Add the reference line y=x
g.ax_joint.axline((0, 0), slope=1, color='black', linestyle='--', label='y = x')

# Clear the y marginal plot and remove its axis
g.ax_marg_y.clear()
g.ax_marg_y.axis('off')

# Set axis labels
g.ax_joint.set_xlabel("Predicted Accuracy")
g.ax_joint.set_ylabel("Real Accuracy")

sns.kdeplot(x=gt_acc, color='black', ax=g.ax_marg_x, label='Real Label Distribution')
g.ax_marg_x.legend(loc='upper left')

# Combine legends from all plots
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, loc='best')

# Add title to the figure
plt.suptitle("Accuracy Estimation for 3D Segmentation Tasks", y=1.02)

plt.savefig('Fig_lineplot_acc_seg3d.pdf', bbox_inches='tight')

# %%
diff_abs_baseline = np.abs(baseline_MCP_AC-gt_acc)
diff_abs_existing_best = np.abs(existing_best-gt_acc)
diff_abs_moval_ensemb = np.abs(moval_ensemb-gt_acc)

sns.set(rc={'figure.figsize':(6,2)})
sns.set_theme(style="darkgrid")
# Create a figure and a single set of axes
fig, ax = plt.subplots()

# Calculate the bin edges to ensure the same bin size for all histograms
min_val = min(diff_abs_baseline.min(), diff_abs_existing_best.min(), diff_abs_moval_ensemb.min())
max_val = max(diff_abs_baseline.max(), diff_abs_existing_best.max(), diff_abs_moval_ensemb.max())
bin_edges = np.linspace(min_val, max_val, 30)

# Plot each distribution on the same axes
sns.histplot(diff_abs_baseline, color='#d3d3d3', label='Baseline: MCP | AC', kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_existing_best, color='grey', label='Existing Best: MCP | ' + estim_alg[select_index], kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_moval_ensemb, color='#1f77b4', label='MOVAL Ensemble', kde=True, bins=bin_edges, ax=ax)

mean_baseline = diff_abs_baseline.mean()
mean_existing_best = diff_abs_existing_best.mean()
mean_moval_ensemb = diff_abs_moval_ensemb.mean()

# Plot stars for means
ax.plot(mean_baseline, 10, '*', color='#d3d3d3', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_existing_best, 10, '*', color='grey', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_moval_ensemb, 10, '*', color='#1f77b4', markeredgecolor='black', markeredgewidth=1, markersize=15, label='Mean')

# Add legend for histograms
legend_hists = ax.legend(loc='upper right')

# Add both legends to the plot
ax.add_artist(legend_hists)

ax.set_xlabel('MAE')
ax.set_ylabel('Number of Samples')


plt.savefig('Fig_hisplot_acc_seg3d.pdf', bbox_inches='tight')

# %%
diff = np.mean(np.abs(estim_seg3d_sens - np.tile(gt_seg3d_sens, (36, 1))), axis = 1)
# 83, 5, 83, 12
#
estim_alg = ["AC", "TS", "DoC", "ATC", "TS-ATC"]
#
diff_existing = diff[existing_index_full]
select_index = np.argmin(diff_existing)
#
baseline_MCP_AC = estim_seg3d_sens[0, :]
existing_best = estim_seg3d_sens[existing_index_full[select_index], :]
moval_ensemb = estim_seg3d_sens_ensemb[0, :]
gt_acc = gt_seg3d_sens[0, :]
#
sns.set_theme(style="darkgrid")

# Create the JointGrid
g = sns.JointGrid()
g.ax_joint.set_xlim([0., 100.])
g.ax_joint.set_ylim([0., 100.])

# Plot the first dataset
sns.scatterplot(x=baseline_MCP_AC[:83], y=gt_acc[:83], color='#d3d3d3', marker='*', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[83:83+5], y=gt_acc[83:83+5], color='#d3d3d3', marker='x', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[83+5:83+5+83], y=gt_acc[83+5:83+5+83], color='#d3d3d3', marker='.', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[83+5+83:], y=gt_acc[83+5+83:], color='#d3d3d3', marker='o', ax=g.ax_joint)
sns.regplot(x=baseline_MCP_AC, y=gt_acc, color='#d3d3d3', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Baseline: MCP | AC')
sns.kdeplot(x=baseline_MCP_AC, fill=True, color='#d3d3d3', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the second dataset
sns.scatterplot(x=existing_best[:83], y=gt_acc[:83], color='grey', marker='*', ax=g.ax_joint)
sns.scatterplot(x=existing_best[83:83+5], y=gt_acc[83:83+5], color='grey', marker='x', ax=g.ax_joint)
sns.scatterplot(x=existing_best[83+5:83+5+83], y=gt_acc[83+5:83+5+83], color='grey', marker='.', ax=g.ax_joint)
sns.scatterplot(x=existing_best[83+5+83:], y=gt_acc[83+5+83:], color='grey', marker='o', ax=g.ax_joint)
sns.regplot(x=existing_best, y=gt_acc, color='grey', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Existing Best: MCP | ' + estim_alg[select_index])
sns.kdeplot(x=existing_best, fill=True, color='grey', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the third dataset
sns.regplot(x=moval_ensemb, y=gt_acc, color='#1f77b4', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='MOVAL Ensemble')
sns.scatterplot(x=moval_ensemb[:83], y=gt_acc[:83], color='#1f77b4', marker='*', ax=g.ax_joint, label='Prostate Synthetic')
sns.scatterplot(x=moval_ensemb[83:83+5], y=gt_acc[83:83+5], color='#1f77b4', marker='x', ax=g.ax_joint, label='Prostate Natural')
sns.scatterplot(x=moval_ensemb[83+5:83+5+83], y=gt_acc[83+5:83+5+83], color='#1f77b4', marker='.', ax=g.ax_joint, label='Brain Lesion Synthetic')
sns.scatterplot(x=moval_ensemb[83+5+83:], y=gt_acc[83+5+83:], color='#1f77b4', marker='o', ax=g.ax_joint, label='Brain Lesion Natural')
sns.kdeplot(x=moval_ensemb, fill=True, color='#1f77b4', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Add the reference line y=x
g.ax_joint.axline((0, 0), slope=1, color='black', linestyle='--', label='y = x')

# Clear the y marginal plot and remove its axis
g.ax_marg_y.clear()
g.ax_marg_y.axis('off')

# Set axis labels
g.ax_joint.set_xlabel("Predicted Sensitivity")
g.ax_joint.set_ylabel("Real Sensitivity")

sns.kdeplot(x=gt_acc, color='black', ax=g.ax_marg_x, label='Real Label Distribution')
g.ax_marg_x.set_ylim((0,0.15))
g.ax_marg_x.legend(loc='upper left')

# Combine legends from all plots
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, loc='best')

# Add title to the figure
plt.suptitle("Sensitivity Estimation for 3D Segmentation Tasks", y=1.02)

plt.savefig('Fig_lineplot_sensitivity_seg3d.pdf', bbox_inches='tight')

# %%
diff_abs_baseline = np.abs(baseline_MCP_AC-gt_acc)
diff_abs_existing_best = np.abs(existing_best-gt_acc)
diff_abs_moval_ensemb = np.abs(moval_ensemb-gt_acc)

sns.set(rc={'figure.figsize':(6,2)})
sns.set_theme(style="darkgrid")
# Create a figure and a single set of axes
fig, ax = plt.subplots()

# Calculate the bin edges to ensure the same bin size for all histograms
min_val = min(diff_abs_baseline.min(), diff_abs_existing_best.min(), diff_abs_moval_ensemb.min())
max_val = max(diff_abs_baseline.max(), diff_abs_existing_best.max(), diff_abs_moval_ensemb.max())
bin_edges = np.linspace(0, 100, 100)

# Plot each distribution on the same axes
sns.histplot(diff_abs_baseline, color='#d3d3d3', label='Baseline: MCP | AC', kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_existing_best, color='grey', label='Existing Best: MCP | ' + estim_alg[select_index], kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_moval_ensemb, color='#1f77b4', label='MOVAL Ensemble', kde=True, bins=bin_edges, ax=ax)

mean_baseline = diff_abs_baseline.mean()
mean_existing_best = diff_abs_existing_best.mean()
mean_moval_ensemb = diff_abs_moval_ensemb.mean()

# Plot stars for means
ax.plot(mean_baseline, 4, '*', color='#d3d3d3', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_existing_best, 4, '*', color='grey', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_moval_ensemb, 4, '*', color='#1f77b4', markeredgecolor='black', markeredgewidth=1, markersize=15, label='Mean')

# Add legend for histograms
legend_hists = ax.legend(loc='upper right')

# Add both legends to the plot
ax.add_artist(legend_hists)

ax.set_xlabel('MAE')
ax.set_ylabel('Number of Samples')

ax.set_xlim((0, 30))

plt.savefig('Fig_hisplot_sens_seg3d.pdf', bbox_inches='tight')

# %%
diff = np.mean(np.abs(estim_seg3d_prec - np.tile(gt_seg3d_prec, (20, 1))), axis = 1)
# 83, 5, 83, 12
#
estim_alg = ["AC", "TS", "DoC", "ATC", "TS-ATC"]
#
diff_existing = diff[existing_index_FP]
select_index = np.argmin(diff_existing)
#
baseline_MCP_AC = estim_seg3d_prec[0, :]
existing_best = estim_seg3d_prec[existing_index_full[select_index], :]
moval_ensemb = estim_seg3d_prec_ensemb[0, :]
gt_acc = gt_seg3d_prec[0, :]
#
sns.set_theme(style="darkgrid")

# Create the JointGrid
g = sns.JointGrid()
g.ax_joint.set_xlim([0., 100.])
g.ax_joint.set_ylim([0., 100.])

# Plot the first dataset
sns.scatterplot(x=baseline_MCP_AC[:83], y=gt_acc[:83], color='#d3d3d3', marker='*', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[83:83+5], y=gt_acc[83:83+5], color='#d3d3d3', marker='x', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[83+5:83+5+83], y=gt_acc[83+5:83+5+83], color='#d3d3d3', marker='.', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[83+5+83:], y=gt_acc[83+5+83:], color='#d3d3d3', marker='o', ax=g.ax_joint)
sns.regplot(x=baseline_MCP_AC, y=gt_acc, color='#d3d3d3', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Baseline: MCP | AC')
sns.kdeplot(x=baseline_MCP_AC, fill=True, color='#d3d3d3', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the second dataset
sns.scatterplot(x=existing_best[:83], y=gt_acc[:83], color='grey', marker='*', ax=g.ax_joint)
sns.scatterplot(x=existing_best[83:83+5], y=gt_acc[83:83+5], color='grey', marker='x', ax=g.ax_joint)
sns.scatterplot(x=existing_best[83+5:83+5+83], y=gt_acc[83+5:83+5+83], color='grey', marker='.', ax=g.ax_joint)
sns.scatterplot(x=existing_best[83+5+83:], y=gt_acc[83+5+83:], color='grey', marker='o', ax=g.ax_joint)
sns.regplot(x=existing_best, y=gt_acc, color='grey', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Existing Best: MCP | ' + estim_alg[select_index])
sns.kdeplot(x=existing_best, fill=True, color='grey', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the third dataset
sns.regplot(x=moval_ensemb, y=gt_acc, color='#1f77b4', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='MOVAL Ensemble')
sns.scatterplot(x=moval_ensemb[:83], y=gt_acc[:83], color='#1f77b4', marker='*', ax=g.ax_joint, label='Prostate Synthetic')
sns.scatterplot(x=moval_ensemb[83:83+5], y=gt_acc[83:83+5], color='#1f77b4', marker='x', ax=g.ax_joint, label='Prostate Natural')
sns.scatterplot(x=moval_ensemb[83+5:83+5+83], y=gt_acc[83+5:83+5+83], color='#1f77b4', marker='.', ax=g.ax_joint, label='Brain Lesion Synthetic')
sns.scatterplot(x=moval_ensemb[83+5+83:], y=gt_acc[83+5+83:], color='#1f77b4', marker='o', ax=g.ax_joint, label='Brain Lesion Natural')
sns.kdeplot(x=moval_ensemb, fill=True, color='#1f77b4', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Add the reference line y=x
g.ax_joint.axline((0, 0), slope=1, color='black', linestyle='--', label='y = x')

# Clear the y marginal plot and remove its axis
g.ax_marg_y.clear()
g.ax_marg_y.axis('off')

# Set axis labels
g.ax_joint.set_xlabel("Predicted Precision")
g.ax_joint.set_ylabel("Real Precision")

sns.kdeplot(x=gt_acc, color='black', ax=g.ax_marg_x, label='Real Label Distribution')
g.ax_marg_x.legend(loc='upper left')

# Combine legends from all plots
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, loc='best')

# Add title to the figure
plt.suptitle("Precision Estimation for 3D Segmentation Tasks", y=1.02)

plt.savefig('Fig_lineplot_precision_seg3d.pdf', bbox_inches='tight')

# %%
diff_abs_baseline = np.abs(baseline_MCP_AC-gt_acc)
diff_abs_existing_best = np.abs(existing_best-gt_acc)
diff_abs_moval_ensemb = np.abs(moval_ensemb-gt_acc)

sns.set(rc={'figure.figsize':(6,2)})
sns.set_theme(style="darkgrid")
# Create a figure and a single set of axes
fig, ax = plt.subplots()

# Calculate the bin edges to ensure the same bin size for all histograms
min_val = min(diff_abs_baseline.min(), diff_abs_existing_best.min(), diff_abs_moval_ensemb.min())
max_val = max(diff_abs_baseline.max(), diff_abs_existing_best.max(), diff_abs_moval_ensemb.max())
bin_edges = np.linspace(0, 100, 100)

# Plot each distribution on the same axes
sns.histplot(diff_abs_baseline, color='#d3d3d3', label='Baseline: MCP | AC', kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_existing_best, color='grey', label='Existing Best: MCP | ' + estim_alg[select_index], kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_moval_ensemb, color='#1f77b4', label='MOVAL Ensemble', kde=True, bins=bin_edges, ax=ax)

mean_baseline = diff_abs_baseline.mean()
mean_existing_best = diff_abs_existing_best.mean()
mean_moval_ensemb = diff_abs_moval_ensemb.mean()

# Plot stars for means
ax.plot(mean_baseline, 4, '*', color='#d3d3d3', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_existing_best, 4, '*', color='grey', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_moval_ensemb, 4, '*', color='#1f77b4', markeredgecolor='black', markeredgewidth=1, markersize=15, label='Mean')

# Add legend for histograms
legend_hists = ax.legend(loc='upper right')

# Add both legends to the plot
ax.add_artist(legend_hists)

ax.set_xlabel('MAE')
ax.set_ylabel('Number of Samples')

ax.set_xlim((0, 30))

plt.savefig('Fig_hisplot_prec_seg3d.pdf', bbox_inches='tight')

# %%
diff = np.mean(np.abs(estim_seg3d_f1 - np.tile(gt_seg3d_f1, (36, 1))), axis = 1)
# 83, 5, 83, 12
#
estim_alg = ["AC", "TS", "DoC", "ATC", "TS-ATC"]
#
diff_existing = diff[existing_index_full]
select_index = np.argmin(diff_existing)
#
baseline_MCP_AC = estim_seg3d_f1[0, :]
existing_best = estim_seg3d_f1[existing_index_full[select_index], :]
moval_ensemb = estim_seg3d_f1_ensemb[0, :]
gt_acc = gt_seg3d_f1[0, :]
#
sns.set_theme(style="darkgrid")

# Create the JointGrid
g = sns.JointGrid()
g.ax_joint.set_xlim([0., 100.])
g.ax_joint.set_ylim([0., 100.])

# Plot the first dataset
sns.scatterplot(x=baseline_MCP_AC[:83], y=gt_acc[:83], color='#d3d3d3', marker='*', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[83:83+5], y=gt_acc[83:83+5], color='#d3d3d3', marker='x', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[83+5:83+5+83], y=gt_acc[83+5:83+5+83], color='#d3d3d3', marker='.', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[83+5+83:], y=gt_acc[83+5+83:], color='#d3d3d3', marker='o', ax=g.ax_joint)
sns.regplot(x=baseline_MCP_AC, y=gt_acc, color='#d3d3d3', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Baseline: MCP | AC')
sns.kdeplot(x=baseline_MCP_AC, fill=True, color='#d3d3d3', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the second dataset
sns.scatterplot(x=existing_best[:83], y=gt_acc[:83], color='grey', marker='*', ax=g.ax_joint)
sns.scatterplot(x=existing_best[83:83+5], y=gt_acc[83:83+5], color='grey', marker='x', ax=g.ax_joint)
sns.scatterplot(x=existing_best[83+5:83+5+83], y=gt_acc[83+5:83+5+83], color='grey', marker='.', ax=g.ax_joint)
sns.scatterplot(x=existing_best[83+5+83:], y=gt_acc[83+5+83:], color='grey', marker='o', ax=g.ax_joint)
sns.regplot(x=existing_best, y=gt_acc, color='grey', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Existing Best: MCP | ' + estim_alg[select_index])
sns.kdeplot(x=existing_best, fill=True, color='grey', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the third dataset
sns.regplot(x=moval_ensemb, y=gt_acc, color='#1f77b4', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='MOVAL Ensemble')
sns.scatterplot(x=moval_ensemb[:83], y=gt_acc[:83], color='#1f77b4', marker='*', ax=g.ax_joint, label='Prostate Synthetic')
sns.scatterplot(x=moval_ensemb[83:83+5], y=gt_acc[83:83+5], color='#1f77b4', marker='x', ax=g.ax_joint, label='Prostate Natural')
sns.scatterplot(x=moval_ensemb[83+5:83+5+83], y=gt_acc[83+5:83+5+83], color='#1f77b4', marker='.', ax=g.ax_joint, label='Brain Lesion Synthetic')
sns.scatterplot(x=moval_ensemb[83+5+83:], y=gt_acc[83+5+83:], color='#1f77b4', marker='o', ax=g.ax_joint, label='Brain Lesion Natural')
sns.kdeplot(x=moval_ensemb, fill=True, color='#1f77b4', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Add the reference line y=x
g.ax_joint.axline((0, 0), slope=1, color='black', linestyle='--', label='y = x')

# Clear the y marginal plot and remove its axis
g.ax_marg_y.clear()
g.ax_marg_y.axis('off')

# Set axis labels
g.ax_joint.set_xlabel("Predicted F1-Score")
g.ax_joint.set_ylabel("Real F1-Score")

sns.kdeplot(x=gt_acc, color='black', ax=g.ax_marg_x, label='Real Label Distribution')
g.ax_marg_x.legend(loc='upper left')

# Combine legends from all plots
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_marg_x.set_ylim((0,0.15))
g.ax_joint.legend(handles=handles, labels=labels, loc='best')

# Add title to the figure
plt.suptitle("F1-Score Estimation for 3D Segmentation Tasks", y=1.02)

plt.savefig('Fig_lineplot_f1_seg3d.pdf', bbox_inches='tight')

# %%
diff_abs_baseline = np.abs(baseline_MCP_AC-gt_acc)
diff_abs_existing_best = np.abs(existing_best-gt_acc)
diff_abs_moval_ensemb = np.abs(moval_ensemb-gt_acc)

sns.set(rc={'figure.figsize':(6,2)})
sns.set_theme(style="darkgrid")
# Create a figure and a single set of axes
fig, ax = plt.subplots()

# Calculate the bin edges to ensure the same bin size for all histograms
min_val = min(diff_abs_baseline.min(), diff_abs_existing_best.min(), diff_abs_moval_ensemb.min())
max_val = max(diff_abs_baseline.max(), diff_abs_existing_best.max(), diff_abs_moval_ensemb.max())
bin_edges = np.linspace(0, 100, 100)

# Plot each distribution on the same axes
sns.histplot(diff_abs_baseline, color='#d3d3d3', label='Baseline: MCP | AC', kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_existing_best, color='grey', label='Existing Best: MCP | ' + estim_alg[select_index], kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_moval_ensemb, color='#1f77b4', label='MOVAL Ensemble', kde=True, bins=bin_edges, ax=ax)

mean_baseline = diff_abs_baseline.mean()
mean_existing_best = diff_abs_existing_best.mean()
mean_moval_ensemb = diff_abs_moval_ensemb.mean()

# Plot stars for means
ax.plot(mean_baseline, 6.5, '*', color='#d3d3d3', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_existing_best, 6.5, '*', color='grey', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_moval_ensemb, 6.5, '*', color='#1f77b4', markeredgecolor='black', markeredgewidth=1, markersize=15, label='Mean')

# Add legend for histograms
legend_hists = ax.legend(loc='upper right')

# Add both legends to the plot
ax.add_artist(legend_hists)

ax.set_xlabel('MAE')
ax.set_ylabel('Number of Samples')

ax.set_xlim((0, 30))

plt.savefig('Fig_hisplot_f1_seg3d.pdf', bbox_inches='tight')

# %%
diff = np.mean(np.abs(estim_seg3d_auc - np.tile(gt_seg3d_auc, (20, 1))), axis = 1)
# 83, 5, 83, 12
#
estim_alg = ["AC", "TS", "DoC", "ATC", "TS-ATC"]
#
diff_existing = diff[existing_index_FP]
select_index = np.argmin(diff_existing)
#
baseline_MCP_AC = estim_seg3d_auc[0, :]
existing_best = estim_seg3d_auc[existing_index_full[select_index], :]
moval_ensemb = estim_seg3d_auc_ensemb[0, :]
gt_acc = gt_seg3d_auc[0, :]
#
sns.set_theme(style="darkgrid")

# Create the JointGrid
g = sns.JointGrid()
g.ax_joint.set_xlim([0., 100.])
g.ax_joint.set_ylim([0., 100.])

# Plot the first dataset
sns.scatterplot(x=baseline_MCP_AC[:83], y=gt_acc[:83], color='#d3d3d3', marker='*', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[83:83+5], y=gt_acc[83:83+5], color='#d3d3d3', marker='x', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[83+5:83+5+83], y=gt_acc[83+5:83+5+83], color='#d3d3d3', marker='.', ax=g.ax_joint)
sns.scatterplot(x=baseline_MCP_AC[83+5+83:], y=gt_acc[83+5+83:], color='#d3d3d3', marker='o', ax=g.ax_joint)
sns.regplot(x=baseline_MCP_AC, y=gt_acc, color='#d3d3d3', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Baseline: MCP | AC')
sns.kdeplot(x=baseline_MCP_AC, fill=True, color='#d3d3d3', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the second dataset
sns.scatterplot(x=existing_best[:83], y=gt_acc[:83], color='grey', marker='*', ax=g.ax_joint)
sns.scatterplot(x=existing_best[83:83+5], y=gt_acc[83:83+5], color='grey', marker='x', ax=g.ax_joint)
sns.scatterplot(x=existing_best[83+5:83+5+83], y=gt_acc[83+5:83+5+83], color='grey', marker='.', ax=g.ax_joint)
sns.scatterplot(x=existing_best[83+5+83:], y=gt_acc[83+5+83:], color='grey', marker='o', ax=g.ax_joint)
sns.regplot(x=existing_best, y=gt_acc, color='grey', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='Existing Best: MCP | ' + estim_alg[select_index])
sns.kdeplot(x=existing_best, fill=True, color='grey', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Plot the third dataset
sns.regplot(x=moval_ensemb, y=gt_acc, color='#1f77b4', ax=g.ax_joint, ci=68, truncate=False, scatter=False, label='MOVAL Ensemble')
sns.scatterplot(x=moval_ensemb[:83], y=gt_acc[:83], color='#1f77b4', marker='*', ax=g.ax_joint, label='Prostate Synthetic')
sns.scatterplot(x=moval_ensemb[83:83+5], y=gt_acc[83:83+5], color='#1f77b4', marker='x', ax=g.ax_joint, label='Prostate Natural')
sns.scatterplot(x=moval_ensemb[83+5:83+5+83], y=gt_acc[83+5:83+5+83], color='#1f77b4', marker='.', ax=g.ax_joint, label='Brain Lesion Synthetic')
sns.scatterplot(x=moval_ensemb[83+5+83:], y=gt_acc[83+5+83:], color='#1f77b4', marker='o', ax=g.ax_joint, label='Brain Lesion Natural')
sns.kdeplot(x=moval_ensemb, fill=True, color='#1f77b4', ax=g.ax_marg_x, linewidth=0, alpha=0.7)

# Add the reference line y=x
g.ax_joint.axline((0, 0), slope=1, color='black', linestyle='--', label='y = x')

# Clear the y marginal plot and remove its axis
g.ax_marg_y.clear()
g.ax_marg_y.axis('off')

# Set axis labels
g.ax_joint.set_xlabel("Predicted AUC")
g.ax_joint.set_ylabel("Real AUC")

sns.kdeplot(x=gt_acc, color='black', ax=g.ax_marg_x, label='Real Label Distribution')
g.ax_marg_x.legend(loc='upper left')

# Combine legends from all plots
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, loc='best')

# Add title to the figure
plt.suptitle("AUC Estimation for 3D Segmentation Tasks", y=1.02)

plt.savefig('Fig_lineplot_AUC_seg3d.pdf', bbox_inches='tight')

# %%
diff_abs_baseline = np.abs(baseline_MCP_AC-gt_acc)
diff_abs_existing_best = np.abs(existing_best-gt_acc)
diff_abs_moval_ensemb = np.abs(moval_ensemb-gt_acc)

sns.set(rc={'figure.figsize':(6,2)})
sns.set_theme(style="darkgrid")
# Create a figure and a single set of axes
fig, ax = plt.subplots()

# Calculate the bin edges to ensure the same bin size for all histograms
min_val = min(diff_abs_baseline.min(), diff_abs_existing_best.min(), diff_abs_moval_ensemb.min())
max_val = max(diff_abs_baseline.max(), diff_abs_existing_best.max(), diff_abs_moval_ensemb.max())
bin_edges = np.linspace(min_val, max_val, 30)

# Plot each distribution on the same axes
sns.histplot(diff_abs_baseline, color='#d3d3d3', label='Baseline: MCP | AC', kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_existing_best, color='grey', label='Existing Best: MCP | ' + estim_alg[select_index], kde=True, bins=bin_edges, ax=ax)
sns.histplot(diff_abs_moval_ensemb, color='#1f77b4', label='MOVAL Ensemble', kde=True, bins=bin_edges, ax=ax)

mean_baseline = diff_abs_baseline.mean()
mean_existing_best = diff_abs_existing_best.mean()
mean_moval_ensemb = diff_abs_moval_ensemb.mean()

# Plot stars for means
ax.plot(mean_baseline, 10.5, '*', color='#d3d3d3', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_existing_best, 10.5, '*', color='grey', markeredgecolor='black', markeredgewidth=1, markersize=15)
ax.plot(mean_moval_ensemb, 10.5, '*', color='#1f77b4', markeredgecolor='black', markeredgewidth=1, markersize=15, label='Mean')

# Add legend for histograms
legend_hists = ax.legend(loc='upper right')

# Add both legends to the plot
ax.add_artist(legend_hists)

ax.set_xlabel('MAE')
ax.set_ylabel('Number of Samples')


plt.savefig('Fig_hisplot_auc_seg3d.pdf', bbox_inches='tight')
